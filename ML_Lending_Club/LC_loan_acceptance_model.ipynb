# %% [markdown]
# For an up-to-date version / full view of the plotly - plots, please, go to
#
# Loan acceptance model: https://drive.google.com/file/d/1AK3SW55QoWe8Kwx-DipmdvwDRVLEFUHZ/view?usp=sharing

# %% [markdown]
# # LendingClub Prediction: Loan Acceptance

# %% [markdown]
# In this step I will predict the loan status of LendingClub's loan data.

# %% [markdown]
# ## Imports

# %%
# %%capture
! pip install scikit-learn==1.2.2 # need old version for eli5
! pip install xgboost==2.0.2

! pip install -q fastparquet==2024.2.0
! pip install -q dask==2023.8.1
! pip install -q pandas==1.5.3
! pip install -q numpy==1.25.2

! pip install -q eli5
! pip install -q shap
! pip install -q sklego

# %%
import numpy as np
import pandas as pd

import sys
import os
import warnings

from dask import dataframe as dd
import matplotlib.pyplot as plt
import seaborn as sns

from imblearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import (StandardScaler,
                                   OrdinalEncoder,
                                   OneHotEncoder,
                                   LabelEncoder)

#from imblearn.over_sampling import SMOTE, RandomOverSampler
#from imblearn.under_sampling import RandomUnderSampler
from sklearn.impute import SimpleImputer #, KNNImputer

from sklearn.feature_selection import SelectKBest, f_classif #, #f_regression
#from sklearn.feature_selection import f_classif #, #f_regression
from sklearn.feature_selection import RFECV

from sklearn.model_selection import train_test_split
from sklearn.model_selection import (RepeatedKFold,
                                     StratifiedKFold,
                                     RepeatedStratifiedKFold)
from sklearn.model_selection import cross_val_score

from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

#from sklearn.metrics import confusion_matrix #for confusion matrix
#from sklearn.metrics import accuracy_score, f1_score

from scipy.stats import randint, loguniform, uniform

import copy

#from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
#from sklearn.experimental import enable_halving_search_cv # noqa
#from sklearn.model_selection import HalvingGridSearchCV, HalvingRandomSearchCV

from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import BaggingClassifier

from tempfile import mkdtemp
from shutil import rmtree
from joblib import Memory

import eli5
from eli5.sklearn import PermutationImportance
import shap
#from sklearn.feature_extraction.text import TfidfVectorizer

from yellowbrick.classifier import (ROCAUC,
                                    PrecisionRecallCurve,
                                    DiscriminationThreshold)

from sklego.meta import Thresholder


import pickle


# Create a temporary folder to store the transformers of the pipeline
cachedir = mkdtemp()
memory = Memory(location=cachedir, verbose=False)


from google.colab import drive
drive.mount("/content/gdrive")

warnings.filterwarnings('ignore')

pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)

#pd.reset_option('display.max_rows')
# Out:
# Mounted at /content/gdrive

# %%
home_folder = '/content/gdrive/MyDrive/Colab Notebooks/Portfolio/ML_LendingClub/'

# %% [markdown]
# ### Functions

# %% [markdown]
# The Python-file with the functions is at
# https://drive.google.com/file/d/1JWLo8HAhUdu5xkDG4-tu7MiUSLgSxOjQ/view?usp=sharing

# %%
# %load_ext autoreload
# %autoreload 2

sys.path.append(home_folder)
import lendfunc as lfunc

# %%
! pip freeze > /content/gdrive/MyDrive/Colab\ Notebooks/Portfolio/ML_LendingClub/requirements.txt

# %% [markdown]
# # Model - Loan Acceptance

# %% [markdown]
# ### Data Preparation

# %%
parquet_home_acc_cleaned = home_folder+'parquet_LCacc_cleaned/'
parquet_home_rej_cleaned = home_folder+'parquet_LCrej_cleaned/'

# %%
LCacc_dd = dd.read_parquet(parquet_home_acc_cleaned, ignore_metadata_file=True)
LCrej_dd = dd.read_parquet(parquet_home_rej_cleaned, ignore_metadata_file=True)

# %%
size_acc_dd = len(LCacc_dd)
size_rej_dd = len(LCrej_dd)
acc_rej_size_ratio = size_acc_dd/size_rej_dd

# %% [markdown]
# #### Create joint sample for Loan Applications

# %%
rej_cols = ['Amount Requested', 'Risk_Score', 'Zip Code', 'State',
       'Employment Length', 'applied_year', 'dti']

# %%
acc_cols = ['loan_amnt', 'fico_range_high', 'zip_code', 'addr_state',
       'emp_length', 'issue_d_year', 'dti']

# %%
rename_map={}
for rej, acc in zip(rej_cols, acc_cols):
    rename_map[acc] = rej

# %%
rejSAMPLES = 10000
frac_rej = rejSAMPLES/size_rej_dd

LCrej_dd_app =LCrej_dd[rej_cols].sample(frac=frac_rej, replace=False, random_state=10)
LCrej_dd_app['App_Status'] = 'rejected'

# %%
accSAMPLES = rejSAMPLES * acc_rej_size_ratio
frac_acc = accSAMPLES/size_acc_dd

LCacc_dd_app =LCacc_dd[acc_cols].sample(frac=frac_acc, replace=False, random_state=10)
LCacc_dd_app['App_Status'] = 'accepted'

# %%
LCrej_app = LCrej_dd_app.compute()
len(LCrej_app)
# Out:
# 10002

# %%
LCacc_app = LCacc_dd_app.compute()
len(LCacc_app)
# Out:
# 779

# %%
LCacc_app.rename(columns=rename_map, inplace=True)

# %%
LCapp = pd.concat([LCrej_app, LCacc_app], axis=0)

LCapp.reset_index(inplace=True, drop=True)

# %%
len(LCapp)
# Out:
# 10781

# %%
LCapp.to_csv(home_folder+'cleaned/LendingClub_app_model.csv', index=False)

# %% [markdown]
# ### Cross Validations and Score Metric Definitions

# %%
cvRK = RepeatedKFold(n_splits=5, n_repeats= 10, random_state=1)
cvSK = StratifiedKFold(n_splits=5, shuffle=False, random_state=None)
vSKs = StratifiedKFold(n_splits=5, shuffle=True, random_state=1)

cvRSK = RepeatedStratifiedKFold(n_splits=5, n_repeats=10, random_state=1)

# %%
#scoring = 'r2' #'f1'
scoring = 'balanced_accuracy' #'f1_weighted'
#scoring = 'f1_macro'
#scoring = 'f1_weighted'
#scoring = 'roc_auc'  #crashes at RFECV

# %% [markdown]
# ### Base Estimators

# %% [markdown]
# If computation time allows I am curious about the performances of as many classifiers as possible. Therefore I hold a collection of them ready to use.

# %% [markdown]
# DEFINE HERE THE SET OF CLASSIFIERS TO BE USED in this run:

# %%
classifiers=[#'Linear Svm','Radial Svm',
             'Logistic Regression',
             'KNN',
             'Decision Tree', #'Random Forest',
             'LightGBM', 'XGBoost'] #, 'CatBoost']

# %% [markdown]
# Base Classifier Setup

# %%
# %reload_ext autoreload

# probability=True in SVMs needed for later scoring, but
# LinSVC = LinearSVC(random_state = 1, class_weight="balanced")
#  <-- cannot set probability=True for later scoring - replace by kernel SVC
LinSVC = SVC(kernel='linear', random_state = 1, class_weight="balanced",
             probability=True)
rbfSVC = SVC(kernel='rbf', random_state = 1, class_weight="balanced",
             probability=True)


#RandomizedSearch takes too long with probability=True
#--> create extra version for hypertuning
LinSVC_hypersearch = SVC(kernel='linear', random_state = 1, class_weight="balanced")
rbfSVC_hypersearch = SVC(kernel='rbf', random_state = 1, class_weight="balanced")


#LinReg = LinearRegression(n_jobs=-1)

LogReg = LogisticRegression(random_state = 1, n_jobs=-1,
                            class_weight="balanced")
KNNClas = KNeighborsClassifier(n_jobs=-1)
DTClas = DecisionTreeClassifier(random_state = 1,
                                class_weight="balanced")
RFClas = RandomForestClassifier(random_state = 1, n_jobs=-1,
                                class_weight="balanced", )
LGBMClas = lfunc.LGBMClassifierWithEarlyStop(random_state=1,
                                             class_weight="balanced",
                                             objective="binary",
                                             metric="binary_logloss",
                                             early_stopping_round=10,
                                             verbosity=-100,
                                             force_row_wise=True,
                                             #force_col_wise=True,
                                             )
#CatBClas = CatBoostClassifier(random_state=1, verbose=False)
XGBClas = lfunc.XGBoostClassifierWithEarlyStop(random_state=1,
                                               enable_categorical=False,
                                               eval_metric='binary_logloss',
                                               verbosity=0)

# estimators and their names
classifier_map = {'Linear Svm': LinSVC,
                  'Radial Svm': rbfSVC,
                  'Logistic Regression': LogReg,
                  'KNN': KNNClas,
                  'Decision Tree': DTClas,
                  'Random Forest': RFClas,
                  'LightGBM': LGBMClas,
                  'XGBoost': XGBClas
}

# %% [markdown]
# ### Test Train Split

# %% [markdown]
# EDA-based selection of features:

# %%
LCapp.columns
# Out:
# Index(['Amount Requested', 'Risk_Score', 'Zip Code', 'State',
#        'Employment Length', 'applied_year', 'dti', 'App_Status'],
#       dtype='object')

# %% [markdown]
# 'Zip Code', 'State', 'applied_year' most likely not helpful.

# %% [markdown]
# Construct the model data set and encode the labels

# %%
features = ['Amount Requested',
            'Risk_Score',
            'Employment Length',
            'dti'
            ]

X = LCapp[features]
y = LCapp['App_Status'].to_frame()

# %%
y['App_Status'].value_counts()
# Out:
# rejected    10002
# accepted      779
# Name: App_Status, dtype: int64

# %%
LE = LabelEncoder()
y = LE.fit_transform(y)

labels = LE.classes_.tolist()
labels
# Out:
# ['accepted', 'rejected']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,
                                                    random_state=0,
                                                    stratify = y) # <---- no stratify for cont. var!!!!!

X_train_analysis = X_train.copy()
X_test_analysis = X_test.copy()

# %% [markdown]
# ### Preprocessor Setup

# %% [markdown]
# **Setup of the Ordinal Encoder**

# %% [markdown]
# Ranking information for Verification Status:
#
# Verified income means that Lending Club independently verified both the source and size of reported income, source verified means that they verified only the source of the income, and not verified means there was no independent verification of the reported values.
#
# https://michaeltoth.me/analyzing-historical-default-rates-of-lending-club-notes.html

# %%
ordinal_encode = {'Employment Length': ['< 1 year', '1 year', '2 years',
                                        '3 years', '4 years', '5 years',
                                        '6 years', '7 years', '8 years',
                                        '9 years', '10+ years']
                  }

ord_stepname_pre = "ord_"

ordinal_impute_step = ("imputer", SimpleImputer(strategy="most_frequent"))
ordinal_transformers=[]

for key in ordinal_encode.keys():
    ordinal_step = ('ordenc', OrdinalEncoder(handle_unknown="error",
                    categories = [ordinal_encode[key]]))
    ordinal_transformer = Pipeline(steps = [ordinal_impute_step,
                                            ordinal_step])
    ordinal_transformer_key = (ord_stepname_pre + key, ordinal_transformer, [key])
    ordinal_transformers.append(ordinal_transformer_key)

# %%
#### switch this here on and off for the use of ordinal encoding:
#ordinal_encode={}

# %% [markdown]
# **Setup of the Numerical and Categorical Transformers**

# %%
numeric_transformer = Pipeline(
    steps=[("imputer", SimpleImputer(strategy="median")),
           ("scaler", StandardScaler())
           ]
)

categorical_transformer = Pipeline(
    steps=[("imputer", SimpleImputer(strategy="most_frequent")),
           ("encoder", OneHotEncoder(handle_unknown="ignore")),
           ]
)

# %% [markdown]
# **Define the ColumnTransformer preprocessing Pipeline and gather the new Columns Names**

# %%
num_feat = X_train.select_dtypes(include=np.number).columns.tolist()
cat_feat = X_train.select_dtypes(exclude=np.number).columns.tolist()
ord_feat = ordinal_encode.keys()

# if ordinal, remove ordinal features from categorical feature list
if ordinal_encode:
    for feat in ord_feat:
        if feat in cat_feat:
            cat_feat.remove(feat)

# basic transformer
transformers=[("num", numeric_transformer, num_feat),
              ("cat", categorical_transformer, cat_feat)
              ]

# if ordinal, extend basic transformer
if ordinal_encode:
    transformers.extend(ordinal_transformers)


# THE PREPROCESSOR
preprocessor = ColumnTransformer(transformers=transformers,
                                 remainder='passthrough'
                                 )


# restoring the columns names after transform:
X_train_transformed = preprocessor.fit_transform(X_train)

new_cols = preprocessor.get_feature_names_out().tolist()

# rename ordinal
for key in ordinal_encode.keys():
   list_index = new_cols.index(ord_stepname_pre+key+"__"+key)
   new_cols[list_index] = ord_stepname_pre+"_"+key

# test if restoring worked (fails for inconsistent shape/length)
X_train_prep = pd.DataFrame(X_train_transformed, columns=new_cols)

# %% [markdown]
# Turn proprocessor into general pipeline steps to which the next steps can be appended, e.g. over/undersampling, classifier.

# %%
X_transformer_steps = [('preprocessor', preprocessor)]

# general pipeline preprocessing steps, i.e. append over/undersampling
pipe_prep_steps = X_transformer_steps.copy()

# %%
print('The number of features increased from', len(X_train.columns), 'to',
      len(X_train_prep.columns), 'after preprocessing.' )
#len(X_train.columns), len(X_train_prep.columns)
# Out:
# The number of features increased from 4 to 4 after preprocessing.

# %%
# how to access infos:
# preprocessor.transformers[0][2]

# %% [markdown]
# ### Feature Selection

# %% [markdown]
# This is rather a try-out. Goal was to see if SelectKBest, RidgeCV, and RFE find the same features.

# %% [markdown]
# #### SelectKBest

# %%
pipe_steps = pipe_prep_steps.copy()
pipe_steps.append(('f_classif', SelectKBest(score_func=f_classif, k=3)))

KBest_pipe = Pipeline(pipe_steps)

KBest_pipe.fit(X_train,y_train)


KBest = KBest_pipe.named_steps['f_classif'].get_feature_names_out()

KBest_cols = []
for feature in KBest:
    index_nr = int(feature.replace('x', ''))
    KBest_cols.append(new_cols[index_nr])

KBest_cols
# Out:
# ['num__Amount Requested', 'num__Risk_Score', 'ord__Employment Length']

# %% [markdown]
# #### RidgeCV

# %% [markdown]
# Another try-out: a regularization algorithm that returns features importances:

# %%
import matplotlib.pyplot as plt
import numpy as np

from sklearn.linear_model import RidgeCV, RidgeClassifierCV

ridge = RidgeClassifierCV(alphas=np.logspace(-6, 6, num=5),
                          scoring = scoring, cv = cvSK)

pipe_steps = pipe_prep_steps.copy()
pipe_steps.append(('Feature Selection', ridge))

ridge_pipeline = Pipeline(pipe_steps)

ridge_pipeline.fit(X_train,y_train)

importance = np.abs(ridge.coef_[0])

ridge_df = pd.DataFrame(importance,index=new_cols,columns=['Importance'])#.sort_values(by='Rank',ascending=True)
ridge_df.reset_index(inplace=True)
ridge_df = ridge_df.sort_values(by='Importance',ascending=False)



fig = plt.figure(figsize=(10,10))
ax = fig.gca()  # define axis

hbars = ax.barh(ridge_df['index'][:20], ridge_df['Importance'][:20], align='center')
ax.set_title("Feature importances via coefficients")
ax.invert_yaxis()
ax.bar_label(hbars, fmt='%.2f')
#ax.set_xlim(right=0.107)  # adjust xlim to fit labels

plt.show()

# %%
ridge_df['index'][:20].sort_values().values.tolist()
# Out:
# ['num__Amount Requested',
#  'num__Risk_Score',
#  'num__dti',
#  'ord__Employment Length']

# %%
KBest_cols.sort()
KBest_cols
# Out:
# ['num__Amount Requested', 'num__Risk_Score', 'ord__Employment Length']

# %% [markdown]
# #### Recursive Feature Elimination (RFECV)

# %% [markdown]
# Attempt to reduce the number of features through recursive feature elimination:

# %%
# %%time
# the error:  "when importance_getter=='auto', the underlying estimator X
# should have 'coef_' or 'feature_importances_' attribute."
# limits the pool of estimator that are easy to use:

#model = LinReg
#model = LogReg
#model = RFClas
#model = LinSVC
model = DTClas


rfecv = RFECV(estimator=model,
              #cv=cvRSK,  ### takes ages!!! >13min
              cv=cvSK, # for classification
              #cv=cvRK, # for regression
              scoring = scoring
              )


pipeline = Pipeline([('preprocessor', preprocessor),
                     ('Feature Selection', rfecv)
                     ])

pipeline.fit(X_train,y_train)

rfecv_df = pd.DataFrame(rfecv.ranking_,index=new_cols,columns=['Rank'])
rfecv_df.reset_index(inplace=True)
rfecv_df = rfecv_df.sort_values(by='Rank',ascending=True)
rfecv_df
# Out:
# CPU times: user 270 ms, sys: 2.33 ms, total: 273 ms
# Wall time: 279 ms
#                     index  Rank
# 1         num__Risk_Score     1
# 2                num__dti     2
# 3  ord__Employment Length     3
# 0   num__Amount Requested     4

# %%
mean_score = np.max(rfecv.cv_results_["mean_test_score"]).round(5)
print('The mean', scoring, 'scoring is:', mean_score)
# Out:
# The mean balanced_accuracy scoring is: 0.98414

# %%
plt.figure(figsize=(12,6))
plt.xlabel('Number of features selected')
plt.ylabel('Cross validation score (nb of correct classifications)')
n_scores = len(rfecv.cv_results_["mean_test_score"])
plt.errorbar(
    range(1, n_scores + 1),
    rfecv.cv_results_["mean_test_score"],
    yerr=rfecv.cv_results_["std_test_score"],
)
plt.show()

# %%
#rfecv.cv_results_["mean_test_score"].round(3)

# %% [markdown]
# ### Scores per Basic Model BEFORE Hyperparameter Tuning

# %% [markdown]
# First, we do a crossvalidation on support vector machines, logistic regression, k-nearest neighbors, decision tree, and random forest, LightGBM, and XGBoost algorithms with their default parameters to see where we stand.

# %%
# %%time
# %reload_ext autoreload

estimators_basic = []
for clas in classifiers:
    estimators_basic.append(classifier_map[clas])

models_basic=[]
for estimator in estimators_basic:
    pipe_steps = pipe_prep_steps.copy()
    pipe_steps.append(('classifier' , estimator))
    models_basic.append(Pipeline(pipe_steps))

model_cv_results_before = lfunc.model_scores(X_train,y_train,X_test,
                                      models = models_basic,
                                      model_names = classifiers,
                                      cv = cvRSK)

(model_performance_before,
 collect_cv_results_before,
 model_prob_before) = model_cv_results_before
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
# [3]	validation_0-logloss:0.12008
# [4]	validation_0-logloss:0.10392
# [5]	validation_0-logloss:0.09343
# [6]	validation_0-logloss:0.08629
# [7]	validation_0-logloss:0.08204
# [8]	validation_0-logloss:0.07824
# [9]	validation_0-logloss:0.07517
# [10]	validation_0-logloss:0.07320
# [11]	validation_0-logloss:0.07072
# [12]	validation_0-logloss:0.06996
# [13]	validation_0-logloss:0.06866
# [14]	validation_0-logloss:0.06876
# [15]	validation_0-logloss:0.06875
# [16]	validation_0-logloss:0.06693
# [17]	validation_0-logloss:0.06698
# [18]	validation_0-logloss:0.06521
# [19]	validation_0-logloss:0.06341
# [20]	validation_0-logloss:0.06240
# [21]	validation_0-logloss:0.06189
# [22]	validation_0-logloss:0.06186
# [23]	validation_0-logloss:0.06161
# [24]	validation_0-logloss:0.06049
# [25]	validation_0-logloss:0.06007
# [26]	validation_0-logloss:0.06042
# [27]	validation_0-logloss:0.06030
# [28]	validation_0-logloss:0.06100
# [29]	validation_0-logloss:0.06136
# [30]	validation_0-logloss:0.06225
# [31]	validation_0-logloss:0.06145
# [32]	validation_0-logloss:0.06185
# [33]	validation_0-logloss:0.06109
# [34]	validation_0-logloss:0.06104
# [35]	validation_0-logloss:0.06069
# [36]	validation_0-logloss:0.06152
# [37]	validation_0-logloss:0.06141
# [38]	validation_0-logloss:0.06181
# [39]	validation_0-logloss:0.06119
# [40]	validation_0-logloss:0.06119
# [41]	validation_0-logloss:0.06118
# [42]	validation_0-logloss:0.06087
# [43]	validation_0-logloss:0.06128
# [44]	validation_0-logloss:0.06141
# [45]	validation_0-logloss:0.06142
# [46]	validation_0-logloss:0.06093
# [47]	validation_0-logloss:0.06129
# [48]	validation_0-logloss:0.06290
# [49]	validation_0-logloss:0.06283
# [50]	validation_0-logloss:0.06327
# [51]	validation_0-logloss:0.06342
# [52]	validation_0-logloss:0.06428
# [53]	validation_0-logloss:0.06417
# [54]	validation_0-logloss:0.06478
# [55]	validation_0-logloss:0.06518
# [56]	validation_0-logloss:0.06448
# [57]	validation_0-logloss:0.06530
# [58]	validation_0-logloss:0.06515
# [59]	validation_0-logloss:0.06568
# [60]	validation_0-logloss:0.06618
# [61]	validation_0-logloss:0.06610
# [62]	validation_0-logloss:0.06606
# [63]	validation_0-logloss:0.06612
# [64]	validation_0-logloss:0.06603
# [65]	validation_0-logloss:0.06677
# [66]	validation_0-logloss:0.06636
# [67]	validation_0-logloss:0.06680
# [68]	validation_0-logloss:0.06662
# [69]	validation_0-logloss:0.06666
# [70]	validation_0-logloss:0.06640
# [71]	validation_0-logloss:0.06680
# [72]	validation_0-logloss:0.06751
# [73]	validation_0-logloss:0.06801
# [74]	validation_0-logloss:0.06899
# [75]	validation_0-logloss:0.06981
# [76]	validation_0-logloss:0.06944
# [77]	validation_0-logloss:0.06944
# [78]	validation_0-logloss:0.06969
# [79]	validation_0-logloss:0.06976
# [80]	validation_0-logloss:0.06993
# [81]	validation_0-logloss:0.06947
# [82]	validation_0-logloss:0.06963
# [83]	validation_0-logloss:0.06908
# [84]	validation_0-logloss:0.06938
# [85]	validation_0-logloss:0.06947
# [86]	validation_0-logloss:0.06920
# [87]	validation_0-logloss:0.06907
# [88]	validation_0-logloss:0.06914
# [89]	validation_0-logloss:0.06941
# [90]	validation_0-logloss:0.06932
# [91]	validation_0-logloss:0.06952
# [92]	validation_0-logloss:0.07001
# [93]	validation_0-logloss:0.06985
# [94]	validation_0-logloss:0.06988
# [95]	validation_0-logloss:0.07038
# [96]	validation_0-logloss:0.07056
# [97]	validation_0-logloss:0.07102
# [98]	validation_0-logloss:0.07222
# [99]	validation_0-logloss:0.07229
# [0]	validation_0-logloss:0.18855
# [1]	validation_0-logloss:0.14825
# [2]	validation_0-logloss:0.12112
# [3]	validation_0-logloss:0.10210
# [4]	validation_0-logloss:0.08915
# [5]	validation_0-logloss:0.07950
# [6]	validation_0-logloss:0.07310
# [7]	validation_0-logloss:0.06823
# [8]	validation_0-logloss:0.06549
# [9]	validation_0-logloss:0.06225
# [10]	validation_0-logloss:0.06072
# [11]	validation_0-logloss:0.05885
# [12]	validation_0-logloss:0.05714
# [13]	validation_0-logloss:0.05663
# [14]	validation_0-logloss:0.05523
# [15]	validation_0-logloss:0.05490
# [16]	validation_0-logloss:0.05510
# [17]	validation_0-logloss:0.05449
# [18]	validation_0-logloss:0.05291
# [19]	validation_0-logloss:0.05213
# [20]	validation_0-logloss:0.05127
# [21]	validation_0-logloss:0.05012
# [22]	validation_0-logloss:0.05003
# [23]	validation_0-logloss:0.05007
# [24]	validation_0-logloss:0.04844
# [25]	validation_0-logloss:0.04803
# [26]	validation_0-logloss:0.04750
# [27]	validation_0-logloss:0.04696
# [28]	validation_0-logloss:0.04736
# [29]	validation_0-logloss:0.04755
# [30]	validation_0-logloss:0.04740
# [31]	validation_0-logloss:0.04693
# [32]	validation_0-logloss:0.04661
# [33]	validation_0-logloss:0.04644
# [34]	validation_0-logloss:0.04632
# [35]	validation_0-logloss:0.04710
# [36]	validation_0-logloss:0.04654
# [37]	validation_0-logloss:0.04712
# [38]	validation_0-logloss:0.04741
# [39]	validation_0-logloss:0.04743
# [40]	validation_0-logloss:0.04776
# [41]	validation_0-logloss:0.04821
# [42]	validation_0-logloss:0.04832
# [43]	validation_0-logloss:0.04837
# [44]	validation_0-logloss:0.04794
# [45]	validation_0-logloss:0.04800
# [46]	validation_0-logloss:0.04751
# [47]	validation_0-logloss:0.04688
# [48]	validation_0-logloss:0.04652
# [49]	validation_0-logloss:0.04696
# [50]	validation_0-logloss:0.04734
# [51]	validation_0-logloss:0.04709
# [52]	validation_0-logloss:0.04697
# [53]	validation_0-logloss:0.04727
# [54]	validation_0-logloss:0.04714
# [55]	validation_0-logloss:0.04777
# [56]	validation_0-logloss:0.04796
# [57]	validation_0-logloss:0.04955
# [58]	validation_0-logloss:0.04966
# [59]	validation_0-logloss:0.04950
# [60]	validation_0-logloss:0.05043
# [61]	validation_0-logloss:0.05030
# [62]	validation_0-logloss:0.05024
# [63]	validation_0-logloss:0.05048
# [64]	validation_0-logloss:0.05054
# [65]	validation_0-logloss:0.05041
# [66]	validation_0-logloss:0.05104
# [67]	validation_0-logloss:0.05178
# [68]	validation_0-logloss:0.05234
# [69]	validation_0-logloss:0.05253
# [70]	validation_0-logloss:0.05245
# [71]	validation_0-logloss:0.05294
# [72]	validation_0-logloss:0.05314
# [73]	validation_0-logloss:0.05368
# [74]	validation_0-logloss:0.05416
# [75]	validation_0-logloss:0.05401
# [76]	validation_0-logloss:0.05393
# [77]	validation_0-logloss:0.05389
# [78]	validation_0-logloss:0.05428
# [79]	validation_0-logloss:0.05475
# [80]	validation_0-logloss:0.05512
# [81]	validation_0-logloss:0.05574
# [82]	validation_0-logloss:0.05614
# [83]	validation_0-logloss:0.05671
# [84]	validation_0-logloss:0.05707
# [85]	validation_0-logloss:0.05752
# [86]	validation_0-logloss:0.05780
# [87]	validation_0-logloss:0.05774
# [88]	validation_0-logloss:0.05801
# [89]	validation_0-logloss:0.05858
# [90]	validation_0-logloss:0.05852
# [91]	validation_0-logloss:0.05886
# [92]	validation_0-logloss:0.05969
# [93]	validation_0-logloss:0.05974
# [94]	validation_0-logloss:0.06000
# [95]	validation_0-logloss:0.05961
# [96]	validation_0-logloss:0.05954
# [97]	validation_0-logloss:0.05928
# [98]	validation_0-logloss:0.05959
# [99]	validation_0-logloss:0.05997
# [0]	validation_0-logloss:0.17889
# [1]	validation_0-logloss:0.13933
# [2]	validation_0-logloss:0.11402
# [3]	validation_0-logloss:0.09660
# [4]	validation_0-logloss:0.08355
# [5]	validation_0-logloss:0.07415
# [6]	validation_0-logloss:0.06911
# [7]	validation_0-logloss:0.06339
# [8]	validation_0-logloss:0.05979
# [9]	validation_0-logloss:0.05753
# [10]	validation_0-logloss:0.05566
# [11]	validation_0-logloss:0.05464
# [12]	validation_0-logloss:0.05323
# [13]	validation_0-logloss:0.05346
# [14]	validation_0-logloss:0.05263
# [15]	validation_0-logloss:0.05353
# [16]	validation_0-logloss:0.05177
# [17]	validation_0-logloss:0.05090
# [18]	validation_0-logloss:0.05090
# [19]	validation_0-logloss:0.05070
# [20]	validation_0-logloss:0.05007
# [21]	validation_0-logloss:0.05047
# [22]	validation_0-logloss:0.05000
# [23]	validation_0-logloss:0.04992
# [24]	validation_0-logloss:0.05024
# [25]	validation_0-logloss:0.05038
# [26]	validation_0-logloss:0.05106
# [27]	validation_0-logloss:0.05168
# [28]	validation_0-logloss:0.05071
# [29]	validation_0-logloss:0.05137
# [30]	validation_0-logloss:0.05108
# [31]	validation_0-logloss:0.05137
# [32]	validation_0-logloss:0.05095
# [33]	validation_0-logloss:0.05129
# [34]	validation_0-logloss:0.05075
# [35]	validation_0-logloss:0.05118
# [36]	validation_0-logloss:0.05074
# [37]	validation_0-logloss:0.05112
# [38]	validation_0-logloss:0.05098
# [39]	validation_0-logloss:0.05027
# [40]	validation_0-logloss:0.05033
# [41]	validation_0-logloss:0.05013
# [42]	validation_0-logloss:0.05049
# [43]	validation_0-logloss:0.05081
# [44]	validation_0-logloss:0.05111
# [45]	validation_0-logloss:0.05085
# [46]	validation_0-logloss:0.05117
# [47]	validation_0-logloss:0.05157
# [48]	validation_0-logloss:0.05190
# [49]	validation_0-logloss:0.05245
# [50]	validation_0-logloss:0.05233
# [51]	validation_0-logloss:0.05274
# [52]	validation_0-logloss:0.05355
# [53]	validation_0-logloss:0.05347
# [54]	validation_0-logloss:0.05319
# [55]	validation_0-logloss:0.05331
# [56]	validation_0-logloss:0.05360
# [57]	validation_0-logloss:0.05360
# [58]	validation_0-logloss:0.05401
# [59]	validation_0-logloss:0.05452
# [60]	validation_0-logloss:0.05501
# [61]	validation_0-logloss:0.05492
# [62]	validation_0-logloss:0.05534
# [63]	validation_0-logloss:0.05545
# [64]	validation_0-logloss:0.05577
# [65]	validation_0-logloss:0.05577
# [66]	validation_0-logloss:0.05615
# [67]	validation_0-logloss:0.05599
# [68]	validation_0-logloss:0.05598
# [69]	validation_0-logloss:0.05650
# [70]	validation_0-logloss:0.05648
# [71]	validation_0-logloss:0.05596
# [72]	validation_0-logloss:0.05639
# [73]	validation_0-logloss:0.05682
# [74]	validation_0-logloss:0.05696
# [75]	validation_0-logloss:0.05729
# [76]	validation_0-logloss:0.05700
# [77]	validation_0-logloss:0.05685
# [78]	validation_0-logloss:0.05713
# [79]	validation_0-logloss:0.05735
# [80]	validation_0-logloss:0.05771
# [81]	validation_0-logloss:0.05793
# [82]	validation_0-logloss:0.05859
# [83]	validation_0-logloss:0.05917
# [84]	validation_0-logloss:0.05900
# [85]	validation_0-logloss:0.05885
# [86]	validation_0-logloss:0.05901
# [87]	validation_0-logloss:0.05916
# [88]	validation_0-logloss:0.05928
# [89]	validation_0-logloss:0.05977
# [90]	validation_0-logloss:0.05985
# [91]	validation_0-logloss:0.05959
# [92]	validation_0-logloss:0.05972
# [93]	validation_0-logloss:0.05976
# [94]	validation_0-logloss:0.05993
# [95]	validation_0-logloss:0.06006
# [96]	validation_0-logloss:0.06005
# [97]	validation_0-logloss:0.06029
# [98]	validation_0-logloss:0.06043
# [99]	validation_0-logloss:0.06057
# [0]	validation_0-logloss:0.19919
# [1]	validation_0-logloss:0.16087
# [2]	validation_0-logloss:0.13707
# [3]	validation_0-logloss:0.12075
# [4]	validation_0-logloss:0.10983
# [5]	validation_0-logloss:0.10030
# [6]	validation_0-logloss:0.09390
# [7]	validation_0-logloss:0.09031
# [8]	validation_0-logloss:0.08736
# [9]	validation_0-logloss:0.08552
# [10]	validation_0-logloss:0.08127
# [11]	validation_0-logloss:0.08088
# [12]	validation_0-logloss:0.07742
# [13]	validation_0-logloss:0.07780
# [14]	validation_0-logloss:0.07544
# [15]	validation_0-logloss:0.07467
# [16]	validation_0-logloss:0.07636
# [17]	validation_0-logloss:0.07500
# [18]	validation_0-logloss:0.07378
# [19]	validation_0-logloss:0.07435
# [20]	validation_0-logloss:0.07306
# [21]	validation_0-logloss:0.07354
# [22]	validation_0-logloss:0.07362
# [23]	validation_0-logloss:0.07288
# [24]	validation_0-logloss:0.07292
# [25]	validation_0-logloss:0.07307
# [26]	validation_0-logloss:0.07235
# [27]	validation_0-logloss:0.07222
# [28]	validation_0-logloss:0.07227
# [29]	validation_0-logloss:0.07156
# [30]	validation_0-logloss:0.07136
# [31]	validation_0-logloss:0.07145
# [32]	validation_0-logloss:0.07218
# [33]	validation_0-logloss:0.07319
# [34]	validation_0-logloss:0.07293
# [35]	validation_0-logloss:0.07329
# [36]	validation_0-logloss:0.07296
# [37]	validation_0-logloss:0.07308
# [38]	validation_0-logloss:0.07284
# [39]	validation_0-logloss:0.07502
# [40]	validation_0-logloss:0.07488
# [41]	validation_0-logloss:0.07514
# [42]	validation_0-logloss:0.07498
# [43]	validation_0-logloss:0.07557
# [44]	validation_0-logloss:0.07541
# [45]	validation_0-logloss:0.07472
# [46]	validation_0-logloss:0.07512
# [47]	validation_0-logloss:0.07520
# [48]	validation_0-logloss:0.07587
# [49]	validation_0-logloss:0.07622
# [50]	validation_0-logloss:0.07724
# [51]	validation_0-logloss:0.07703
# [52]	validation_0-logloss:0.07750
# [53]	validation_0-logloss:0.07773
# [54]	validation_0-logloss:0.07804
# [55]	validation_0-logloss:0.07787
# [56]	validation_0-logloss:0.07867
# [57]	validation_0-logloss:0.07855
# [58]	validation_0-logloss:0.07865
# [59]	validation_0-logloss:0.07777
# [60]	validation_0-logloss:0.07772
# [61]	validation_0-logloss:0.07861
# [62]	validation_0-logloss:0.07916
# [63]	validation_0-logloss:0.07920
# [64]	validation_0-logloss:0.07921
# [65]	validation_0-logloss:0.07978
# [66]	validation_0-logloss:0.07951
# [67]	validation_0-logloss:0.08013
# [68]	validation_0-logloss:0.07991
# [69]	validation_0-logloss:0.07973
# [70]	validation_0-logloss:0.08000
# [71]	validation_0-logloss:0.08026
# [72]	validation_0-logloss:0.08094
# [73]	validation_0-logloss:0.08116
# [74]	validation_0-logloss:0.08139
# [75]	validation_0-logloss:0.08177
# [76]	validation_0-logloss:0.08172
# [77]	validation_0-logloss:0.08246
# [78]	validation_0-logloss:0.08350
# [79]	validation_0-logloss:0.08352
# [80]	validation_0-logloss:0.08398
# [81]	validation_0-logloss:0.08402
# [82]	validation_0-logloss:0.08393
# [83]	validation_0-logloss:0.08427
# [84]	validation_0-logloss:0.08489
# [85]	validation_0-logloss:0.08470
# [86]	validation_0-logloss:0.08510
# [87]	validation_0-logloss:0.08536
# [88]	validation_0-logloss:0.08542
# [89]	validation_0-logloss:0.08492
# [90]	validation_0-logloss:0.08462
# [91]	validation_0-logloss:0.08538
# [92]	validation_0-logloss:0.08581
# [93]	validation_0-logloss:0.08549
# [94]	validation_0-logloss:0.08570
# [95]	validation_0-logloss:0.08559
# [96]	validation_0-logloss:0.08617
# [97]	validation_0-logloss:0.08560
# [98]	validation_0-logloss:0.08669
# [99]	validation_0-logloss:0.08707
# [0]	validation_0-logloss:0.17854
# [1]	validation_0-logloss:0.14065
# [2]	validation_0-logloss:0.11456
# [3]	validation_0-logloss:0.09670
# [4]	validation_0-logloss:0.08539
# [5]	validation_0-logloss:0.07634
# [6]	validation_0-logloss:0.07030
# [7]	validation_0-logloss:0.06546
# [8]	validation_0-logloss:0.06268
# [9]	validation_0-logloss:0.06029
# [10]	validation_0-logloss:0.05878
# [11]	validation_0-logloss:0.05626
# [12]	validation_0-logloss:0.05417
# [13]	validation_0-logloss:0.05258
# [14]	validation_0-logloss:0.05213
# [15]	validation_0-logloss:0.05183
# [16]	validation_0-logloss:0.05211
# [17]	validation_0-logloss:0.05178
# [18]	validation_0-logloss:0.05167
# [19]	validation_0-logloss:0.05098
# [20]	validation_0-logloss:0.05023
# [21]	validation_0-logloss:0.05029
# [22]	validation_0-logloss:0.04994
# [23]	validation_0-logloss:0.04992
# [24]	validation_0-logloss:0.05087
# [25]	validation_0-logloss:0.05053
# [26]	validation_0-logloss:0.05016
# [27]	validation_0-logloss:0.04974
# [28]	validation_0-logloss:0.05083
# [29]	validation_0-logloss:0.05103
# [30]	validation_0-logloss:0.05015
# [31]	validation_0-logloss:0.05014
# [32]	validation_0-logloss:0.04919
# [33]	validation_0-logloss:0.04904
# [34]	validation_0-logloss:0.04955
# [35]	validation_0-logloss:0.04929
# [36]	validation_0-logloss:0.04859
# [37]	validation_0-logloss:0.04956
# [38]	validation_0-logloss:0.04982
# [39]	validation_0-logloss:0.04969
# [40]	validation_0-logloss:0.04989
# [41]	validation_0-logloss:0.05052
# [42]	validation_0-logloss:0.05052
# [43]	validation_0-logloss:0.05027
# [44]	validation_0-logloss:0.05071
# [45]	validation_0-logloss:0.05036
# [46]	validation_0-logloss:0.05068
# [47]	validation_0-logloss:0.05050
# [48]	validation_0-logloss:0.05092
# [49]	validation_0-logloss:0.05127
# [50]	validation_0-logloss:0.05125
# [51]	validation_0-logloss:0.05081
# [52]	validation_0-logloss:0.05049
# [53]	validation_0-logloss:0.05047
# [54]	validation_0-logloss:0.05047
# [55]	validation_0-logloss:0.05154
# [56]	validation_0-logloss:0.05175
# [57]	validation_0-logloss:0.05096
# [58]	validation_0-logloss:0.05087
# [59]	validation_0-logloss:0.05078
# [60]	validation_0-logloss:0.05112
# [61]	validation_0-logloss:0.05110
# [62]	validation_0-logloss:0.05077
# [63]	validation_0-logloss:0.05104
# [64]	validation_0-logloss:0.05062
# [65]	validation_0-logloss:0.05122
# [66]	validation_0-logloss:0.05130
# [67]	validation_0-logloss:0.05160
# [68]	validation_0-logloss:0.05185
# [69]	validation_0-logloss:0.05206
# [70]	validation_0-logloss:0.05196
# [71]	validation_0-logloss:0.05188
# [72]	validation_0-logloss:0.05163
# [73]	validation_0-logloss:0.05132
# [74]	validation_0-logloss:0.05171
# [75]	validation_0-logloss:0.05202
# [76]	validation_0-logloss:0.05214
# [77]	validation_0-logloss:0.05203
# [78]	validation_0-logloss:0.05205
# [79]	validation_0-logloss:0.05188
# [80]	validation_0-logloss:0.05184
# [81]	validation_0-logloss:0.05190
# [82]	validation_0-logloss:0.05190
# [83]	validation_0-logloss:0.05218
# [84]	validation_0-logloss:0.05185
# [85]	validation_0-logloss:0.05157
# [86]	validation_0-logloss:0.05165
# [87]	validation_0-logloss:0.05270
# [88]	validation_0-logloss:0.05255
# [89]	validation_0-logloss:0.05273
# [90]	validation_0-logloss:0.05256
# [91]	validation_0-logloss:0.05257
# [92]	validation_0-logloss:0.05307
# [93]	validation_0-logloss:0.05296
# [94]	validation_0-logloss:0.05278
# [95]	validation_0-logloss:0.05252
# [96]	validation_0-logloss:0.05265
# [97]	validation_0-logloss:0.05234
# [98]	validation_0-logloss:0.05203
# [99]	validation_0-logloss:0.05183
# [0]	validation_0-logloss:0.18155
# [1]	validation_0-logloss:0.14312
# [2]	validation_0-logloss:0.11812
# [3]	validation_0-logloss:0.10131
# [4]	validation_0-logloss:0.08937
# [5]	validation_0-logloss:0.08052
# [6]	validation_0-logloss:0.07436
# [7]	validation_0-logloss:0.06966
# [8]	validation_0-logloss:0.06664
# [9]	validation_0-logloss:0.06368
# [10]	validation_0-logloss:0.06147
# [11]	validation_0-logloss:0.06071
# [12]	validation_0-logloss:0.05909
# [13]	validation_0-logloss:0.05720
# [14]	validation_0-logloss:0.05658
# [15]	validation_0-logloss:0.05500
# [16]	validation_0-logloss:0.05380
# [17]	validation_0-logloss:0.05339
# [18]	validation_0-logloss:0.05347
# [19]	validation_0-logloss:0.05151
# [20]	validation_0-logloss:0.05002
# [21]	validation_0-logloss:0.04902
# [22]	validation_0-logloss:0.04878
# [23]	validation_0-logloss:0.04831
# [24]	validation_0-logloss:0.04739
# [25]	validation_0-logloss:0.04759
# [26]	validation_0-logloss:0.04779
# [27]	validation_0-logloss:0.04783
# [28]	validation_0-logloss:0.04740
# [29]	validation_0-logloss:0.04750
# [30]	validation_0-logloss:0.04730
# [31]	validation_0-logloss:0.04747
# [32]	validation_0-logloss:0.04769
# [33]	validation_0-logloss:0.04786
# [34]	validation_0-logloss:0.04739
# [35]	validation_0-logloss:0.04753
# [36]	validation_0-logloss:0.04794
# [37]	validation_0-logloss:0.04892
# [38]	validation_0-logloss:0.04902
# [39]	validation_0-logloss:0.04855
# [40]	validation_0-logloss:0.04878
# [41]	validation_0-logloss:0.04946
# [42]	validation_0-logloss:0.04973
# [43]	validation_0-logloss:0.05044
# [44]	validation_0-logloss:0.05067
# [45]	validation_0-logloss:0.05042
# [46]	validation_0-logloss:0.05026
# [47]	validation_0-logloss:0.05025
# [48]	validation_0-logloss:0.04994
# [49]	validation_0-logloss:0.04994
# [50]	validation_0-logloss:0.04967
# [51]	validation_0-logloss:0.04946
# [52]	validation_0-logloss:0.04975
# [53]	validation_0-logloss:0.05018
# [54]	validation_0-logloss:0.05067
# [55]	validation_0-logloss:0.05040
# [56]	validation_0-logloss:0.05096
# [57]	validation_0-logloss:0.05088
# [58]	validation_0-logloss:0.05126
# [59]	validation_0-logloss:0.05192
# [60]	validation_0-logloss:0.05192
# [61]	validation_0-logloss:0.05189
# [62]	validation_0-logloss:0.05262
# [63]	validation_0-logloss:0.05279
# [64]	validation_0-logloss:0.05270
# [65]	validation_0-logloss:0.05305
# [66]	validation_0-logloss:0.05368
# [67]	validation_0-logloss:0.05371
# [68]	validation_0-logloss:0.05374
# [69]	validation_0-logloss:0.05378
# [70]	validation_0-logloss:0.05381
# [71]	validation_0-logloss:0.05369
# [72]	validation_0-logloss:0.05402
# [73]	validation_0-logloss:0.05437
# [74]	validation_0-logloss:0.05493
# [75]	validation_0-logloss:0.05500
# [76]	validation_0-logloss:0.05547
# [77]	validation_0-logloss:0.05550
# [78]	validation_0-logloss:0.05564
# [79]	validation_0-logloss:0.05600
# [80]	validation_0-logloss:0.05610
# [81]	validation_0-logloss:0.05624
# [82]	validation_0-logloss:0.05612
# [83]	validation_0-logloss:0.05675
# [84]	validation_0-logloss:0.05631
# [85]	validation_0-logloss:0.05608
# [86]	validation_0-logloss:0.05666
# [87]	validation_0-logloss:0.05687
# [88]	validation_0-logloss:0.05680
# [89]	validation_0-logloss:0.05712
# [90]	validation_0-logloss:0.05740
# [91]	validation_0-logloss:0.05766
# [92]	validation_0-logloss:0.05771
# [93]	validation_0-logloss:0.05844
# [94]	validation_0-logloss:0.05823
# [95]	validation_0-logloss:0.05855
# [96]	validation_0-logloss:0.05855
# [97]	validation_0-logloss:0.05901
# [98]	validation_0-logloss:0.05936
# [99]	validation_0-logloss:0.05928
# [0]	validation_0-logloss:0.19493
# [1]	validation_0-logloss:0.15131
# [2]	validation_0-logloss:0.12191
# [3]	validation_0-logloss:0.10366
# [4]	validation_0-logloss:0.09030
# [5]	validation_0-logloss:0.08071
# [6]	validation_0-logloss:0.07355
# [7]	validation_0-logloss:0.07020
# [8]	validation_0-logloss:0.06704
# [9]	validation_0-logloss:0.06419
# [10]	validation_0-logloss:0.06021
# [11]	validation_0-logloss:0.05925
# [12]	validation_0-logloss:0.05844
# [13]	validation_0-logloss:0.05796
# [14]	validation_0-logloss:0.05735
# [15]	validation_0-logloss:0.05700
# [16]	validation_0-logloss:0.05806
# [17]	validation_0-logloss:0.05596
# [18]	validation_0-logloss:0.05572
# [19]	validation_0-logloss:0.05441
# [20]	validation_0-logloss:0.05406
# [21]	validation_0-logloss:0.05404
# [22]	validation_0-logloss:0.05383
# [23]	validation_0-logloss:0.05423
# [24]	validation_0-logloss:0.05422
# [25]	validation_0-logloss:0.05493
# [26]	validation_0-logloss:0.05504
# [27]	validation_0-logloss:0.05445
# [28]	validation_0-logloss:0.05537
# [29]	validation_0-logloss:0.05539
# [30]	validation_0-logloss:0.05636
# [31]	validation_0-logloss:0.05574
# [32]	validation_0-logloss:0.05508
# [33]	validation_0-logloss:0.05536
# [34]	validation_0-logloss:0.05592
# [35]	validation_0-logloss:0.05677
# [36]	validation_0-logloss:0.05727
# [37]	validation_0-logloss:0.05783
# [38]	validation_0-logloss:0.05758
# [39]	validation_0-logloss:0.05817
# [40]	validation_0-logloss:0.05843
# [41]	validation_0-logloss:0.05886
# [42]	validation_0-logloss:0.05927
# [43]	validation_0-logloss:0.05952
# [44]	validation_0-logloss:0.05940
# [45]	validation_0-logloss:0.05949
# [46]	validation_0-logloss:0.05894
# [47]	validation_0-logloss:0.05955
# [48]	validation_0-logloss:0.05968
# [49]	validation_0-logloss:0.05994
# [50]	validation_0-logloss:0.05925
# [51]	validation_0-logloss:0.05949
# [52]	validation_0-logloss:0.06028
# [53]	validation_0-logloss:0.06074
# [54]	validation_0-logloss:0.06083
# [55]	validation_0-logloss:0.06093
# [56]	validation_0-logloss:0.06100
# [57]	validation_0-logloss:0.06107
# [58]	validation_0-logloss:0.06172
# [59]	validation_0-logloss:0.06242
# [60]	validation_0-logloss:0.06295
# [61]	validation_0-logloss:0.06243
# [62]	validation_0-logloss:0.06272
# [63]	validation_0-logloss:0.06288
# [64]	validation_0-logloss:0.06300
# [65]	validation_0-logloss:0.06293
# [66]	validation_0-logloss:0.06324
# [67]	validation_0-logloss:0.06287
# [68]	validation_0-logloss:0.06269
# [69]	validation_0-logloss:0.06289
# [70]	validation_0-logloss:0.06349
# [71]	validation_0-logloss:0.06345
# [72]	validation_0-logloss:0.06352
# [73]	validation_0-logloss:0.06416
# [74]	validation_0-logloss:0.06503
# [75]	validation_0-logloss:0.06514
# [76]	validation_0-logloss:0.06509
# [77]	validation_0-logloss:0.06567
# [78]	validation_0-logloss:0.06593
# [79]	validation_0-logloss:0.06639
# [80]	validation_0-logloss:0.06676
# [81]	validation_0-logloss:0.06632
# [82]	validation_0-logloss:0.06619
# [83]	validation_0-logloss:0.06596
# [84]	validation_0-logloss:0.06630
# [85]	validation_0-logloss:0.06663
# [86]	validation_0-logloss:0.06671
# [87]	validation_0-logloss:0.06577
# [88]	validation_0-logloss:0.06606
# [89]	validation_0-logloss:0.06619
# [90]	validation_0-logloss:0.06660
# [91]	validation_0-logloss:0.06684
# [92]	validation_0-logloss:0.06717
# [93]	validation_0-logloss:0.06770
# [94]	validation_0-logloss:0.06719
# [95]	validation_0-logloss:0.06675
# [96]	validation_0-logloss:0.06703
# [97]	validation_0-logloss:0.06756
# [98]	validation_0-logloss:0.06728
# [99]	validation_0-logloss:0.06726
# [0]	validation_0-logloss:0.18832
# [1]	validation_0-logloss:0.14833
# [2]	validation_0-logloss:0.12349
# [3]	validation_0-logloss:0.10654
# [4]	validation_0-logloss:0.09410
# [5]	validation_0-logloss:0.08545
# [6]	validation_0-logloss:0.08022
# [7]	validation_0-logloss:0.07610
# [8]	validation_0-logloss:0.07213
# [9]	validation_0-logloss:0.07065
# [10]	validation_0-logloss:0.06896
# [11]	validation_0-logloss:0.06664
# [12]	validation_0-logloss:0.06437
# [13]	validation_0-logloss:0.06613
# [14]	validation_0-logloss:0.06494
# [15]	validation_0-logloss:0.06427
# [16]	validation_0-logloss:0.06503
# [17]	validation_0-logloss:0.06464
# [18]	validation_0-logloss:0.06402
# [19]	validation_0-logloss:0.06382
# [20]	validation_0-logloss:0.06335
# [21]	validation_0-logloss:0.06318
# [22]	validation_0-logloss:0.06447
# [23]	validation_0-logloss:0.06455
# [24]	validation_0-logloss:0.06473
# [25]	validation_0-logloss:0.06557
# [26]	validation_0-logloss:0.06695
# [27]	validation_0-logloss:0.06710
# [28]	validation_0-logloss:0.06770
# [29]	validation_0-logloss:0.06827
# [30]	validation_0-logloss:0.06874
# [31]	validation_0-logloss:0.06919
# [32]	validation_0-logloss:0.06972
# [33]	validation_0-logloss:0.06993
# [34]	validation_0-logloss:0.07056
# [35]	validation_0-logloss:0.07112
# [36]	validation_0-logloss:0.07248
# [37]	validation_0-logloss:0.07218
# [38]	validation_0-logloss:0.07257
# [39]	validation_0-logloss:0.07309
# [40]	validation_0-logloss:0.07392
# [41]	validation_0-logloss:0.07476
# [42]	validation_0-logloss:0.07604
# [43]	validation_0-logloss:0.07641
# [44]	validation_0-logloss:0.07672
# [45]	validation_0-logloss:0.07679
# [46]	validation_0-logloss:0.07818
# [47]	validation_0-logloss:0.07773
# [48]	validation_0-logloss:0.07901
# [49]	validation_0-logloss:0.08080
# [50]	validation_0-logloss:0.08046
# [51]	validation_0-logloss:0.08073
# [52]	validation_0-logloss:0.08108
# [53]	validation_0-logloss:0.08159
# [54]	validation_0-logloss:0.08202
# [55]	validation_0-logloss:0.08265
# [56]	validation_0-logloss:0.08304
# [57]	validation_0-logloss:0.08279
# [58]	validation_0-logloss:0.08318
# [59]	validation_0-logloss:0.08290
# [60]	validation_0-logloss:0.08261
# [61]	validation_0-logloss:0.08330
# [62]	validation_0-logloss:0.08421
# [63]	validation_0-logloss:0.08504
# [64]	validation_0-logloss:0.08589
# [65]	validation_0-logloss:0.08653
# [66]	validation_0-logloss:0.08710
# [67]	validation_0-logloss:0.08799
# [68]	validation_0-logloss:0.08856
# [69]	validation_0-logloss:0.08885
# [70]	validation_0-logloss:0.08896
# [71]	validation_0-logloss:0.08927
# [72]	validation_0-logloss:0.08956
# [73]	validation_0-logloss:0.08996
# [74]	validation_0-logloss:0.09002
# [75]	validation_0-logloss:0.09100
# [76]	validation_0-logloss:0.09121
# [77]	validation_0-logloss:0.09258
# [78]	validation_0-logloss:0.09280
# [79]	validation_0-logloss:0.09247
# [80]	validation_0-logloss:0.09378
# [81]	validation_0-logloss:0.09420
# [82]	validation_0-logloss:0.09456
# [83]	validation_0-logloss:0.09477
# [84]	validation_0-logloss:0.09506
# [85]	validation_0-logloss:0.09528
# [86]	validation_0-logloss:0.09560
# [87]	validation_0-logloss:0.09638
# [88]	validation_0-logloss:0.09706
# [89]	validation_0-logloss:0.09703
# [90]	validation_0-logloss:0.09775
# [91]	validation_0-logloss:0.09741
# [92]	validation_0-logloss:0.09786
# [93]	validation_0-logloss:0.09803
# [94]	validation_0-logloss:0.09888
# [95]	validation_0-logloss:0.09908
# [96]	validation_0-logloss:0.09923
# [97]	validation_0-logloss:0.09983
# [98]	validation_0-logloss:0.09968
# [99]	validation_0-logloss:0.09978
# [0]	validation_0-logloss:0.19066
# [1]	validation_0-logloss:0.15419
# [2]	validation_0-logloss:0.12974
# [3]	validation_0-logloss:0.11436
# [4]	validation_0-logloss:0.10306
# [5]	validation_0-logloss:0.09514
# [6]	validation_0-logloss:0.08898
# [7]	validation_0-logloss:0.08538
# [8]	validation_0-logloss:0.08218
# [9]	validation_0-logloss:0.08118
# [10]	validation_0-logloss:0.07869
# [11]	validation_0-logloss:0.07664
# [12]	validation_0-logloss:0.07663
# [13]	validation_0-logloss:0.07678
# [14]	validation_0-logloss:0.07704
# [15]	validation_0-logloss:0.07627
# [16]	validation_0-logloss:0.07557
# [17]	validation_0-logloss:0.07549
# [18]	validation_0-logloss:0.07683
# [19]	validation_0-logloss:0.07616
# [20]	validation_0-logloss:0.07667
# [21]	validation_0-logloss:0.07679
# [22]	validation_0-logloss:0.07630
# [23]	validation_0-logloss:0.07570
# [24]	validation_0-logloss:0.07530
# [25]	validation_0-logloss:0.07498
# [26]	validation_0-logloss:0.07564
# [27]	validation_0-logloss:0.07627
# [28]	validation_0-logloss:0.07707
# [29]	validation_0-logloss:0.07785
# [30]	validation_0-logloss:0.07838
# [31]	validation_0-logloss:0.07807
# [32]	validation_0-logloss:0.07906
# [33]	validation_0-logloss:0.07950
# [34]	validation_0-logloss:0.07962
# [35]	validation_0-logloss:0.08081
# [36]	validation_0-logloss:0.08044
# [37]	validation_0-logloss:0.07982
# [38]	validation_0-logloss:0.08180
# [39]	validation_0-logloss:0.08262
# [40]	validation_0-logloss:0.08320
# [41]	validation_0-logloss:0.08366
# [42]	validation_0-logloss:0.08372
# [43]	validation_0-logloss:0.08364
# [44]	validation_0-logloss:0.08329
# [45]	validation_0-logloss:0.08279
# [46]	validation_0-logloss:0.08287
# [47]	validation_0-logloss:0.08332
# [48]	validation_0-logloss:0.08454
# [49]	validation_0-logloss:0.08532
# [50]	validation_0-logloss:0.08658
# [51]	validation_0-logloss:0.08714
# [52]	validation_0-logloss:0.08731
# [53]	validation_0-logloss:0.08719
# [54]	validation_0-logloss:0.08739
# [55]	validation_0-logloss:0.08797
# [56]	validation_0-logloss:0.08761
# [57]	validation_0-logloss:0.08776
# [58]	validation_0-logloss:0.08835
# [59]	validation_0-logloss:0.08824
# [60]	validation_0-logloss:0.08783
# [61]	validation_0-logloss:0.08859
# [62]	validation_0-logloss:0.08949
# [63]	validation_0-logloss:0.09003
# [64]	validation_0-logloss:0.09013
# [65]	validation_0-logloss:0.09072
# [66]	validation_0-logloss:0.09150
# [67]	validation_0-logloss:0.09263
# [68]	validation_0-logloss:0.09315
# [69]	validation_0-logloss:0.09331
# [70]	validation_0-logloss:0.09355
# [71]	validation_0-logloss:0.09397
# [72]	validation_0-logloss:0.09446
# [73]	validation_0-logloss:0.09521
# [74]	validation_0-logloss:0.09582
# [75]	validation_0-logloss:0.09633
# [76]	validation_0-logloss:0.09681
# [77]	validation_0-logloss:0.09699
# [78]	validation_0-logloss:0.09703
# [79]	validation_0-logloss:0.09712
# [80]	validation_0-logloss:0.09776
# [81]	validation_0-logloss:0.09863
# [82]	validation_0-logloss:0.09947
# [83]	validation_0-logloss:0.09940
# [84]	validation_0-logloss:0.09994
# [85]	validation_0-logloss:0.10040
# [86]	validation_0-logloss:0.10008
# [87]	validation_0-logloss:0.10003
# [88]	validation_0-logloss:0.10061
# [89]	validation_0-logloss:0.10126
# [90]	validation_0-logloss:0.10160
# [91]	validation_0-logloss:0.10161
# [92]	validation_0-logloss:0.10194
# [93]	validation_0-logloss:0.10265
# [94]	validation_0-logloss:0.10276
# [95]	validation_0-logloss:0.10315
# [96]	validation_0-logloss:0.10351
# [97]	validation_0-logloss:0.10304
# [98]	validation_0-logloss:0.10343
# [99]	validation_0-logloss:0.10361
# [0]	validation_0-logloss:0.18123
# [1]	validation_0-logloss:0.14563
# [2]	validation_0-logloss:0.12231
# [3]	validation_0-logloss:0.10637
# [4]	validation_0-logloss:0.09613
# [5]	validation_0-logloss:0.08830
# [6]	validation_0-logloss:0.08159
# [7]	validation_0-logloss:0.07846
# [8]	validation_0-logloss:0.07471
# [9]	validation_0-logloss:0.07372
# [10]	validation_0-logloss:0.07120
# [11]	validation_0-logloss:0.06846
# [12]	validation_0-logloss:0.06740
# [13]	validation_0-logloss:0.06688
# [14]	validation_0-logloss:0.06587
# [15]	validation_0-logloss:0.06597
# [16]	validation_0-logloss:0.06490
# [17]	validation_0-logloss:0.06441
# [18]	validation_0-logloss:0.06244
# [19]	validation_0-logloss:0.06191
# [20]	validation_0-logloss:0.06229
# [21]	validation_0-logloss:0.06217
# [22]	validation_0-logloss:0.06129
# [23]	validation_0-logloss:0.06070
# [24]	validation_0-logloss:0.05971
# [25]	validation_0-logloss:0.06016
# [26]	validation_0-logloss:0.06128
# [27]	validation_0-logloss:0.06102
# [28]	validation_0-logloss:0.06035
# [29]	validation_0-logloss:0.06035
# [30]	validation_0-logloss:0.06033
# [31]	validation_0-logloss:0.06093
# [32]	validation_0-logloss:0.06128
# [33]	validation_0-logloss:0.06110
# [34]	validation_0-logloss:0.06140
# [35]	validation_0-logloss:0.06243
# [36]	validation_0-logloss:0.06261
# [37]	validation_0-logloss:0.06332
# [38]	validation_0-logloss:0.06435
# [39]	validation_0-logloss:0.06478
# [40]	validation_0-logloss:0.06477
# [41]	validation_0-logloss:0.06504
# [42]	validation_0-logloss:0.06449
# [43]	validation_0-logloss:0.06541
# [44]	validation_0-logloss:0.06586
# [45]	validation_0-logloss:0.06596
# [46]	validation_0-logloss:0.06729
# [47]	validation_0-logloss:0.06796
# [48]	validation_0-logloss:0.06890
# [49]	validation_0-logloss:0.06934
# [50]	validation_0-logloss:0.06959
# [51]	validation_0-logloss:0.06974
# [52]	validation_0-logloss:0.06998
# [53]	validation_0-logloss:0.07064
# [54]	validation_0-logloss:0.07123
# [55]	validation_0-logloss:0.07221
# [56]	validation_0-logloss:0.07216
# [57]	validation_0-logloss:0.07183
# [58]	validation_0-logloss:0.07209
# [59]	validation_0-logloss:0.07172
# [60]	validation_0-logloss:0.07128
# [61]	validation_0-logloss:0.07169
# [62]	validation_0-logloss:0.07200
# [63]	validation_0-logloss:0.07132
# [64]	validation_0-logloss:0.07190
# [65]	validation_0-logloss:0.07247
# [66]	validation_0-logloss:0.07353
# [67]	validation_0-logloss:0.07349
# [68]	validation_0-logloss:0.07439
# [69]	validation_0-logloss:0.07394
# [70]	validation_0-logloss:0.07407
# [71]	validation_0-logloss:0.07398
# [72]	validation_0-logloss:0.07455
# [73]	validation_0-logloss:0.07462
# [74]	validation_0-logloss:0.07538
# [75]	validation_0-logloss:0.07526
# [76]	validation_0-logloss:0.07566
# [77]	validation_0-logloss:0.07645
# [78]	validation_0-logloss:0.07664
# [79]	validation_0-logloss:0.07705
# [80]	validation_0-logloss:0.07802
# [81]	validation_0-logloss:0.07804
# [82]	validation_0-logloss:0.07836
# [83]	validation_0-logloss:0.07806
# [84]	validation_0-logloss:0.07805
# [85]	validation_0-logloss:0.07816
# [86]	validation_0-logloss:0.07862
# [87]	validation_0-logloss:0.07830
# [88]	validation_0-logloss:0.07893
# [89]	validation_0-logloss:0.07911
# [90]	validation_0-logloss:0.07969
# [91]	validation_0-logloss:0.07957
# [92]	validation_0-logloss:0.07928
# [93]	validation_0-logloss:0.07906
# [94]	validation_0-logloss:0.07905
# [95]	validation_0-logloss:0.07937
# [96]	validation_0-logloss:0.07966
# [97]	validation_0-logloss:0.07994
# [98]	validation_0-logloss:0.07992
# [99]	validation_0-logloss:0.08062
# [0]	validation_0-logloss:0.18162
# [1]	validation_0-logloss:0.14586
# [2]	validation_0-logloss:0.12076
# [3]	validation_0-logloss:0.10359
# [4]	validation_0-logloss:0.09119
# [5]	validation_0-logloss:0.08336
# [6]	validation_0-logloss:0.07798
# [7]	validation_0-logloss:0.07436
# [8]	validation_0-logloss:0.07114
# [9]	validation_0-logloss:0.07044
# [10]	validation_0-logloss:0.07054
# [11]	validation_0-logloss:0.06920
# [12]	validation_0-logloss:0.06816
# [13]	validation_0-logloss:0.06768
# [14]	validation_0-logloss:0.06695
# [15]	validation_0-logloss:0.06586
# [16]	validation_0-logloss:0.06453
# [17]	validation_0-logloss:0.06555
# [18]	validation_0-logloss:0.06665
# [19]	validation_0-logloss:0.06651
# [20]	validation_0-logloss:0.06722
# [21]	validation_0-logloss:0.06792
# [22]	validation_0-logloss:0.06751
# [23]	validation_0-logloss:0.06687
# [24]	validation_0-logloss:0.06763
# [25]	validation_0-logloss:0.06748
# [26]	validation_0-logloss:0.06776
# [27]	validation_0-logloss:0.06810
# [28]	validation_0-logloss:0.06937
# [29]	validation_0-logloss:0.07049
# [30]	validation_0-logloss:0.07158
# [31]	validation_0-logloss:0.07182
# [32]	validation_0-logloss:0.07272
# [33]	validation_0-logloss:0.07227
# [34]	validation_0-logloss:0.07317
# [35]	validation_0-logloss:0.07382
# [36]	validation_0-logloss:0.07456
# [37]	validation_0-logloss:0.07461
# [38]	validation_0-logloss:0.07569
# [39]	validation_0-logloss:0.07615
# [40]	validation_0-logloss:0.07658
# [41]	validation_0-logloss:0.07646
# [42]	validation_0-logloss:0.07809
# [43]	validation_0-logloss:0.07836
# [44]	validation_0-logloss:0.07829
# [45]	validation_0-logloss:0.07959
# [46]	validation_0-logloss:0.08037
# [47]	validation_0-logloss:0.08118
# [48]	validation_0-logloss:0.08142
# [49]	validation_0-logloss:0.08232
# [50]	validation_0-logloss:0.08213
# [51]	validation_0-logloss:0.08247
# [52]	validation_0-logloss:0.08302
# [53]	validation_0-logloss:0.08292
# [54]	validation_0-logloss:0.08298
# [55]	validation_0-logloss:0.08415
# [56]	validation_0-logloss:0.08458
# [57]	validation_0-logloss:0.08495
# [58]	validation_0-logloss:0.08548
# [59]	validation_0-logloss:0.08561
# [60]	validation_0-logloss:0.08619
# [61]	validation_0-logloss:0.08633
# [62]	validation_0-logloss:0.08643
# [63]	validation_0-logloss:0.08655
# [64]	validation_0-logloss:0.08659
# [65]	validation_0-logloss:0.08676
# [66]	validation_0-logloss:0.08722
# [67]	validation_0-logloss:0.08732
# [68]	validation_0-logloss:0.08745
# [69]	validation_0-logloss:0.08761
# [70]	validation_0-logloss:0.08743
# [71]	validation_0-logloss:0.08829
# [72]	validation_0-logloss:0.08817
# [73]	validation_0-logloss:0.08884
# [74]	validation_0-logloss:0.08913
# [75]	validation_0-logloss:0.08907
# [76]	validation_0-logloss:0.08982
# [77]	validation_0-logloss:0.09045
# [78]	validation_0-logloss:0.09103
# [79]	validation_0-logloss:0.09168
# [80]	validation_0-logloss:0.09253
# [81]	validation_0-logloss:0.09217
# [82]	validation_0-logloss:0.09232
# [83]	validation_0-logloss:0.09267
# [84]	validation_0-logloss:0.09378
# [85]	validation_0-logloss:0.09393
# [86]	validation_0-logloss:0.09444
# [87]	validation_0-logloss:0.09490
# [88]	validation_0-logloss:0.09496
# [89]	validation_0-logloss:0.09548
# [90]	validation_0-logloss:0.09554
# [91]	validation_0-logloss:0.09601
# [92]	validation_0-logloss:0.09565
# [93]	validation_0-logloss:0.09612
# [94]	validation_0-logloss:0.09620
# [95]	validation_0-logloss:0.09611
# [96]	validation_0-logloss:0.09618
# [97]	validation_0-logloss:0.09651
# [98]	validation_0-logloss:0.09691
# [99]	validation_0-logloss:0.09694
# [0]	validation_0-logloss:0.19194
# [1]	validation_0-logloss:0.15123
# [2]	validation_0-logloss:0.12472
# [3]	validation_0-logloss:0.10581
# [4]	validation_0-logloss:0.09117
# [5]	validation_0-logloss:0.08236
# [6]	validation_0-logloss:0.07589
# [7]	validation_0-logloss:0.07102
# [8]	validation_0-logloss:0.06765
# [9]	validation_0-logloss:0.06388
# [10]	validation_0-logloss:0.06149
# [11]	validation_0-logloss:0.05844
# [12]	validation_0-logloss:0.05707
# [13]	validation_0-logloss:0.05486
# [14]	validation_0-logloss:0.05365
# [15]	validation_0-logloss:0.05215
# [16]	validation_0-logloss:0.05127
# [17]	validation_0-logloss:0.05110
# [18]	validation_0-logloss:0.05057
# [19]	validation_0-logloss:0.05059
# [20]	validation_0-logloss:0.05091
# [21]	validation_0-logloss:0.05027
# [22]	validation_0-logloss:0.05029
# [23]	validation_0-logloss:0.05020
# [24]	validation_0-logloss:0.05048
# [25]	validation_0-logloss:0.05030
# [26]	validation_0-logloss:0.05016
# [27]	validation_0-logloss:0.04967
# [28]	validation_0-logloss:0.04876
# [29]	validation_0-logloss:0.04811
# [30]	validation_0-logloss:0.04814
# [31]	validation_0-logloss:0.04819
# [32]	validation_0-logloss:0.04805
# [33]	validation_0-logloss:0.04819
# [34]	validation_0-logloss:0.04857
# [35]	validation_0-logloss:0.04822
# [36]	validation_0-logloss:0.04828
# [37]	validation_0-logloss:0.04853
# [38]	validation_0-logloss:0.04821
# [39]	validation_0-logloss:0.04817
# [40]	validation_0-logloss:0.04822
# [41]	validation_0-logloss:0.04795
# [42]	validation_0-logloss:0.04784
# [43]	validation_0-logloss:0.04743
# [44]	validation_0-logloss:0.04737
# [45]	validation_0-logloss:0.04745
# [46]	validation_0-logloss:0.04731
# [47]	validation_0-logloss:0.04779
# [48]	validation_0-logloss:0.04789
# [49]	validation_0-logloss:0.04816
# [50]	validation_0-logloss:0.04825
# [51]	validation_0-logloss:0.04837
# [52]	validation_0-logloss:0.04821
# [53]	validation_0-logloss:0.04836
# [54]	validation_0-logloss:0.04887
# [55]	validation_0-logloss:0.04924
# [56]	validation_0-logloss:0.04956
# [57]	validation_0-logloss:0.05001
# [58]	validation_0-logloss:0.05012
# [59]	validation_0-logloss:0.05061
# [60]	validation_0-logloss:0.05017
# [61]	validation_0-logloss:0.05001
# [62]	validation_0-logloss:0.05011
# [63]	validation_0-logloss:0.05019
# [64]	validation_0-logloss:0.05039
# [65]	validation_0-logloss:0.05033
# [66]	validation_0-logloss:0.05076
# [67]	validation_0-logloss:0.05133
# [68]	validation_0-logloss:0.05125
# [69]	validation_0-logloss:0.05168
# [70]	validation_0-logloss:0.05174
# [71]	validation_0-logloss:0.05170
# [72]	validation_0-logloss:0.05180
# [73]	validation_0-logloss:0.05200
# [74]	validation_0-logloss:0.05210
# [75]	validation_0-logloss:0.05223
# [76]	validation_0-logloss:0.05243
# [77]	validation_0-logloss:0.05204
# [78]	validation_0-logloss:0.05179
# [79]	validation_0-logloss:0.05193
# [80]	validation_0-logloss:0.05180
# [81]	validation_0-logloss:0.05186
# [82]	validation_0-logloss:0.05250
# [83]	validation_0-logloss:0.05288
# [84]	validation_0-logloss:0.05272
# [85]	validation_0-logloss:0.05319
# [86]	validation_0-logloss:0.05335
# [87]	validation_0-logloss:0.05375
# [88]	validation_0-logloss:0.05354
# [89]	validation_0-logloss:0.05378
# [90]	validation_0-logloss:0.05378
# [91]	validation_0-logloss:0.05420
# [92]	validation_0-logloss:0.05430
# [93]	validation_0-logloss:0.05464
# [94]	validation_0-logloss:0.05472
# [95]	validation_0-logloss:0.05500
# [96]	validation_0-logloss:0.05460
# [97]	validation_0-logloss:0.05438
# [98]	validation_0-logloss:0.05489
# [99]	validation_0-logloss:0.05491
# [0]	validation_0-logloss:0.18090
# [1]	validation_0-logloss:0.14518
# [2]	validation_0-logloss:0.12146
# [3]	validation_0-logloss:0.10371
# [4]	validation_0-logloss:0.09256
# [5]	validation_0-logloss:0.08276
# [6]	validation_0-logloss:0.07666
# [7]	validation_0-logloss:0.07244
# [8]	validation_0-logloss:0.06948
# [9]	validation_0-logloss:0.06639
# [10]	validation_0-logloss:0.06384
# [11]	validation_0-logloss:0.06274
# [12]	validation_0-logloss:0.06158
# [13]	validation_0-logloss:0.06119
# [14]	validation_0-logloss:0.06184
# [15]	validation_0-logloss:0.06200
# [16]	validation_0-logloss:0.06327
# [17]	validation_0-logloss:0.06284
# [18]	validation_0-logloss:0.06323
# [19]	validation_0-logloss:0.06289
# [20]	validation_0-logloss:0.06239
# [21]	validation_0-logloss:0.06213
# [22]	validation_0-logloss:0.06186
# [23]	validation_0-logloss:0.06209
# [24]	validation_0-logloss:0.06310
# [25]	validation_0-logloss:0.06450
# [26]	validation_0-logloss:0.06457
# [27]	validation_0-logloss:0.06516
# [28]	validation_0-logloss:0.06550
# [29]	validation_0-logloss:0.06584
# [30]	validation_0-logloss:0.06593
# [31]	validation_0-logloss:0.06636
# [32]	validation_0-logloss:0.06688
# [33]	validation_0-logloss:0.06694
# [34]	validation_0-logloss:0.06724
# [35]	validation_0-logloss:0.06690
# [36]	validation_0-logloss:0.06814
# [37]	validation_0-logloss:0.06858
# [38]	validation_0-logloss:0.06884
# [39]	validation_0-logloss:0.06996
# [40]	validation_0-logloss:0.07039
# [41]	validation_0-logloss:0.07071
# [42]	validation_0-logloss:0.07076
# [43]	validation_0-logloss:0.07104
# [44]	validation_0-logloss:0.07140
# [45]	validation_0-logloss:0.07170
# [46]	validation_0-logloss:0.07171
# [47]	validation_0-logloss:0.07242
# [48]	validation_0-logloss:0.07313
# [49]	validation_0-logloss:0.07333
# [50]	validation_0-logloss:0.07384
# [51]	validation_0-logloss:0.07367
# [52]	validation_0-logloss:0.07392
# [53]	validation_0-logloss:0.07467
# [54]	validation_0-logloss:0.07531
# [55]	validation_0-logloss:0.07579
# [56]	validation_0-logloss:0.07600
# [57]	validation_0-logloss:0.07675
# [58]	validation_0-logloss:0.07696
# [59]	validation_0-logloss:0.07717
# [60]	validation_0-logloss:0.07723
# [61]	validation_0-logloss:0.07819
# [62]	validation_0-logloss:0.07819
# [63]	validation_0-logloss:0.07796
# [64]	validation_0-logloss:0.07932
# [65]	validation_0-logloss:0.07971
# [66]	validation_0-logloss:0.07992
# [67]	validation_0-logloss:0.08032
# [68]	validation_0-logloss:0.08090
# [69]	validation_0-logloss:0.08092
# [70]	validation_0-logloss:0.08123
# [71]	validation_0-logloss:0.08148
# [72]	validation_0-logloss:0.08176
# [73]	validation_0-logloss:0.08159
# [74]	validation_0-logloss:0.08143
# [75]	validation_0-logloss:0.08114
# [76]	validation_0-logloss:0.08115
# [77]	validation_0-logloss:0.08116
# [78]	validation_0-logloss:0.08145
# [79]	validation_0-logloss:0.08178
# [80]	validation_0-logloss:0.08172
# [81]	validation_0-logloss:0.08191
# [82]	validation_0-logloss:0.08258
# [83]	validation_0-logloss:0.08279
# [84]	validation_0-logloss:0.08344
# [85]	validation_0-logloss:0.08372
# [86]	validation_0-logloss:0.08481
# [87]	validation_0-logloss:0.08427
# [88]	validation_0-logloss:0.08435
# [89]	validation_0-logloss:0.08461
# [90]	validation_0-logloss:0.08464
# [91]	validation_0-logloss:0.08499
# [92]	validation_0-logloss:0.08460
# [93]	validation_0-logloss:0.08480
# [94]	validation_0-logloss:0.08512
# [95]	validation_0-logloss:0.08574
# [96]	validation_0-logloss:0.08653
# [97]	validation_0-logloss:0.08730
# [98]	validation_0-logloss:0.08716
# [99]	validation_0-logloss:0.08769
# [0]	validation_0-logloss:0.17330
# [1]	validation_0-logloss:0.13255
# [2]	validation_0-logloss:0.10600
# [3]	validation_0-logloss:0.08669
# [4]	validation_0-logloss:0.07381
# [5]	validation_0-logloss:0.06419
# [6]	validation_0-logloss:0.05717
# [7]	validation_0-logloss:0.05260
# [8]	validation_0-logloss:0.04822
# [9]	validation_0-logloss:0.04469
# [10]	validation_0-logloss:0.04251
# [11]	validation_0-logloss:0.04064
# [12]	validation_0-logloss:0.03938
# [13]	validation_0-logloss:0.03841
# [14]	validation_0-logloss:0.03791
# [15]	validation_0-logloss:0.03709
# [16]	validation_0-logloss:0.03625
# [17]	validation_0-logloss:0.03583
# [18]	validation_0-logloss:0.03611
# [19]	validation_0-logloss:0.03595
# [20]	validation_0-logloss:0.03587
# [21]	validation_0-logloss:0.03562
# [22]	validation_0-logloss:0.03566
# [23]	validation_0-logloss:0.03461
# [24]	validation_0-logloss:0.03444
# [25]	validation_0-logloss:0.03401
# [26]	validation_0-logloss:0.03449
# [27]	validation_0-logloss:0.03465
# [28]	validation_0-logloss:0.03524
# [29]	validation_0-logloss:0.03566
# [30]	validation_0-logloss:0.03607
# [31]	validation_0-logloss:0.03557
# [32]	validation_0-logloss:0.03613
# [33]	validation_0-logloss:0.03583
# [34]	validation_0-logloss:0.03642
# [35]	validation_0-logloss:0.03607
# [36]	validation_0-logloss:0.03650
# [37]	validation_0-logloss:0.03680
# [38]	validation_0-logloss:0.03714
# [39]	validation_0-logloss:0.03702
# [40]	validation_0-logloss:0.03692
# [41]	validation_0-logloss:0.03687
# [42]	validation_0-logloss:0.03735
# [43]	validation_0-logloss:0.03808
# [44]	validation_0-logloss:0.03737
# [45]	validation_0-logloss:0.03776
# [46]	validation_0-logloss:0.03786
# [47]	validation_0-logloss:0.03773
# [48]	validation_0-logloss:0.03790
# [49]	validation_0-logloss:0.03764
# [50]	validation_0-logloss:0.03764
# [51]	validation_0-logloss:0.03803
# [52]	validation_0-logloss:0.03839
# [53]	validation_0-logloss:0.03827
# [54]	validation_0-logloss:0.03850
# [55]	validation_0-logloss:0.03814
# [56]	validation_0-logloss:0.03823
# [57]	validation_0-logloss:0.03843
# [58]	validation_0-logloss:0.03857
# [59]	validation_0-logloss:0.03858
# [60]	validation_0-logloss:0.03870
# [61]	validation_0-logloss:0.03823
# [62]	validation_0-logloss:0.03810
# [63]	validation_0-logloss:0.03834
# [64]	validation_0-logloss:0.03815
# [65]	validation_0-logloss:0.03790
# [66]	validation_0-logloss:0.03810
# [67]	validation_0-logloss:0.03796
# [68]	validation_0-logloss:0.03765
# [69]	validation_0-logloss:0.03770
# [70]	validation_0-logloss:0.03794
# [71]	validation_0-logloss:0.03780
# [72]	validation_0-logloss:0.03800
# [73]	validation_0-logloss:0.03850
# [74]	validation_0-logloss:0.03873
# [75]	validation_0-logloss:0.03915
# [76]	validation_0-logloss:0.03924
# [77]	validation_0-logloss:0.03921
# [78]	validation_0-logloss:0.03904
# [79]	validation_0-logloss:0.03943
# [80]	validation_0-logloss:0.03963
# [81]	validation_0-logloss:0.03962
# [82]	validation_0-logloss:0.03967
# [83]	validation_0-logloss:0.03964
# [84]	validation_0-logloss:0.03944
# [85]	validation_0-logloss:0.03976
# [86]	validation_0-logloss:0.03952
# [87]	validation_0-logloss:0.03890
# [88]	validation_0-logloss:0.03901
# [89]	validation_0-logloss:0.03910
# [90]	validation_0-logloss:0.03958
# [91]	validation_0-logloss:0.03965
# [92]	validation_0-logloss:0.03993
# [93]	validation_0-logloss:0.03992
# [94]	validation_0-logloss:0.03984
# [95]	validation_0-logloss:0.03985
# [96]	validation_0-logloss:0.03993
# [97]	validation_0-logloss:0.04050
# [98]	validation_0-logloss:0.04033
# [99]	validation_0-logloss:0.04044
# [0]	validation_0-logloss:0.17176
# [1]	validation_0-logloss:0.13316
# [2]	validation_0-logloss:0.10777
# [3]	validation_0-logloss:0.08933
# [4]	validation_0-logloss:0.07678
# [5]	validation_0-logloss:0.06807
# [6]	validation_0-logloss:0.06253
# [7]	validation_0-logloss:0.05816
# [8]	validation_0-logloss:0.05423
# [9]	validation_0-logloss:0.05176
# [10]	validation_0-logloss:0.05003
# [11]	validation_0-logloss:0.04890
# [12]	validation_0-logloss:0.04803
# [13]	validation_0-logloss:0.04791
# [14]	validation_0-logloss:0.04781
# [15]	validation_0-logloss:0.04731
# [16]	validation_0-logloss:0.04736
# ...
# [31]	validation_0-logloss:0.04246
# [32]	validation_0-logloss:0.04317
# [33]	validation_0-logloss:0.04309
# [34]	validation_0-logloss:0.04382
# [35]	validation_0-logloss:0.04394
# [36]	validation_0-logloss:0.04412
# [37]	validation_0-logloss:0.04397
# [38]	validation_0-logloss:0.04411
# [39]	validation_0-logloss:0.04417
# [40]	validation_0-logloss:0.04355
# [41]	validation_0-logloss:0.04373
# [42]	validation_0-logloss:0.04277
# [43]	validation_0-logloss:0.04265
# [44]	validation_0-logloss:0.04287
# [45]	validation_0-logloss:0.04359
# [46]	validation_0-logloss:0.04377
# [47]	validation_0-logloss:0.04495
# [48]	validation_0-logloss:0.04490
# [49]	validation_0-logloss:0.04474
# [50]	validation_0-logloss:0.04489
# [51]	validation_0-logloss:0.04493
# [52]	validation_0-logloss:0.04482
# [53]	validation_0-logloss:0.04452
# [54]	validation_0-logloss:0.04408
# [55]	validation_0-logloss:0.04389
# [56]	validation_0-logloss:0.04409
# [57]	validation_0-logloss:0.04407
# [58]	validation_0-logloss:0.04445
# [59]	validation_0-logloss:0.04471
# [60]	validation_0-logloss:0.04563
# [61]	validation_0-logloss:0.04591
# [62]	validation_0-logloss:0.04587
# [63]	validation_0-logloss:0.04613
# [64]	validation_0-logloss:0.04592
# [65]	validation_0-logloss:0.04628
# [66]	validation_0-logloss:0.04629
# [67]	validation_0-logloss:0.04617
# [68]	validation_0-logloss:0.04619
# [69]	validation_0-logloss:0.04622
# [70]	validation_0-logloss:0.04655
# [71]	validation_0-logloss:0.04678
# [72]	validation_0-logloss:0.04687
# [73]	validation_0-logloss:0.04723
# [74]	validation_0-logloss:0.04709
# [75]	validation_0-logloss:0.04678
# [76]	validation_0-logloss:0.04672
# [77]	validation_0-logloss:0.04723
# [78]	validation_0-logloss:0.04749
# [79]	validation_0-logloss:0.04749
# [80]	validation_0-logloss:0.04828
# [81]	validation_0-logloss:0.04796
# [82]	validation_0-logloss:0.04846
# [83]	validation_0-logloss:0.04830
# [84]	validation_0-logloss:0.04810
# [85]	validation_0-logloss:0.04798
# [86]	validation_0-logloss:0.04803
# [87]	validation_0-logloss:0.04830
# [88]	validation_0-logloss:0.04832
# [89]	validation_0-logloss:0.04859
# [90]	validation_0-logloss:0.04876
# [91]	validation_0-logloss:0.04848
# [92]	validation_0-logloss:0.04830
# [93]	validation_0-logloss:0.04849
# [94]	validation_0-logloss:0.04872
# [95]	validation_0-logloss:0.04948
# [96]	validation_0-logloss:0.04960
# [97]	validation_0-logloss:0.04945
# [98]	validation_0-logloss:0.04929
# [99]	validation_0-logloss:0.04947
# [0]	validation_0-logloss:0.17493
# [1]	validation_0-logloss:0.13559
# [2]	validation_0-logloss:0.10939
# [3]	validation_0-logloss:0.09143
# [4]	validation_0-logloss:0.07847
# [5]	validation_0-logloss:0.06907
# [6]	validation_0-logloss:0.06191
# [7]	validation_0-logloss:0.05790
# [8]	validation_0-logloss:0.05444
# [9]	validation_0-logloss:0.05183
# [10]	validation_0-logloss:0.04952
# [11]	validation_0-logloss:0.04789
# [12]	validation_0-logloss:0.04665
# [13]	validation_0-logloss:0.04482
# [14]	validation_0-logloss:0.04441
# [15]	validation_0-logloss:0.04325
# [16]	validation_0-logloss:0.04362
# [17]	validation_0-logloss:0.04332
# [18]	validation_0-logloss:0.04242
# [19]	validation_0-logloss:0.04218
# [20]	validation_0-logloss:0.04134
# [21]	validation_0-logloss:0.04069
# [22]	validation_0-logloss:0.04083
# [23]	validation_0-logloss:0.04111
# [24]	validation_0-logloss:0.04184
# [25]	validation_0-logloss:0.04137
# [26]	validation_0-logloss:0.04255
# [27]	validation_0-logloss:0.04285
# [28]	validation_0-logloss:0.04308
# [29]	validation_0-logloss:0.04363
# [30]	validation_0-logloss:0.04431
# [31]	validation_0-logloss:0.04411
# [32]	validation_0-logloss:0.04396
# [33]	validation_0-logloss:0.04382
# [34]	validation_0-logloss:0.04354
# [35]	validation_0-logloss:0.04326
# [36]	validation_0-logloss:0.04393
# [37]	validation_0-logloss:0.04395
# [38]	validation_0-logloss:0.04379
# [39]	validation_0-logloss:0.04377
# [40]	validation_0-logloss:0.04349
# [41]	validation_0-logloss:0.04383
# [42]	validation_0-logloss:0.04378
# [43]	validation_0-logloss:0.04374
# [44]	validation_0-logloss:0.04423
# [45]	validation_0-logloss:0.04442
# [46]	validation_0-logloss:0.04506
# [47]	validation_0-logloss:0.04547
# [48]	validation_0-logloss:0.04586
# [49]	validation_0-logloss:0.04666
# [50]	validation_0-logloss:0.04666
# [51]	validation_0-logloss:0.04682
# [52]	validation_0-logloss:0.04720
# [53]	validation_0-logloss:0.04713
# [54]	validation_0-logloss:0.04706
# [55]	validation_0-logloss:0.04759
# [56]	validation_0-logloss:0.04786
# [57]	validation_0-logloss:0.04819
# [58]	validation_0-logloss:0.04802
# [59]	validation_0-logloss:0.04837
# [60]	validation_0-logloss:0.04855
# [61]	validation_0-logloss:0.04871
# [62]	validation_0-logloss:0.04832
# [63]	validation_0-logloss:0.04844
# [64]	validation_0-logloss:0.04874
# [65]	validation_0-logloss:0.04894
# [66]	validation_0-logloss:0.04880
# [67]	validation_0-logloss:0.04867
# [68]	validation_0-logloss:0.04884
# [69]	validation_0-logloss:0.04861
# [70]	validation_0-logloss:0.04912
# [71]	validation_0-logloss:0.04955
# [72]	validation_0-logloss:0.05010
# [73]	validation_0-logloss:0.05047
# [74]	validation_0-logloss:0.05063
# [75]	validation_0-logloss:0.05105
# [76]	validation_0-logloss:0.05183
# [77]	validation_0-logloss:0.05219
# [78]	validation_0-logloss:0.05205
# [79]	validation_0-logloss:0.05212
# [80]	validation_0-logloss:0.05246
# [81]	validation_0-logloss:0.05231
# [82]	validation_0-logloss:0.05292
# [83]	validation_0-logloss:0.05330
# [84]	validation_0-logloss:0.05320
# [85]	validation_0-logloss:0.05309
# [86]	validation_0-logloss:0.05326
# [87]	validation_0-logloss:0.05308
# [88]	validation_0-logloss:0.05299
# [89]	validation_0-logloss:0.05322
# [90]	validation_0-logloss:0.05352
# [91]	validation_0-logloss:0.05393
# [92]	validation_0-logloss:0.05348
# [93]	validation_0-logloss:0.05334
# [94]	validation_0-logloss:0.05342
# [95]	validation_0-logloss:0.05352
# [96]	validation_0-logloss:0.05358
# [97]	validation_0-logloss:0.05352
# [98]	validation_0-logloss:0.05338
# [99]	validation_0-logloss:0.05378
# [0]	validation_0-logloss:0.18812
# [1]	validation_0-logloss:0.14868
# [2]	validation_0-logloss:0.12411
# [3]	validation_0-logloss:0.10563
# [4]	validation_0-logloss:0.09084
# [5]	validation_0-logloss:0.08177
# [6]	validation_0-logloss:0.07485
# [7]	validation_0-logloss:0.06895
# [8]	validation_0-logloss:0.06584
# [9]	validation_0-logloss:0.06294
# [10]	validation_0-logloss:0.06042
# [11]	validation_0-logloss:0.05878
# [12]	validation_0-logloss:0.05825
# [13]	validation_0-logloss:0.05760
# [14]	validation_0-logloss:0.05685
# [15]	validation_0-logloss:0.05800
# [16]	validation_0-logloss:0.05694
# [17]	validation_0-logloss:0.05630
# [18]	validation_0-logloss:0.05663
# [19]	validation_0-logloss:0.05745
# [20]	validation_0-logloss:0.05866
# [21]	validation_0-logloss:0.05895
# [22]	validation_0-logloss:0.05863
# [23]	validation_0-logloss:0.05903
# [24]	validation_0-logloss:0.05832
# [25]	validation_0-logloss:0.05761
# [26]	validation_0-logloss:0.05797
# [27]	validation_0-logloss:0.05796
# [28]	validation_0-logloss:0.05777
# [29]	validation_0-logloss:0.05773
# [30]	validation_0-logloss:0.05811
# [31]	validation_0-logloss:0.05884
# [32]	validation_0-logloss:0.05832
# [33]	validation_0-logloss:0.05870
# [34]	validation_0-logloss:0.05864
# [35]	validation_0-logloss:0.05864
# [36]	validation_0-logloss:0.05764
# [37]	validation_0-logloss:0.05851
# [38]	validation_0-logloss:0.05897
# [39]	validation_0-logloss:0.05934
# [40]	validation_0-logloss:0.05986
# [41]	validation_0-logloss:0.06123
# [42]	validation_0-logloss:0.06177
# [43]	validation_0-logloss:0.06194
# [44]	validation_0-logloss:0.06286
# [45]	validation_0-logloss:0.06302
# [46]	validation_0-logloss:0.06352
# [47]	validation_0-logloss:0.06459
# [48]	validation_0-logloss:0.06411
# [49]	validation_0-logloss:0.06323
# [50]	validation_0-logloss:0.06421
# [51]	validation_0-logloss:0.06506
# [52]	validation_0-logloss:0.06550
# [53]	validation_0-logloss:0.06529
# [54]	validation_0-logloss:0.06571
# [55]	validation_0-logloss:0.06546
# [56]	validation_0-logloss:0.06566
# [57]	validation_0-logloss:0.06574
# [58]	validation_0-logloss:0.06645
# [59]	validation_0-logloss:0.06667
# [60]	validation_0-logloss:0.06615
# [61]	validation_0-logloss:0.06645
# [62]	validation_0-logloss:0.06696
# [63]	validation_0-logloss:0.06691
# [64]	validation_0-logloss:0.06706
# [65]	validation_0-logloss:0.06720
# [66]	validation_0-logloss:0.06710
# [67]	validation_0-logloss:0.06735
# [68]	validation_0-logloss:0.06785
# [69]	validation_0-logloss:0.06817
# [70]	validation_0-logloss:0.06811
# [71]	validation_0-logloss:0.06849
# [72]	validation_0-logloss:0.06844
# [73]	validation_0-logloss:0.06940
# [74]	validation_0-logloss:0.06950
# [75]	validation_0-logloss:0.06966
# [76]	validation_0-logloss:0.06964
# [77]	validation_0-logloss:0.06987
# [78]	validation_0-logloss:0.06986
# [79]	validation_0-logloss:0.07009
# [80]	validation_0-logloss:0.07024
# [81]	validation_0-logloss:0.07042
# [82]	validation_0-logloss:0.07059
# [83]	validation_0-logloss:0.07058
# [84]	validation_0-logloss:0.07065
# [85]	validation_0-logloss:0.07072
# [86]	validation_0-logloss:0.07072
# [87]	validation_0-logloss:0.07085
# [88]	validation_0-logloss:0.07064
# [89]	validation_0-logloss:0.07108
# [90]	validation_0-logloss:0.07103
# [91]	validation_0-logloss:0.07068
# [92]	validation_0-logloss:0.07138
# [93]	validation_0-logloss:0.07180
# [94]	validation_0-logloss:0.07184
# [95]	validation_0-logloss:0.07232
# [96]	validation_0-logloss:0.07271
# [97]	validation_0-logloss:0.07290
# [98]	validation_0-logloss:0.07298
# [99]	validation_0-logloss:0.07270
# [0]	validation_0-logloss:0.18584
# [1]	validation_0-logloss:0.14698
# [2]	validation_0-logloss:0.11833
# [3]	validation_0-logloss:0.10032
# [4]	validation_0-logloss:0.08575
# [5]	validation_0-logloss:0.07831
# [6]	validation_0-logloss:0.07131
# [7]	validation_0-logloss:0.06603
# [8]	validation_0-logloss:0.06268
# [9]	validation_0-logloss:0.05995
# [10]	validation_0-logloss:0.05788
# [11]	validation_0-logloss:0.05684
# [12]	validation_0-logloss:0.05473
# [13]	validation_0-logloss:0.05386
# [14]	validation_0-logloss:0.05316
# [15]	validation_0-logloss:0.05307
# [16]	validation_0-logloss:0.05223
# [17]	validation_0-logloss:0.05210
# [18]	validation_0-logloss:0.05155
# [19]	validation_0-logloss:0.05151
# [20]	validation_0-logloss:0.05159
# [21]	validation_0-logloss:0.05162
# [22]	validation_0-logloss:0.05149
# [23]	validation_0-logloss:0.05137
# [24]	validation_0-logloss:0.05140
# [25]	validation_0-logloss:0.05089
# [26]	validation_0-logloss:0.05119
# [27]	validation_0-logloss:0.05101
# [28]	validation_0-logloss:0.05071
# [29]	validation_0-logloss:0.05049
# [30]	validation_0-logloss:0.05033
# [31]	validation_0-logloss:0.04957
# [32]	validation_0-logloss:0.04962
# [33]	validation_0-logloss:0.04931
# [34]	validation_0-logloss:0.04947
# [35]	validation_0-logloss:0.04967
# [36]	validation_0-logloss:0.05011
# [37]	validation_0-logloss:0.05004
# [38]	validation_0-logloss:0.04987
# [39]	validation_0-logloss:0.05068
# [40]	validation_0-logloss:0.05141
# [41]	validation_0-logloss:0.05051
# [42]	validation_0-logloss:0.05050
# [43]	validation_0-logloss:0.05054
# [44]	validation_0-logloss:0.05050
# [45]	validation_0-logloss:0.05068
# [46]	validation_0-logloss:0.05015
# [47]	validation_0-logloss:0.05037
# [48]	validation_0-logloss:0.05054
# [49]	validation_0-logloss:0.05070
# [50]	validation_0-logloss:0.05061
# [51]	validation_0-logloss:0.05109
# [52]	validation_0-logloss:0.05068
# [53]	validation_0-logloss:0.05074
# [54]	validation_0-logloss:0.05117
# [55]	validation_0-logloss:0.05113
# [56]	validation_0-logloss:0.05117
# [57]	validation_0-logloss:0.05184
# [58]	validation_0-logloss:0.05198
# [59]	validation_0-logloss:0.05185
# [60]	validation_0-logloss:0.05217
# [61]	validation_0-logloss:0.05215
# [62]	validation_0-logloss:0.05238
# [63]	validation_0-logloss:0.05189
# [64]	validation_0-logloss:0.05165
# [65]	validation_0-logloss:0.05151
# [66]	validation_0-logloss:0.05220
# [67]	validation_0-logloss:0.05218
# [68]	validation_0-logloss:0.05184
# [69]	validation_0-logloss:0.05213
# [70]	validation_0-logloss:0.05222
# [71]	validation_0-logloss:0.05234
# [72]	validation_0-logloss:0.05257
# [73]	validation_0-logloss:0.05284
# [74]	validation_0-logloss:0.05288
# [75]	validation_0-logloss:0.05298
# [76]	validation_0-logloss:0.05285
# [77]	validation_0-logloss:0.05254
# [78]	validation_0-logloss:0.05295
# [79]	validation_0-logloss:0.05308
# [80]	validation_0-logloss:0.05324
# [81]	validation_0-logloss:0.05320
# [82]	validation_0-logloss:0.05332
# [83]	validation_0-logloss:0.05364
# [84]	validation_0-logloss:0.05392
# [85]	validation_0-logloss:0.05351
# [86]	validation_0-logloss:0.05359
# [87]	validation_0-logloss:0.05422
# [88]	validation_0-logloss:0.05437
# [89]	validation_0-logloss:0.05408
# [90]	validation_0-logloss:0.05468
# [91]	validation_0-logloss:0.05462
# [92]	validation_0-logloss:0.05472
# [93]	validation_0-logloss:0.05489
# [94]	validation_0-logloss:0.05503
# [95]	validation_0-logloss:0.05460
# [96]	validation_0-logloss:0.05514
# [97]	validation_0-logloss:0.05526
# [98]	validation_0-logloss:0.05569
# [99]	validation_0-logloss:0.05584
# [0]	validation_0-logloss:0.19051
# [1]	validation_0-logloss:0.15222
# [2]	validation_0-logloss:0.12558
# [3]	validation_0-logloss:0.10791
# [4]	validation_0-logloss:0.09368
# [5]	validation_0-logloss:0.08434
# [6]	validation_0-logloss:0.07715
# [7]	validation_0-logloss:0.07225
# [8]	validation_0-logloss:0.06934
# [9]	validation_0-logloss:0.06641
# [10]	validation_0-logloss:0.06468
# [11]	validation_0-logloss:0.06380
# [12]	validation_0-logloss:0.06269
# [13]	validation_0-logloss:0.06169
# [14]	validation_0-logloss:0.06241
# [15]	validation_0-logloss:0.06304
# [16]	validation_0-logloss:0.06315
# [17]	validation_0-logloss:0.06249
# [18]	validation_0-logloss:0.06299
# [19]	validation_0-logloss:0.06449
# [20]	validation_0-logloss:0.06467
# [21]	validation_0-logloss:0.06553
# [22]	validation_0-logloss:0.06548
# [23]	validation_0-logloss:0.06538
# [24]	validation_0-logloss:0.06534
# [25]	validation_0-logloss:0.06525
# [26]	validation_0-logloss:0.06461
# [27]	validation_0-logloss:0.06537
# [28]	validation_0-logloss:0.06537
# [29]	validation_0-logloss:0.06635
# [30]	validation_0-logloss:0.06645
# [31]	validation_0-logloss:0.06692
# [32]	validation_0-logloss:0.06708
# [33]	validation_0-logloss:0.06862
# [34]	validation_0-logloss:0.06949
# [35]	validation_0-logloss:0.06961
# [36]	validation_0-logloss:0.07041
# [37]	validation_0-logloss:0.07179
# [38]	validation_0-logloss:0.07192
# [39]	validation_0-logloss:0.07292
# [40]	validation_0-logloss:0.07383
# [41]	validation_0-logloss:0.07437
# [42]	validation_0-logloss:0.07528
# [43]	validation_0-logloss:0.07613
# [44]	validation_0-logloss:0.07670
# [45]	validation_0-logloss:0.07728
# [46]	validation_0-logloss:0.07775
# [47]	validation_0-logloss:0.07797
# [48]	validation_0-logloss:0.07883
# [49]	validation_0-logloss:0.07845
# [50]	validation_0-logloss:0.07891
# [51]	validation_0-logloss:0.07874
# [52]	validation_0-logloss:0.07882
# [53]	validation_0-logloss:0.07978
# [54]	validation_0-logloss:0.08013
# [55]	validation_0-logloss:0.07993
# [56]	validation_0-logloss:0.08014
# [57]	validation_0-logloss:0.08101
# [58]	validation_0-logloss:0.08181
# [59]	validation_0-logloss:0.08168
# [60]	validation_0-logloss:0.08256
# [61]	validation_0-logloss:0.08363
# [62]	validation_0-logloss:0.08444
# [63]	validation_0-logloss:0.08388
# [64]	validation_0-logloss:0.08339
# [65]	validation_0-logloss:0.08335
# [66]	validation_0-logloss:0.08498
# [67]	validation_0-logloss:0.08538
# [68]	validation_0-logloss:0.08617
# [69]	validation_0-logloss:0.08592
# [70]	validation_0-logloss:0.08550
# [71]	validation_0-logloss:0.08523
# [72]	validation_0-logloss:0.08587
# [73]	validation_0-logloss:0.08617
# [74]	validation_0-logloss:0.08664
# [75]	validation_0-logloss:0.08699
# [76]	validation_0-logloss:0.08727
# [77]	validation_0-logloss:0.08786
# [78]	validation_0-logloss:0.08865
# [79]	validation_0-logloss:0.08865
# [80]	validation_0-logloss:0.08894
# [81]	validation_0-logloss:0.08942
# [82]	validation_0-logloss:0.08928
# [83]	validation_0-logloss:0.08979
# [84]	validation_0-logloss:0.08998
# [85]	validation_0-logloss:0.09053
# [86]	validation_0-logloss:0.09098
# [87]	validation_0-logloss:0.09145
# [88]	validation_0-logloss:0.09133
# [89]	validation_0-logloss:0.09118
# [90]	validation_0-logloss:0.09118
# [91]	validation_0-logloss:0.09167
# [92]	validation_0-logloss:0.09148
# [93]	validation_0-logloss:0.09173
# [94]	validation_0-logloss:0.09218
# [95]	validation_0-logloss:0.09294
# [96]	validation_0-logloss:0.09356
# [97]	validation_0-logloss:0.09358
# [98]	validation_0-logloss:0.09377
# [99]	validation_0-logloss:0.09389
# Done!
# CPU times: user 1min 37s, sys: 2.2 s, total: 1min 39s
# Wall time: 1min 45s

# %%
model_performance_before.round(3)
# Out:
#                      accuracy mean  accuracy std  balanced accuracy mean  \
# Logistic Regression          0.920         0.006                   0.899
# KNN                          0.971         0.003                   0.881
# Decision Tree                0.970         0.003                   0.883
# LightGBM                     0.975         0.004                   0.950
# XGBoost                      0.978         0.003                   0.920
#
#                      balanced accuracy std  f1 mean  f1 std  f1 micro mean  \
# Logistic Regression                  0.015    0.956   0.004          0.920
# KNN                                  0.020    0.984   0.002          0.971
# Decision Tree                        0.017    0.984   0.002          0.970
# LightGBM                             0.012    0.986   0.002          0.975
# XGBoost                              0.017    0.988   0.002          0.978
#
#                      f1 micro std  f1 macro mean  f1 macro std  \
# Logistic Regression         0.006          0.785         0.014
# KNN                         0.003          0.889         0.014
# Decision Tree               0.003          0.886         0.013
# LightGBM                    0.004          0.914         0.012
# XGBoost                     0.003          0.918         0.012
#
#                      f1 weighted mean  f1 weighted std  precision mean  \
# Logistic Regression             0.931            0.005           0.989
# KNN                             0.970            0.004           0.983
# Decision Tree                   0.969            0.003           0.983
# LightGBM                        0.976            0.004           0.994
# XGBoost                         0.978            0.003           0.988
#
#                      precision std  precision micro mean  precision micro std  \
# Logistic Regression          0.002                 0.920                0.006
# KNN                          0.003                 0.971                0.003
# Decision Tree                0.003                 0.970                0.003
# LightGBM                     0.002                 0.975                0.004
# XGBoost                      0.003                 0.978                0.003
#
#                      precision macro mean  precision macro std  \
# Logistic Regression                 0.732                0.013
# KNN                                 0.898                0.016
# Decision Tree                       0.889                0.015
# LightGBM                            0.884                0.017
# XGBoost                             0.916                0.015
#
#                      precision weighted mean  precision weighted std  \
# Logistic Regression                    0.952                   0.003
# KNN                                    0.970                   0.004
# Decision Tree                          0.969                   0.003
# LightGBM                               0.978                   0.003
# XGBoost                                0.978                   0.003
#
#                      average precision mean  average precision std  \
# Logistic Regression                   0.997                  0.000
# KNN                                   0.993                  0.002
# Decision Tree                         0.982                  0.003
# LightGBM                              1.000                  0.000
# XGBoost                               0.999                  0.000
#
#                      recall mean  recall std  recall micro mean  \
# Logistic Regression        0.924       0.006              0.920
# KNN                        0.986       0.003              0.971
# Decision Tree              0.984       0.003              0.970
# LightGBM                   0.979       0.004              0.975
# XGBoost                    0.988       0.003              0.978
#
#                      recall micro std  recall macro mean  recall macro std  \
# Logistic Regression             0.006              0.899             0.015
# KNN                             0.003              0.881             0.020
# Decision Tree                   0.003              0.883             0.017
# LightGBM                        0.004              0.950             0.012
# XGBoost                         0.003              0.920             0.017
#
#                      recall weighted mean  recall weighted std  roc auc mean  \
# Logistic Regression                 0.920                0.006         0.960
# KNN                                 0.971                0.003         0.949
# Decision Tree                       0.970                0.003         0.883
# LightGBM                            0.975                0.004         0.994
# XGBoost                             0.978                0.003         0.993
#
#                      roc auc std  roc auc ovr mean  roc auc ovr std  \
# Logistic Regression        0.005             0.960            0.005
# KNN                        0.012             0.949            0.012
# Decision Tree              0.017             0.883            0.017
# LightGBM                   0.001             0.994            0.001
# XGBoost                    0.001             0.993            0.001
#
#                      roc auc ovo mean  roc auc ovo std  \
# Logistic Regression             0.960            0.005
# KNN                             0.949            0.012
# Decision Tree                   0.883            0.017
# LightGBM                        0.994            0.001
# XGBoost                         0.993            0.001
#
#                      roc auc ovr weighted mean  roc auc ovr weighted std  \
# Logistic Regression                      0.960                     0.005
# KNN                                      0.949                     0.012
# Decision Tree                            0.883                     0.017
# LightGBM                                 0.994                     0.001
# XGBoost                                  0.993                     0.001
#
#                      roc auc ovo weighted mean  roc auc ovo weighted std
# Logistic Regression                      0.960                     0.005
# KNN                                      0.949                     0.012
# Decision Tree                            0.883                     0.017
# LightGBM                                 0.994                     0.001
# XGBoost                                  0.993                     0.001

# %% [markdown]
# Reminder:
# * Precision = TP / (TP + FP)
# * Recall = TP / (TP + FN)

# %%
score_metric = scoring
lfunc.plot_model_score([collect_cv_results_before],
                 score = score_metric, classifiers_names = classifiers,
                 colors = ['skyblue'], tilt_x = True,
                 title = score_metric.replace('_',' ').title()+
                        ' per Algorithm before Hypertuning')  ;

# %% [markdown]
# #### Confusion Matrices before Hypertune

# %%
# %reload_ext autoreload

lfunc.plot_confusion_matrices(model_prob_before,y_test,
                              names = classifiers,
                              n_cols = 3, normalize = 'all', labels = labels,
                              title = 'for the Following Algorithms')
;
# Out:
# ''

# %% [markdown]
# ## Hyperparameter Tuning with RandomizedSearchCV

# %%
classifiers_h = classifiers

# %% [markdown]
# In a previous project, I have made the function 'hyper_search' to loop over the given estimators and several (grid-)search-varieties ('Grid', 'HalvingGrid', 'Random', 'HalvingRandom').
# In the following, I will focus on RandomizedSearchCV, which performed best in the previous projects.

# %% [markdown]
# The dummy estimator in the pipeline will be replaced by the classifiers in the hyperparameter dictionaries

# %%
pipe_steps = pipe_prep_steps.copy()
pipe_steps.append(('classifier' , RandomForestClassifier()))

pipe = Pipeline(pipe_steps, memory=memory)   # cache pipeline results except from last step

# %% [markdown]
# In the following, I create the parameter distribution for Randomized SearchCV per classifier. Since XGBoost and LightGBM are fast, I let them test more parameters.

# %%
# %reload_ext autoreload

# Create param distribution (Randomized Search) per classifier

hyper_distro_XGB = {
          'classifier' : [XGBClas],
          "classifier__n_estimators": randint(50, 1000),
          "classifier__max_depth": randint(1, 10),
          "classifier__scale_pos_weight": uniform(1, 30),
          "classifier__learning_rate": uniform(0.05, 0.2),
          'classifier__early_stopping_rounds': randint(5, 10),
          "classifier__min_child_weight": randint(1, 12),       # min. number of obs. (hessians) in a node to make split
          "classifier__gamma": uniform(0, 1),                   # L0 regularization - dep. on number of leaves
          "classifier__reg_alpha": uniform(0, 1),               # L1 regularization
          "classifier__reg_lambda": uniform(loc=0, scale=1),    # L2 regularization
          "classifier__subsample": uniform(0.1, 1),
          "classifier__colsample_bytree": uniform(0.1, 1),

      }

#hyper_distro_CatB = {
#        'classifier' : [CatBClas],
#        "classifier__n_estimators":      randint(50, 1000),
#        "classifier__depth":             randint(1, 12),
#        "classifier__colsample_bylevel": uniform(0.1, 1),
#        "classifier__boosting_type":     ["Ordered", "Plain"],
#        "classifier__bootstrap_type":    ["Bayesian", "Bernoulli", "MVS"],
#        'classifier__early_stopping_rounds': randint(1, 10),
#        "classifier__random_strength":   loguniform(1e-4, 10.0),
#        "classifier__l2_leaf_reg":       loguniform(1e-8, 10.0),
#        #"classifier__bagging_temperature": uniform(0, 10), # if param["bootstrap_type"] == "Bayesian"
#        #"classifier__subsample": uniform(0.1, 1),          # if param["bootstrap_type"] == "Bernoulli"
#      }

hyper_distro_LightGBM = {
        'classifier' : [LGBMClas],
        "classifier__n_estimators": randint(50, 1000),
        "classifier__max_depth": randint(1, 12),
        "classifier__boosting_type": ["gbdt"],
        "classifier__learning_rate": uniform(0.05, 0.2),
        "classifier__lambda_l1": loguniform(1e-8, 10.0),
        "classifier__lambda_l2": loguniform(1e-8, 10.0),
        "classifier__num_leaves": randint(2, 256),
        'classifier__early_stopping_round': randint(1, 10),
        "classifier__feature_fraction": uniform(0.4, 1.0),
        "classifier__bagging_fraction": uniform(0.4, 1.0),
        "classifier__bagging_freq": randint(1, 7),
        "classifier__min_child_samples": randint(5, 100),

        }

hyper_distro_LinSVC = {'classifier' : [LinSVC_hypersearch],
     'classifier__C' : loguniform(0.01, 1e3)}

hyper_distro_rbfSVC = {'classifier' : [rbfSVC_hypersearch],
     'classifier__kernel' : ['rbf'],
     'classifier__C' : loguniform(0.01, 1e3),
     'classifier__gamma': loguniform(0.01, 1e3)}

hyper_distro_LogReg = {'classifier' : [LogReg],
     'classifier__C' : loguniform(0.01, 1e3)}

hyper_distro_KNN = {'classifier' : [KNNClas],
             'classifier__n_neighbors' : randint(1, 21),
             'classifier__weights' : ['uniform','distance'],
             'classifier__metric' : ['minkowski','euclidean','manhattan']}

#https://towardsdatascience.com/how-to-tune-a-decision-tree-f03721801680
hyper_distro_DTC = {'classifier' : [DTClas],
     'classifier__min_samples_split' : randint(10, 41),
     'classifier__min_samples_leaf' : randint(1, 21)}

hyper_distro_RFC = {'classifier' : [RFClas],
     'classifier__n_estimators' : randint(10, 1000),
     #'classifier__max_features': ['sqrt', 'log2', None],
     #'classifier__max_depth': randint(1, 10),
     #'classifier__max_leaf_nodes': randint(1, 10)
                    }


# Classifiers and their corresponding hyperparameter setup
param_distro_map = {'Linear Svm': hyper_distro_LinSVC,
                  'Radial Svm': hyper_distro_rbfSVC,
                  'Logistic Regression': hyper_distro_LogReg,
                  'KNN': hyper_distro_KNN,
                  'Decision Tree': hyper_distro_DTC,
                  'Random Forest': hyper_distro_RFC,
                  'LightGBM': hyper_distro_LightGBM,
                  'XGBoost': hyper_distro_XGB
}

# hyperparameter setups used in this run:
param_distro = []
for clas in classifiers_h:
    param_distro.append(param_distro_map[clas])

# %% [markdown]
# **Derive the Hyperparameters**

# %%
# %%time
# %reload_ext autoreload

start = 0
stop = 4

hyper_params = lfunc.hyper_search(pipe,  X_train, y_train,
                            param_distributions = param_distro, #[start:stop],
                            classifier_names = classifiers,#[start:stop],
                            cv = cvSK, niter = 20,
                            searches = ['Random'],
                            scoring = scoring,
                            verbose=0)
# Out:
# Executing Logistic Regression
# for search method: Random
# best score: 0.903
# best parameters: {'classifier': LogisticRegression(class_weight='balanced', n_jobs=-1, random_state=1), 'classifier__C': 4.877726266856736}
#
# Executing KNN
# for search method: Random
# best score: 0.886
# best parameters: {'classifier': KNeighborsClassifier(n_jobs=-1), 'classifier__metric': 'manhattan', 'classifier__n_neighbors': 16, 'classifier__weights': 'uniform'}
#
# Executing Decision Tree
# for search method: Random
# best score: 0.959
# best parameters: {'classifier': DecisionTreeClassifier(class_weight='balanced', random_state=1), 'classifier__min_samples_leaf': 6, 'classifier__min_samples_split': 40}
#
# Executing LightGBM
# for search method: Random
# best score: 0.969
# best parameters: {'classifier': LGBMClassifierWithEarlyStop(boosting_type='gbdt', class_weight='balanced',
#                             colsample_bytree=1.0, early_stopping_round=10,
#                             force_row_wise=True, importance_type='split',
#                             learning_rate=0.1, max_depth=-1,
#                             metric='binary_logloss', min_child_samples=20,
#                             min_child_weight=0.001, min_split_gain=0.0,
#                             n_estimators=100, n_jobs=None, num_leaves=31,
#                             objective='binary', random_state=1, reg_alpha=0.0,
#                             reg_lambda=0.0, subsample=1.0,
#                             subsample_for_bin=200000, subsample_freq=0,
#                             verbosity=-100), 'classifier__bagging_fraction': 0.9435060776707007, 'classifier__bagging_freq': 3, 'classifier__boosting_type': 'gbdt', 'classifier__early_stopping_round': 4, 'classifier__feature_fraction': 0.982283081244809, 'classifier__lambda_l1': 0.041105676423791794, 'classifier__lambda_l2': 0.41162353845724853, 'classifier__learning_rate': 0.08517828798604898, 'classifier__max_depth': 3, 'classifier__min_child_samples': 6, 'classifier__n_estimators': 961, 'classifier__num_leaves': 88}
#
# Executing XGBoost
# for search method: Random
# best score: 0.911
# best parameters: {'classifier': XGBoostClassifierWithEarlyStop(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None,
#                                colsample_bytree=None, device=None,
#                                early_stopping_rounds=None,
#                                enable_categorical=False, eval_metric=None,
#                                feature_types=None, gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=None, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=None, n_jobs=None,
#                                num_parallel_tree=None,
#                                objective='binary:logistic', ...), 'classifier__colsample_bytree': 0.8619623125184942, 'classifier__early_stopping_rounds': 8, 'classifier__gamma': 0.7374597038900097, 'classifier__learning_rate': 0.14175709968250919, 'classifier__max_depth': 4, 'classifier__min_child_weight': 1, 'classifier__n_estimators': 475, 'classifier__reg_alpha': 0.814671058444582, 'classifier__reg_lambda': 0.8725471276050031, 'classifier__scale_pos_weight': 1.9808772625302176, 'classifier__subsample': 0.9382125668022399}
#
# CPU times: user 2.96 s, sys: 188 ms, total: 3.15 s
# Wall time: 42.3 s

# %%
hyper_params
# Out:
#             classifier search method  best score  time[s]  \
# 0  Logistic Regression        Random       0.903      4.2
# 1                  KNN        Random       0.886     13.1
# 2        Decision Tree        Random       0.959      2.1
# 3             LightGBM        Random       0.969      8.5
# 4              XGBoost        Random       0.911     14.3
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                best params
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               {'classifier': LogisticRegression(class_weight='balanced', n_jobs=-1, random_state=1), 'classifier__C': 4.877726266856736}
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      {'classifier': KNeighborsClassifier(n_jobs=-1), 'classifier__metric': 'manhattan', 'classifier__n_neighbors': 16, 'classifier__weights': 'uniform'}
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  {'classifier': DecisionTreeClassifier(class_weight='balanced', random_state=1), 'classifier__min_samples_leaf': 6, 'classifier__min_samples_split': 40}
# 3                                                                                                                                                                                                                                                                                                                                                  {'classifier': LGBMClassifierWithEarlyStop(boosting_type='gbdt', class_weight='balanced',
#                             colsample_bytree=1.0, early_stopping_round=10,
#                             force_row_wise=True, importance_type='split',
#                             learning_rate=0.1, max_depth=-1,
#                             metric='binary_logloss', min_child_samples=20,
#                             min_child_weight=0.001, min_split_gain=0.0,
#                             n_estimators=100, n_jobs=None, num_leaves=31,
#                             objective='binary', random_state=1, reg_alpha=0.0,
#                             reg_lambda=0.0, subsample=1.0,
#                             subsample_for_bin=200000, subsample_freq=0,
#                             verbosity=-100), 'classifier__bagging_fraction': 0.9435060776707007, 'classifier__bagging_freq': 3, 'classifier__boosting_type': 'gbdt', 'classifier__early_stopping_round': 4, 'classifier__feature_fraction': 0.982283081244809, 'classifier__lambda_l1': 0.041105676423791794, 'classifier__lambda_l2': 0.41162353845724853, 'classifier__learning_rate': 0.08517828798604898, 'classifier__max_depth': 3, 'classifier__min_child_samples': 6, 'classifier__n_estimators': 961, 'classifier__num_leaves': 88}
# 4  {'classifier': XGBoostClassifierWithEarlyStop(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None,
#                                colsample_bytree=None, device=None,
#                                early_stopping_rounds=None,
#                                enable_categorical=False, eval_metric=None,
#                                feature_types=None, gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=None, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=None, n_jobs=None,
#                                num_parallel_tree=None,
#                                objective='binary:logistic', ...), 'classifier__colsample_bytree': 0.8619623125184942, 'classifier__early_stopping_rounds': 8, 'classifier__gamma': 0.7374597038900097, 'classifier__learning_rate': 0.14175709968250919, 'classifier__max_depth': 4, 'classifier__min_child_weight': 1, 'classifier__n_estimators': 475, 'classifier__reg_alpha': 0.814671058444582, 'classifier__reg_lambda': 0.8725471276050031, 'classifier__scale_pos_weight': 1.9808772625302176, 'classifier__subsample': 0.9382125668022399}

# %% [markdown]
# Extract the best tuned hyperparameters per classifier:

# %%
param_classifiers={}


for classifier in classifiers_h:
    param_classifier = hyper_params.loc[(hyper_params['classifier']==classifier)]
    param_classifier = param_classifier.loc[param_classifier['best score']==param_classifier['best score'].max()]['best params'].values[0]
    # replace the 'classifier__' in the keys --> can insert best params directly into untuned classifiers
    if 'classifier' in param_classifier.keys():
        param_classifier.pop('classifier')
    new_keys = [key.replace('classifier__','') for key in param_classifier.keys()]
    param_classifier = dict(zip(new_keys, list(param_classifier.values())))
    print(param_classifier)
    param_classifiers[classifier] = param_classifier
# Out:
# {'C': 4.877726266856736}
# {'metric': 'manhattan', 'n_neighbors': 16, 'weights': 'uniform'}
# {'min_samples_leaf': 6, 'min_samples_split': 40}
# {'bagging_fraction': 0.9435060776707007, 'bagging_freq': 3, 'boosting_type': 'gbdt', 'early_stopping_round': 4, 'feature_fraction': 0.982283081244809, 'lambda_l1': 0.041105676423791794, 'lambda_l2': 0.41162353845724853, 'learning_rate': 0.08517828798604898, 'max_depth': 3, 'min_child_samples': 6, 'n_estimators': 961, 'num_leaves': 88}
# {'colsample_bytree': 0.8619623125184942, 'early_stopping_rounds': 8, 'gamma': 0.7374597038900097, 'learning_rate': 0.14175709968250919, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 475, 'reg_alpha': 0.814671058444582, 'reg_lambda': 0.8725471276050031, 'scale_pos_weight': 1.9808772625302176, 'subsample': 0.9382125668022399}

# %% [markdown]
# ##### Update the base classifiers with the hypertuned parameters:

# %%
# %%capture

LinSVC_h = copy.deepcopy(LinSVC_hypersearch)
if 'Linear Svm' in param_classifiers.keys():
    # probability=True in SVMs needed for later scoring:
    LinSVC_h.set_params(**param_classifiers['Linear Svm'], probability=True)

rbfSVC_h = copy.deepcopy(rbfSVC_hypersearch)
if 'Radial Svm' in param_classifiers.keys():
    rbfSVC_h.set_params(**param_classifiers['Radial Svm'], probability=True)

LogReg_h = copy.deepcopy(LogReg)
if 'Logistic Regression' in param_classifiers.keys():
    LogReg_h.set_params(**param_classifiers['Logistic Regression'])

KNNClas_h = copy.deepcopy(KNNClas)
if 'KNN' in param_classifiers.keys():
    KNNClas_h.set_params(**param_classifiers['KNN'])

DTClas_h = copy.deepcopy(DTClas)
if 'Decision Tree' in param_classifiers.keys():
    DTClas_h.set_params(**param_classifiers['Decision Tree'])

RFClas_h = copy.deepcopy(RFClas)
if 'Random Forest' in param_classifiers.keys():
    RFClas_h.set_params(**param_classifiers['Random Forest'])

LGBMClas_h = copy.deepcopy(LGBMClas)
if 'LightGBM' in param_classifiers.keys():
    LGBMClas_h.set_params(**param_classifiers['LightGBM'])

# active when enough time to compile:
# CatBClas_h = CatBClas
#if 'CatBoost' in param_classifiers.keys():
    # CatBClas_h.set_params(**param_classifiers['CatBoost'])

XGBClas_h = copy.deepcopy(XGBClas)
if 'XGBoost' in param_classifiers.keys():
    XGBoost_param_fit={}
    # cross_val_score cannot deal with 'early_stopping_rounds'
    # ---> put it into fit_params for the fit-function:
    if 'early_stopping_rounds' in param_classifiers['XGBoost']:
        XGBoost_param_fit['classifier__early_stopping_rounds'] = param_classifiers['XGBoost']['early_stopping_rounds']
        param_classifiers['XGBoost'].pop('early_stopping_rounds')
    XGBClas_h.set_params(**param_classifiers['XGBoost'])



# hypertuned estimators and their names
classifier_map_h = {'Linear Svm': LinSVC_h,
                  'Radial Svm': rbfSVC_h,
                  'Logistic Regression': LogReg_h,
                  'KNN': KNNClas_h,
                  'Decision Tree': DTClas_h,
                  'Random Forest': RFClas_h,
                  'LightGBM': LGBMClas_h,
                  'XGBoost': XGBClas_h
}

# %% [markdown]
# ## Scores per Basic Model AFTER Hyperparameter Tuning

# %% [markdown]
# Let's redo the crossvalidation on the algorithms with their now tuned parameters.

# %%
#classifiers_h =[#'KNN',
# #'Decision Tree',
# 'LightGBM']

# %%
# %%time
# %reload_ext autoreload

estimators_hyped = []
for clas in classifiers_h:
    estimators_hyped.append(classifier_map_h[clas])

models_hyped=[]
fit_params_hyped=[]
for estimator in estimators_hyped:
    pipe_steps = pipe_prep_steps.copy()
    pipe_steps.append(('classifier' , estimator))
    models_hyped.append(Pipeline(pipe_steps))

    if estimator == XGBClas_h:
        fit_params_hyped.append(XGBoost_param_fit)
    else:
        fit_params_hyped.append(None)

model_cv_results_after = lfunc.model_scores(X_train,y_train,X_test,
                                      models = models_hyped,
                                      model_names = classifiers_h,
                                      fit_params = fit_params_hyped,
                                      cv = cvRSK)

(model_performance_after,
 collect_cv_results_after,
 model_prob_after) = model_cv_results_after
# Out:
# Executing Logistic Regression
# Executing KNN
# Executing Decision Tree
# Executing LightGBM
# Executing XGBoost
# [0]	validation_0-logloss:0.24277
# [1]	validation_0-logloss:0.20403
# [2]	validation_0-logloss:0.18569
# [3]	validation_0-logloss:0.16424
# [4]	validation_0-logloss:0.15257
# [5]	validation_0-logloss:0.14017
# [6]	validation_0-logloss:0.12763
# [7]	validation_0-logloss:0.11701
# [8]	validation_0-logloss:0.10870
# [9]	validation_0-logloss:0.10194
# [10]	validation_0-logloss:0.09655
# [11]	validation_0-logloss:0.09086
# [12]	validation_0-logloss:0.08600
# [13]	validation_0-logloss:0.08251
# [14]	validation_0-logloss:0.07969
# [15]	validation_0-logloss:0.07656
# [16]	validation_0-logloss:0.07414
# [17]	validation_0-logloss:0.07219
# [18]	validation_0-logloss:0.07001
# [19]	validation_0-logloss:0.06889
# [20]	validation_0-logloss:0.06838
# [21]	validation_0-logloss:0.06682
# [22]	validation_0-logloss:0.06546
# [23]	validation_0-logloss:0.06452
# [24]	validation_0-logloss:0.06374
# [25]	validation_0-logloss:0.06278
# [26]	validation_0-logloss:0.06252
# [27]	validation_0-logloss:0.06281
# [28]	validation_0-logloss:0.06273
# [29]	validation_0-logloss:0.06275
# [30]	validation_0-logloss:0.06263
# [31]	validation_0-logloss:0.06208
# [32]	validation_0-logloss:0.06132
# [33]	validation_0-logloss:0.06089
# [34]	validation_0-logloss:0.06016
# [35]	validation_0-logloss:0.06029
# [36]	validation_0-logloss:0.06031
# [37]	validation_0-logloss:0.05986
# [38]	validation_0-logloss:0.05941
# [39]	validation_0-logloss:0.05954
# [40]	validation_0-logloss:0.05912
# [41]	validation_0-logloss:0.05871
# [42]	validation_0-logloss:0.05818
# [43]	validation_0-logloss:0.05733
# [44]	validation_0-logloss:0.05680
# [45]	validation_0-logloss:0.05679
# [46]	validation_0-logloss:0.05657
# [47]	validation_0-logloss:0.05654
# [48]	validation_0-logloss:0.05624
# [49]	validation_0-logloss:0.05584
# [50]	validation_0-logloss:0.05596
# [51]	validation_0-logloss:0.05524
# [52]	validation_0-logloss:0.05521
# [53]	validation_0-logloss:0.05473
# [54]	validation_0-logloss:0.05470
# [55]	validation_0-logloss:0.05469
# [56]	validation_0-logloss:0.05426
# [57]	validation_0-logloss:0.05429
# [58]	validation_0-logloss:0.05399
# [59]	validation_0-logloss:0.05370
# [60]	validation_0-logloss:0.05368
# [61]	validation_0-logloss:0.05362
# [62]	validation_0-logloss:0.05406
# [63]	validation_0-logloss:0.05402
# [64]	validation_0-logloss:0.05398
# [65]	validation_0-logloss:0.05405
# [66]	validation_0-logloss:0.05415
# [67]	validation_0-logloss:0.05421
# [68]	validation_0-logloss:0.05430
# [0]	validation_0-logloss:0.26650
# [1]	validation_0-logloss:0.22124
# [2]	validation_0-logloss:0.19831
# [3]	validation_0-logloss:0.17441
# [4]	validation_0-logloss:0.16074
# [5]	validation_0-logloss:0.14816
# [6]	validation_0-logloss:0.13461
# [7]	validation_0-logloss:0.12433
# [8]	validation_0-logloss:0.11527
# [9]	validation_0-logloss:0.10806
# [10]	validation_0-logloss:0.10217
# [11]	validation_0-logloss:0.09592
# [12]	validation_0-logloss:0.09071
# [13]	validation_0-logloss:0.08763
# [14]	validation_0-logloss:0.08471
# [15]	validation_0-logloss:0.08132
# [16]	validation_0-logloss:0.07848
# [17]	validation_0-logloss:0.07710
# [18]	validation_0-logloss:0.07505
# [19]	validation_0-logloss:0.07374
# [20]	validation_0-logloss:0.07302
# [21]	validation_0-logloss:0.07168
# [22]	validation_0-logloss:0.06988
# [23]	validation_0-logloss:0.06881
# [24]	validation_0-logloss:0.06756
# [25]	validation_0-logloss:0.06600
# [26]	validation_0-logloss:0.06504
# [27]	validation_0-logloss:0.06479
# [28]	validation_0-logloss:0.06462
# [29]	validation_0-logloss:0.06494
# [30]	validation_0-logloss:0.06458
# [31]	validation_0-logloss:0.06348
# [32]	validation_0-logloss:0.06259
# [33]	validation_0-logloss:0.06187
# [34]	validation_0-logloss:0.06147
# [35]	validation_0-logloss:0.06120
# [36]	validation_0-logloss:0.06157
# [37]	validation_0-logloss:0.06129
# [38]	validation_0-logloss:0.06089
# [39]	validation_0-logloss:0.06065
# [40]	validation_0-logloss:0.06037
# [41]	validation_0-logloss:0.05981
# [42]	validation_0-logloss:0.05971
# [43]	validation_0-logloss:0.05890
# [44]	validation_0-logloss:0.05835
# [45]	validation_0-logloss:0.05794
# [46]	validation_0-logloss:0.05785
# [47]	validation_0-logloss:0.05784
# [48]	validation_0-logloss:0.05743
# [49]	validation_0-logloss:0.05700
# [50]	validation_0-logloss:0.05698
# [51]	validation_0-logloss:0.05737
# [52]	validation_0-logloss:0.05732
# [53]	validation_0-logloss:0.05732
# [54]	validation_0-logloss:0.05703
# [55]	validation_0-logloss:0.05664
# [56]	validation_0-logloss:0.05669
# [57]	validation_0-logloss:0.05659
# [58]	validation_0-logloss:0.05660
# [59]	validation_0-logloss:0.05620
# [60]	validation_0-logloss:0.05571
# [61]	validation_0-logloss:0.05558
# [62]	validation_0-logloss:0.05539
# [63]	validation_0-logloss:0.05569
# [64]	validation_0-logloss:0.05572
# [65]	validation_0-logloss:0.05575
# [66]	validation_0-logloss:0.05574
# [67]	validation_0-logloss:0.05549
# [68]	validation_0-logloss:0.05555
# [69]	validation_0-logloss:0.05533
# [70]	validation_0-logloss:0.05539
# [71]	validation_0-logloss:0.05540
# [72]	validation_0-logloss:0.05493
# [73]	validation_0-logloss:0.05490
# [74]	validation_0-logloss:0.05491
# [75]	validation_0-logloss:0.05493
# [76]	validation_0-logloss:0.05502
# [77]	validation_0-logloss:0.05502
# [78]	validation_0-logloss:0.05507
# [79]	validation_0-logloss:0.05507
# [80]	validation_0-logloss:0.05517
# [81]	validation_0-logloss:0.05569
# [0]	validation_0-logloss:0.23283
# [1]	validation_0-logloss:0.19294
# [2]	validation_0-logloss:0.17170
# [3]	validation_0-logloss:0.14964
# [4]	validation_0-logloss:0.13610
# [5]	validation_0-logloss:0.12422
# [6]	validation_0-logloss:0.11161
# [7]	validation_0-logloss:0.10137
# [8]	validation_0-logloss:0.09298
# [9]	validation_0-logloss:0.08646
# [10]	validation_0-logloss:0.08148
# [11]	validation_0-logloss:0.07589
# [12]	validation_0-logloss:0.07103
# [13]	validation_0-logloss:0.06802
# [14]	validation_0-logloss:0.06503
# [15]	validation_0-logloss:0.06208
# [16]	validation_0-logloss:0.05998
# [17]	validation_0-logloss:0.05806
# [18]	validation_0-logloss:0.05647
# [19]	validation_0-logloss:0.05502
# [20]	validation_0-logloss:0.05382
# [21]	validation_0-logloss:0.05294
# [22]	validation_0-logloss:0.05227
# [23]	validation_0-logloss:0.05097
# [24]	validation_0-logloss:0.04980
# [25]	validation_0-logloss:0.04908
# [26]	validation_0-logloss:0.04892
# [27]	validation_0-logloss:0.04885
# [28]	validation_0-logloss:0.04823
# [29]	validation_0-logloss:0.04809
# [30]	validation_0-logloss:0.04760
# [31]	validation_0-logloss:0.04695
# [32]	validation_0-logloss:0.04647
# [33]	validation_0-logloss:0.04587
# [34]	validation_0-logloss:0.04577
# [35]	validation_0-logloss:0.04568
# [36]	validation_0-logloss:0.04563
# [37]	validation_0-logloss:0.04554
# [38]	validation_0-logloss:0.04521
# [39]	validation_0-logloss:0.04503
# [40]	validation_0-logloss:0.04479
# [41]	validation_0-logloss:0.04443
# [42]	validation_0-logloss:0.04405
# [43]	validation_0-logloss:0.04381
# [44]	validation_0-logloss:0.04355
# [45]	validation_0-logloss:0.04350
# [46]	validation_0-logloss:0.04350
# [47]	validation_0-logloss:0.04329
# [48]	validation_0-logloss:0.04324
# [49]	validation_0-logloss:0.04341
# [50]	validation_0-logloss:0.04311
# [51]	validation_0-logloss:0.04301
# [52]	validation_0-logloss:0.04331
# [53]	validation_0-logloss:0.04366
# [54]	validation_0-logloss:0.04352
# [55]	validation_0-logloss:0.04346
# [56]	validation_0-logloss:0.04347
# [57]	validation_0-logloss:0.04338
# [58]	validation_0-logloss:0.04347
# [59]	validation_0-logloss:0.04333
# [0]	validation_0-logloss:0.25286
# [1]	validation_0-logloss:0.21526
# [2]	validation_0-logloss:0.19717
# [3]	validation_0-logloss:0.17612
# [4]	validation_0-logloss:0.16476
# [5]	validation_0-logloss:0.15185
# [6]	validation_0-logloss:0.14119
# [7]	validation_0-logloss:0.13238
# [8]	validation_0-logloss:0.12434
# [9]	validation_0-logloss:0.11830
# [10]	validation_0-logloss:0.11279
# [11]	validation_0-logloss:0.10828
# [12]	validation_0-logloss:0.10460
# [13]	validation_0-logloss:0.10128
# [14]	validation_0-logloss:0.09854
# [15]	validation_0-logloss:0.09606
# [16]	validation_0-logloss:0.09435
# [17]	validation_0-logloss:0.09426
# [18]	validation_0-logloss:0.09220
# [19]	validation_0-logloss:0.09231
# [20]	validation_0-logloss:0.09236
# [21]	validation_0-logloss:0.08991
# [22]	validation_0-logloss:0.08916
# [23]	validation_0-logloss:0.08792
# [24]	validation_0-logloss:0.08723
# [25]	validation_0-logloss:0.08595
# [26]	validation_0-logloss:0.08523
# [27]	validation_0-logloss:0.08573
# [28]	validation_0-logloss:0.08621
# [29]	validation_0-logloss:0.08651
# [30]	validation_0-logloss:0.08689
# [31]	validation_0-logloss:0.08525
# [32]	validation_0-logloss:0.08439
# [33]	validation_0-logloss:0.08321
# [34]	validation_0-logloss:0.08297
# [35]	validation_0-logloss:0.08362
# [36]	validation_0-logloss:0.08349
# [37]	validation_0-logloss:0.08430
# [38]	validation_0-logloss:0.08384
# [39]	validation_0-logloss:0.08394
# [40]	validation_0-logloss:0.08313
# [41]	validation_0-logloss:0.08270
# [42]	validation_0-logloss:0.08186
# [43]	validation_0-logloss:0.08131
# [44]	validation_0-logloss:0.08112
# [45]	validation_0-logloss:0.08068
# [46]	validation_0-logloss:0.07987
# [47]	validation_0-logloss:0.07978
# [48]	validation_0-logloss:0.07886
# [49]	validation_0-logloss:0.07839
# [50]	validation_0-logloss:0.07834
# [51]	validation_0-logloss:0.07714
# [52]	validation_0-logloss:0.07620
# [53]	validation_0-logloss:0.07618
# [54]	validation_0-logloss:0.07595
# [55]	validation_0-logloss:0.07563
# [56]	validation_0-logloss:0.07488
# [57]	validation_0-logloss:0.07457
# [58]	validation_0-logloss:0.07396
# [59]	validation_0-logloss:0.07433
# [60]	validation_0-logloss:0.07402
# [61]	validation_0-logloss:0.07360
# [62]	validation_0-logloss:0.07327
# [63]	validation_0-logloss:0.07321
# [64]	validation_0-logloss:0.07328
# [65]	validation_0-logloss:0.07259
# [66]	validation_0-logloss:0.07321
# [67]	validation_0-logloss:0.07338
# [68]	validation_0-logloss:0.07317
# [69]	validation_0-logloss:0.07307
# [70]	validation_0-logloss:0.07294
# [71]	validation_0-logloss:0.07286
# [72]	validation_0-logloss:0.07287
# [73]	validation_0-logloss:0.07287
# [0]	validation_0-logloss:0.26161
# [1]	validation_0-logloss:0.22204
# [2]	validation_0-logloss:0.20242
# [3]	validation_0-logloss:0.18023
# [4]	validation_0-logloss:0.16824
# [5]	validation_0-logloss:0.15566
# [6]	validation_0-logloss:0.14288
# [7]	validation_0-logloss:0.13319
# [8]	validation_0-logloss:0.12506
# [9]	validation_0-logloss:0.11844
# [10]	validation_0-logloss:0.11325
# [11]	validation_0-logloss:0.10811
# [12]	validation_0-logloss:0.10416
# [13]	validation_0-logloss:0.10063
# [14]	validation_0-logloss:0.09754
# [15]	validation_0-logloss:0.09402
# [16]	validation_0-logloss:0.09159
# [17]	validation_0-logloss:0.09105
# [18]	validation_0-logloss:0.08927
# [19]	validation_0-logloss:0.08831
# [20]	validation_0-logloss:0.08815
# [21]	validation_0-logloss:0.08616
# [22]	validation_0-logloss:0.08447
# [23]	validation_0-logloss:0.08285
# [24]	validation_0-logloss:0.08144
# [25]	validation_0-logloss:0.08026
# [26]	validation_0-logloss:0.07897
# [27]	validation_0-logloss:0.07867
# [28]	validation_0-logloss:0.07883
# [29]	validation_0-logloss:0.07930
# [30]	validation_0-logloss:0.07897
# [31]	validation_0-logloss:0.07788
# [32]	validation_0-logloss:0.07683
# [33]	validation_0-logloss:0.07629
# [34]	validation_0-logloss:0.07569
# [35]	validation_0-logloss:0.07532
# [36]	validation_0-logloss:0.07513
# [37]	validation_0-logloss:0.07533
# [38]	validation_0-logloss:0.07508
# [39]	validation_0-logloss:0.07486
# [40]	validation_0-logloss:0.07411
# [41]	validation_0-logloss:0.07340
# [42]	validation_0-logloss:0.07274
# [43]	validation_0-logloss:0.07237
# [44]	validation_0-logloss:0.07162
# [45]	validation_0-logloss:0.07117
# [46]	validation_0-logloss:0.07076
# [47]	validation_0-logloss:0.07044
# [48]	validation_0-logloss:0.07014
# [49]	validation_0-logloss:0.06945
# [50]	validation_0-logloss:0.06890
# [51]	validation_0-logloss:0.06882
# [52]	validation_0-logloss:0.06817
# [53]	validation_0-logloss:0.06797
# [54]	validation_0-logloss:0.06767
# [55]	validation_0-logloss:0.06839
# [56]	validation_0-logloss:0.06865
# [57]	validation_0-logloss:0.06884
# [58]	validation_0-logloss:0.06866
# [59]	validation_0-logloss:0.06836
# [60]	validation_0-logloss:0.06820
# [61]	validation_0-logloss:0.06795
# [0]	validation_0-logloss:0.24361
# [1]	validation_0-logloss:0.20388
# [2]	validation_0-logloss:0.18280
# [3]	validation_0-logloss:0.16112
# [4]	validation_0-logloss:0.14795
# [5]	validation_0-logloss:0.13544
# [6]	validation_0-logloss:0.12277
# [7]	validation_0-logloss:0.11253
# [8]	validation_0-logloss:0.10364
# [9]	validation_0-logloss:0.09677
# [10]	validation_0-logloss:0.09148
# [11]	validation_0-logloss:0.08574
# [12]	validation_0-logloss:0.08134
# [13]	validation_0-logloss:0.07806
# [14]	validation_0-logloss:0.07479
# [15]	validation_0-logloss:0.07185
# [16]	validation_0-logloss:0.06924
# [17]	validation_0-logloss:0.06770
# [18]	validation_0-logloss:0.06561
# [19]	validation_0-logloss:0.06427
# [20]	validation_0-logloss:0.06346
# [21]	validation_0-logloss:0.06171
# [22]	validation_0-logloss:0.06013
# [23]	validation_0-logloss:0.05899
# [24]	validation_0-logloss:0.05776
# [25]	validation_0-logloss:0.05658
# [26]	validation_0-logloss:0.05572
# [27]	validation_0-logloss:0.05529
# [28]	validation_0-logloss:0.05491
# [29]	validation_0-logloss:0.05470
# [30]	validation_0-logloss:0.05470
# [31]	validation_0-logloss:0.05413
# [32]	validation_0-logloss:0.05333
# [33]	validation_0-logloss:0.05287
# [34]	validation_0-logloss:0.05218
# [35]	validation_0-logloss:0.05198
# [36]	validation_0-logloss:0.05212
# [37]	validation_0-logloss:0.05154
# [38]	validation_0-logloss:0.05125
# [39]	validation_0-logloss:0.05146
# [40]	validation_0-logloss:0.05124
# [41]	validation_0-logloss:0.05096
# [42]	validation_0-logloss:0.05085
# [43]	validation_0-logloss:0.05027
# [44]	validation_0-logloss:0.05007
# [45]	validation_0-logloss:0.04976
# [46]	validation_0-logloss:0.04925
# [47]	validation_0-logloss:0.04889
# [48]	validation_0-logloss:0.04905
# [49]	validation_0-logloss:0.04901
# [50]	validation_0-logloss:0.04875
# [51]	validation_0-logloss:0.04881
# [52]	validation_0-logloss:0.04890
# [53]	validation_0-logloss:0.04906
# [54]	validation_0-logloss:0.04884
# [55]	validation_0-logloss:0.04839
# [56]	validation_0-logloss:0.04848
# [57]	validation_0-logloss:0.04854
# [58]	validation_0-logloss:0.04841
# [59]	validation_0-logloss:0.04845
# [60]	validation_0-logloss:0.04842
# [61]	validation_0-logloss:0.04836
# [62]	validation_0-logloss:0.04853
# [63]	validation_0-logloss:0.04887
# [64]	validation_0-logloss:0.04883
# [65]	validation_0-logloss:0.04894
# [66]	validation_0-logloss:0.04920
# [67]	validation_0-logloss:0.04946
# [68]	validation_0-logloss:0.04944
# [0]	validation_0-logloss:0.23238
# [1]	validation_0-logloss:0.19551
# [2]	validation_0-logloss:0.17646
# [3]	validation_0-logloss:0.15532
# [4]	validation_0-logloss:0.14332
# [5]	validation_0-logloss:0.13118
# [6]	validation_0-logloss:0.11874
# [7]	validation_0-logloss:0.10896
# [8]	validation_0-logloss:0.10071
# [9]	validation_0-logloss:0.09444
# [10]	validation_0-logloss:0.08831
# [11]	validation_0-logloss:0.08269
# [12]	validation_0-logloss:0.07753
# [13]	validation_0-logloss:0.07355
# [14]	validation_0-logloss:0.06994
# [15]	validation_0-logloss:0.06664
# [16]	validation_0-logloss:0.06372
# [17]	validation_0-logloss:0.06247
# [18]	validation_0-logloss:0.06080
# [19]	validation_0-logloss:0.05986
# [20]	validation_0-logloss:0.05928
# [21]	validation_0-logloss:0.05825
# [22]	validation_0-logloss:0.05697
# [23]	validation_0-logloss:0.05594
# [24]	validation_0-logloss:0.05495
# [25]	validation_0-logloss:0.05385
# [26]	validation_0-logloss:0.05281
# [27]	validation_0-logloss:0.05224
# [28]	validation_0-logloss:0.05214
# [29]	validation_0-logloss:0.05225
# [30]	validation_0-logloss:0.05232
# [31]	validation_0-logloss:0.05138
# [32]	validation_0-logloss:0.05114
# [33]	validation_0-logloss:0.05038
# [34]	validation_0-logloss:0.05005
# [35]	validation_0-logloss:0.04968
# [36]	validation_0-logloss:0.04957
# [37]	validation_0-logloss:0.04952
# [38]	validation_0-logloss:0.04929
# [39]	validation_0-logloss:0.04923
# [40]	validation_0-logloss:0.04868
# [41]	validation_0-logloss:0.04825
# [42]	validation_0-logloss:0.04804
# [43]	validation_0-logloss:0.04742
# [44]	validation_0-logloss:0.04690
# [45]	validation_0-logloss:0.04568
# [46]	validation_0-logloss:0.04549
# [47]	validation_0-logloss:0.04485
# [48]	validation_0-logloss:0.04513
# [49]	validation_0-logloss:0.04452
# [50]	validation_0-logloss:0.04443
# [51]	validation_0-logloss:0.04436
# [52]	validation_0-logloss:0.04339
# [53]	validation_0-logloss:0.04317
# [54]	validation_0-logloss:0.04304
# [55]	validation_0-logloss:0.04293
# [56]	validation_0-logloss:0.04278
# [57]	validation_0-logloss:0.04288
# [58]	validation_0-logloss:0.04274
# [59]	validation_0-logloss:0.04275
# [60]	validation_0-logloss:0.04260
# [61]	validation_0-logloss:0.04256
# [62]	validation_0-logloss:0.04294
# [63]	validation_0-logloss:0.04271
# [64]	validation_0-logloss:0.04251
# [65]	validation_0-logloss:0.04271
# [66]	validation_0-logloss:0.04277
# [67]	validation_0-logloss:0.04259
# [68]	validation_0-logloss:0.04253
# [69]	validation_0-logloss:0.04274
# [70]	validation_0-logloss:0.04253
# [71]	validation_0-logloss:0.04258
# [72]	validation_0-logloss:0.04255
# [0]	validation_0-logloss:0.22480
# [1]	validation_0-logloss:0.18790
# [2]	validation_0-logloss:0.16920
# [3]	validation_0-logloss:0.14773
# [4]	validation_0-logloss:0.13634
# [5]	validation_0-logloss:0.12440
# [6]	validation_0-logloss:0.11223
# [7]	validation_0-logloss:0.10267
# [8]	validation_0-logloss:0.09474
# [9]	validation_0-logloss:0.08806
# [10]	validation_0-logloss:0.08259
# [11]	validation_0-logloss:0.07750
# [12]	validation_0-logloss:0.07302
# [13]	validation_0-logloss:0.06967
# [14]	validation_0-logloss:0.06671
# [15]	validation_0-logloss:0.06363
# [16]	validation_0-logloss:0.06136
# [17]	validation_0-logloss:0.05994
# [18]	validation_0-logloss:0.05798
# [19]	validation_0-logloss:0.05677
# [20]	validation_0-logloss:0.05599
# [21]	validation_0-logloss:0.05494
# [22]	validation_0-logloss:0.05382
# [23]	validation_0-logloss:0.05209
# [24]	validation_0-logloss:0.05076
# [25]	validation_0-logloss:0.04991
# [26]	validation_0-logloss:0.04941
# [27]	validation_0-logloss:0.04855
# [28]	validation_0-logloss:0.04803
# [29]	validation_0-logloss:0.04799
# [30]	validation_0-logloss:0.04759
# [31]	validation_0-logloss:0.04651
# [32]	validation_0-logloss:0.04585
# [33]	validation_0-logloss:0.04533
# [34]	validation_0-logloss:0.04489
# [35]	validation_0-logloss:0.04450
# [36]	validation_0-logloss:0.04424
# [37]	validation_0-logloss:0.04436
# [38]	validation_0-logloss:0.04411
# [39]	validation_0-logloss:0.04373
# [40]	validation_0-logloss:0.04352
# [41]	validation_0-logloss:0.04326
# [42]	validation_0-logloss:0.04287
# [43]	validation_0-logloss:0.04263
# [44]	validation_0-logloss:0.04242
# [45]	validation_0-logloss:0.04215
# [46]	validation_0-logloss:0.04192
# [47]	validation_0-logloss:0.04140
# [48]	validation_0-logloss:0.04108
# [49]	validation_0-logloss:0.04110
# [50]	validation_0-logloss:0.04068
# [51]	validation_0-logloss:0.04065
# [52]	validation_0-logloss:0.04047
# [53]	validation_0-logloss:0.04050
# [54]	validation_0-logloss:0.04038
# [55]	validation_0-logloss:0.04017
# [56]	validation_0-logloss:0.04017
# [57]	validation_0-logloss:0.03959
# [58]	validation_0-logloss:0.03943
# [59]	validation_0-logloss:0.03936
# [60]	validation_0-logloss:0.03914
# [61]	validation_0-logloss:0.03908
# [62]	validation_0-logloss:0.03890
# [63]	validation_0-logloss:0.03882
# [64]	validation_0-logloss:0.03898
# [65]	validation_0-logloss:0.03898
# [66]	validation_0-logloss:0.03898
# [67]	validation_0-logloss:0.03898
# [68]	validation_0-logloss:0.03894
# [69]	validation_0-logloss:0.03897
# [70]	validation_0-logloss:0.03897
# [71]	validation_0-logloss:0.03894
# [0]	validation_0-logloss:0.24253
# [1]	validation_0-logloss:0.20145
# [2]	validation_0-logloss:0.18060
# [3]	validation_0-logloss:0.15786
# [4]	validation_0-logloss:0.14452
# [5]	validation_0-logloss:0.13225
# [6]	validation_0-logloss:0.11877
# [7]	validation_0-logloss:0.10783
# [8]	validation_0-logloss:0.09890
# [9]	validation_0-logloss:0.09182
# [10]	validation_0-logloss:0.08635
# [11]	validation_0-logloss:0.08038
# [12]	validation_0-logloss:0.07537
# [13]	validation_0-logloss:0.07181
# [14]	validation_0-logloss:0.06912
# [15]	validation_0-logloss:0.06559
# [16]	validation_0-logloss:0.06260
# [17]	validation_0-logloss:0.06086
# [18]	validation_0-logloss:0.05830
# [19]	validation_0-logloss:0.05715
# [20]	validation_0-logloss:0.05581
# [21]	validation_0-logloss:0.05447
# [22]	validation_0-logloss:0.05304
# [23]	validation_0-logloss:0.05142
# [24]	validation_0-logloss:0.05053
# [25]	validation_0-logloss:0.04958
# [26]	validation_0-logloss:0.04896
# [27]	validation_0-logloss:0.04846
# [28]	validation_0-logloss:0.04779
# [29]	validation_0-logloss:0.04744
# [30]	validation_0-logloss:0.04715
# [31]	validation_0-logloss:0.04632
# [32]	validation_0-logloss:0.04539
# [33]	validation_0-logloss:0.04464
# [34]	validation_0-logloss:0.04421
# [35]	validation_0-logloss:0.04402
# [36]	validation_0-logloss:0.04389
# [37]	validation_0-logloss:0.04377
# [38]	validation_0-logloss:0.04333
# [39]	validation_0-logloss:0.04348
# [40]	validation_0-logloss:0.04277
# [41]	validation_0-logloss:0.04249
# [42]	validation_0-logloss:0.04246
# [43]	validation_0-logloss:0.04214
# [44]	validation_0-logloss:0.04220
# [45]	validation_0-logloss:0.04166
# [46]	validation_0-logloss:0.04162
# [47]	validation_0-logloss:0.04088
# [48]	validation_0-logloss:0.04075
# [49]	validation_0-logloss:0.04032
# [50]	validation_0-logloss:0.03989
# [51]	validation_0-logloss:0.03980
# [52]	validation_0-logloss:0.03975
# [53]	validation_0-logloss:0.03976
# [54]	validation_0-logloss:0.03974
# [55]	validation_0-logloss:0.03950
# [56]	validation_0-logloss:0.03970
# [57]	validation_0-logloss:0.03978
# [58]	validation_0-logloss:0.03903
# [59]	validation_0-logloss:0.03901
# [60]	validation_0-logloss:0.03906
# [61]	validation_0-logloss:0.03870
# [62]	validation_0-logloss:0.03869
# [63]	validation_0-logloss:0.03808
# [64]	validation_0-logloss:0.03805
# [65]	validation_0-logloss:0.03809
# [66]	validation_0-logloss:0.03810
# [67]	validation_0-logloss:0.03813
# [68]	validation_0-logloss:0.03751
# [69]	validation_0-logloss:0.03723
# [70]	validation_0-logloss:0.03693
# [71]	validation_0-logloss:0.03687
# [72]	validation_0-logloss:0.03670
# [73]	validation_0-logloss:0.03671
# [74]	validation_0-logloss:0.03674
# [75]	validation_0-logloss:0.03690
# [76]	validation_0-logloss:0.03690
# [77]	validation_0-logloss:0.03691
# [78]	validation_0-logloss:0.03691
# [79]	validation_0-logloss:0.03690
# [80]	validation_0-logloss:0.03691
# [0]	validation_0-logloss:0.23672
# [1]	validation_0-logloss:0.19979
# [2]	validation_0-logloss:0.18124
# [3]	validation_0-logloss:0.15934
# [4]	validation_0-logloss:0.14775
# [5]	validation_0-logloss:0.13535
# [6]	validation_0-logloss:0.12281
# [7]	validation_0-logloss:0.11298
# [8]	validation_0-logloss:0.10397
# [9]	validation_0-logloss:0.09658
# [10]	validation_0-logloss:0.09094
# [11]	validation_0-logloss:0.08529
# [12]	validation_0-logloss:0.08060
# [13]	validation_0-logloss:0.07715
# [14]	validation_0-logloss:0.07456
# [15]	validation_0-logloss:0.07127
# [16]	validation_0-logloss:0.06926
# [17]	validation_0-logloss:0.06782
# [18]	validation_0-logloss:0.06599
# [19]	validation_0-logloss:0.06518
# [20]	validation_0-logloss:0.06454
# [21]	validation_0-logloss:0.06270
# [22]	validation_0-logloss:0.06096
# [23]	validation_0-logloss:0.05985
# [24]	validation_0-logloss:0.05870
# [25]	validation_0-logloss:0.05781
# [26]	validation_0-logloss:0.05688
# [27]	validation_0-logloss:0.05666
# [28]	validation_0-logloss:0.05633
# [29]	validation_0-logloss:0.05601
# [30]	validation_0-logloss:0.05572
# [31]	validation_0-logloss:0.05472
# [32]	validation_0-logloss:0.05376
# [33]	validation_0-logloss:0.05317
# [34]	validation_0-logloss:0.05284
# [35]	validation_0-logloss:0.05281
# [36]	validation_0-logloss:0.05262
# [37]	validation_0-logloss:0.05219
# [38]	validation_0-logloss:0.05178
# [39]	validation_0-logloss:0.05153
# [40]	validation_0-logloss:0.05101
# [41]	validation_0-logloss:0.05021
# [42]	validation_0-logloss:0.05009
# [43]	validation_0-logloss:0.04950
# [44]	validation_0-logloss:0.04907
# [45]	validation_0-logloss:0.04866
# [46]	validation_0-logloss:0.04816
# [47]	validation_0-logloss:0.04820
# [48]	validation_0-logloss:0.04812
# [49]	validation_0-logloss:0.04691
# [50]	validation_0-logloss:0.04674
# [51]	validation_0-logloss:0.04598
# [52]	validation_0-logloss:0.04582
# [53]	validation_0-logloss:0.04559
# [54]	validation_0-logloss:0.04561
# [55]	validation_0-logloss:0.04547
# [56]	validation_0-logloss:0.04543
# [57]	validation_0-logloss:0.04542
# [58]	validation_0-logloss:0.04518
# [59]	validation_0-logloss:0.04485
# [60]	validation_0-logloss:0.04480
# [61]	validation_0-logloss:0.04469
# [62]	validation_0-logloss:0.04442
# [63]	validation_0-logloss:0.04425
# [64]	validation_0-logloss:0.04447
# [65]	validation_0-logloss:0.04407
# [66]	validation_0-logloss:0.04388
# [67]	validation_0-logloss:0.04388
# [68]	validation_0-logloss:0.04393
# [69]	validation_0-logloss:0.04372
# [70]	validation_0-logloss:0.04370
# [71]	validation_0-logloss:0.04339
# [72]	validation_0-logloss:0.04344
# [73]	validation_0-logloss:0.04344
# [74]	validation_0-logloss:0.04344
# [75]	validation_0-logloss:0.04307
# [76]	validation_0-logloss:0.04310
# [77]	validation_0-logloss:0.04304
# [78]	validation_0-logloss:0.04305
# [79]	validation_0-logloss:0.04311
# [80]	validation_0-logloss:0.04314
# [81]	validation_0-logloss:0.04314
# [82]	validation_0-logloss:0.04316
# [83]	validation_0-logloss:0.04316
# [84]	validation_0-logloss:0.04312
# [85]	validation_0-logloss:0.04313
# [0]	validation_0-logloss:0.22470
# [1]	validation_0-logloss:0.18852
# [2]	validation_0-logloss:0.16811
# [3]	validation_0-logloss:0.14740
# [4]	validation_0-logloss:0.13465
# [5]	validation_0-logloss:0.12251
# [6]	validation_0-logloss:0.11057
# [7]	validation_0-logloss:0.10048
# [8]	validation_0-logloss:0.09218
# [9]	validation_0-logloss:0.08518
# [10]	validation_0-logloss:0.07977
# [11]	validation_0-logloss:0.07433
# [12]	validation_0-logloss:0.07016
# [13]	validation_0-logloss:0.06706
# [14]	validation_0-logloss:0.06413
# [15]	validation_0-logloss:0.06138
# [16]	validation_0-logloss:0.05870
# [17]	validation_0-logloss:0.05741
# [18]	validation_0-logloss:0.05543
# [19]	validation_0-logloss:0.05470
# [20]	validation_0-logloss:0.05375
# [21]	validation_0-logloss:0.05218
# [22]	validation_0-logloss:0.05069
# [23]	validation_0-logloss:0.04984
# [24]	validation_0-logloss:0.04862
# [25]	validation_0-logloss:0.04842
# [26]	validation_0-logloss:0.04760
# [27]	validation_0-logloss:0.04749
# [28]	validation_0-logloss:0.04721
# [29]	validation_0-logloss:0.04691
# [30]	validation_0-logloss:0.04670
# [31]	validation_0-logloss:0.04606
# [32]	validation_0-logloss:0.04534
# [33]	validation_0-logloss:0.04481
# [34]	validation_0-logloss:0.04396
# [35]	validation_0-logloss:0.04417
# [36]	validation_0-logloss:0.04383
# [37]	validation_0-logloss:0.04402
# [38]	validation_0-logloss:0.04359
# [39]	validation_0-logloss:0.04361
# [40]	validation_0-logloss:0.04296
# [41]	validation_0-logloss:0.04277
# [42]	validation_0-logloss:0.04253
# [43]	validation_0-logloss:0.04297
# [44]	validation_0-logloss:0.04252
# [45]	validation_0-logloss:0.04249
# [46]	validation_0-logloss:0.04245
# [47]	validation_0-logloss:0.04253
# [48]	validation_0-logloss:0.04198
# [49]	validation_0-logloss:0.04173
# [50]	validation_0-logloss:0.04185
# [51]	validation_0-logloss:0.04171
# [52]	validation_0-logloss:0.04132
# [53]	validation_0-logloss:0.04115
# [54]	validation_0-logloss:0.04066
# [55]	validation_0-logloss:0.04033
# [56]	validation_0-logloss:0.04037
# [57]	validation_0-logloss:0.04017
# [58]	validation_0-logloss:0.03984
# [59]	validation_0-logloss:0.03985
# [60]	validation_0-logloss:0.03972
# [61]	validation_0-logloss:0.03965
# [62]	validation_0-logloss:0.04030
# [63]	validation_0-logloss:0.04001
# [64]	validation_0-logloss:0.03969
# [65]	validation_0-logloss:0.03956
# [66]	validation_0-logloss:0.03960
# [67]	validation_0-logloss:0.03968
# [68]	validation_0-logloss:0.03959
# [69]	validation_0-logloss:0.03954
# [70]	validation_0-logloss:0.03954
# [71]	validation_0-logloss:0.03960
# [72]	validation_0-logloss:0.03959
# [73]	validation_0-logloss:0.03962
# [74]	validation_0-logloss:0.03965
# [75]	validation_0-logloss:0.03902
# [76]	validation_0-logloss:0.03905
# [77]	validation_0-logloss:0.03905
# [78]	validation_0-logloss:0.03905
# [79]	validation_0-logloss:0.03914
# [80]	validation_0-logloss:0.03914
# [81]	validation_0-logloss:0.03916
# [82]	validation_0-logloss:0.03967
# [0]	validation_0-logloss:0.25979
# [1]	validation_0-logloss:0.21559
# [2]	validation_0-logloss:0.19349
# [3]	validation_0-logloss:0.16964
# [4]	validation_0-logloss:0.15630
# [5]	validation_0-logloss:0.14327
# [6]	validation_0-logloss:0.12950
# [7]	validation_0-logloss:0.11854
# [8]	validation_0-logloss:0.10914
# [9]	validation_0-logloss:0.10159
# [10]	validation_0-logloss:0.09613
# [11]	validation_0-logloss:0.09045
# [12]	validation_0-logloss:0.08535
# [13]	validation_0-logloss:0.08213
# [14]	validation_0-logloss:0.07910
# [15]	validation_0-logloss:0.07514
# [16]	validation_0-logloss:0.07279
# [17]	validation_0-logloss:0.07145
# [18]	validation_0-logloss:0.06964
# [19]	validation_0-logloss:0.06837
# [20]	validation_0-logloss:0.06767
# [21]	validation_0-logloss:0.06537
# [22]	validation_0-logloss:0.06359
# [23]	validation_0-logloss:0.06253
# [24]	validation_0-logloss:0.06160
# [25]	validation_0-logloss:0.06060
# [26]	validation_0-logloss:0.05986
# [27]	validation_0-logloss:0.05971
# [28]	validation_0-logloss:0.05922
# [29]	validation_0-logloss:0.05883
# [30]	validation_0-logloss:0.05866
# [31]	validation_0-logloss:0.05777
# [32]	validation_0-logloss:0.05684
# [33]	validation_0-logloss:0.05620
# [34]	validation_0-logloss:0.05572
# [35]	validation_0-logloss:0.05557
# [36]	validation_0-logloss:0.05549
# [37]	validation_0-logloss:0.05502
# [38]	validation_0-logloss:0.05472
# [39]	validation_0-logloss:0.05445
# [40]	validation_0-logloss:0.05407
# [41]	validation_0-logloss:0.05382
# [42]	validation_0-logloss:0.05322
# [43]	validation_0-logloss:0.05297
# [44]	validation_0-logloss:0.05275
# [45]	validation_0-logloss:0.05229
# [46]	validation_0-logloss:0.05208
# [47]	validation_0-logloss:0.05197
# [48]	validation_0-logloss:0.05161
# [49]	validation_0-logloss:0.05220
# [50]	validation_0-logloss:0.05165
# [51]	validation_0-logloss:0.05165
# [52]	validation_0-logloss:0.05156
# [53]	validation_0-logloss:0.05137
# [54]	validation_0-logloss:0.05096
# [55]	validation_0-logloss:0.05118
# [56]	validation_0-logloss:0.05121
# [57]	validation_0-logloss:0.05080
# [58]	validation_0-logloss:0.05080
# [59]	validation_0-logloss:0.05058
# [60]	validation_0-logloss:0.05012
# [61]	validation_0-logloss:0.05011
# [62]	validation_0-logloss:0.05007
# [63]	validation_0-logloss:0.04967
# [64]	validation_0-logloss:0.04955
# [65]	validation_0-logloss:0.04944
# [66]	validation_0-logloss:0.04927
# [67]	validation_0-logloss:0.04925
# [68]	validation_0-logloss:0.04925
# [69]	validation_0-logloss:0.04930
# [70]	validation_0-logloss:0.04931
# [71]	validation_0-logloss:0.04896
# [72]	validation_0-logloss:0.04911
# [73]	validation_0-logloss:0.04911
# [74]	validation_0-logloss:0.04906
# [75]	validation_0-logloss:0.04911
# [76]	validation_0-logloss:0.04913
# [77]	validation_0-logloss:0.04912
# [78]	validation_0-logloss:0.04854
# [79]	validation_0-logloss:0.04857
# [80]	validation_0-logloss:0.04869
# [81]	validation_0-logloss:0.04873
# [82]	validation_0-logloss:0.04858
# [83]	validation_0-logloss:0.04857
# [84]	validation_0-logloss:0.04857
# [85]	validation_0-logloss:0.04842
# [86]	validation_0-logloss:0.04840
# [87]	validation_0-logloss:0.04843
# [88]	validation_0-logloss:0.04826
# [89]	validation_0-logloss:0.04826
# [90]	validation_0-logloss:0.04826
# [91]	validation_0-logloss:0.04824
# [92]	validation_0-logloss:0.04838
# [93]	validation_0-logloss:0.04835
# [94]	validation_0-logloss:0.04850
# [95]	validation_0-logloss:0.04849
# [96]	validation_0-logloss:0.04849
# [97]	validation_0-logloss:0.04849
# [98]	validation_0-logloss:0.04847
# [0]	validation_0-logloss:0.24840
# [1]	validation_0-logloss:0.20697
# [2]	validation_0-logloss:0.18672
# [3]	validation_0-logloss:0.16439
# [4]	validation_0-logloss:0.15177
# [5]	validation_0-logloss:0.13963
# [6]	validation_0-logloss:0.12672
# [7]	validation_0-logloss:0.11656
# [8]	validation_0-logloss:0.10777
# [9]	validation_0-logloss:0.10049
# [10]	validation_0-logloss:0.09440
# [11]	validation_0-logloss:0.08831
# [12]	validation_0-logloss:0.08419
# [13]	validation_0-logloss:0.08077
# [14]	validation_0-logloss:0.07778
# [15]	validation_0-logloss:0.07490
# [16]	validation_0-logloss:0.07223
# [17]	validation_0-logloss:0.07159
# [18]	validation_0-logloss:0.06950
# [19]	validation_0-logloss:0.06892
# [20]	validation_0-logloss:0.06836
# [21]	validation_0-logloss:0.06692
# [22]	validation_0-logloss:0.06555
# [23]	validation_0-logloss:0.06452
# [24]	validation_0-logloss:0.06357
# [25]	validation_0-logloss:0.06275
# [26]	validation_0-logloss:0.06181
# [27]	validation_0-logloss:0.06182
# [28]	validation_0-logloss:0.06204
# [29]	validation_0-logloss:0.06220
# [30]	validation_0-logloss:0.06222
# [31]	validation_0-logloss:0.06121
# [32]	validation_0-logloss:0.06038
# [33]	validation_0-logloss:0.05972
# [34]	validation_0-logloss:0.05908
# [35]	validation_0-logloss:0.05917
# [36]	validation_0-logloss:0.05921
# [37]	validation_0-logloss:0.05932
# [38]	validation_0-logloss:0.05884
# [39]	validation_0-logloss:0.05911
# [40]	validation_0-logloss:0.05866
# [41]	validation_0-logloss:0.05806
# [42]	validation_0-logloss:0.05798
# [43]	validation_0-logloss:0.05787
# [44]	validation_0-logloss:0.05788
# [45]	validation_0-logloss:0.05789
# [46]	validation_0-logloss:0.05738
# [47]	validation_0-logloss:0.05673
# [48]	validation_0-logloss:0.05601
# [49]	validation_0-logloss:0.05559
# [50]	validation_0-logloss:0.05529
# [51]	validation_0-logloss:0.05534
# [52]	validation_0-logloss:0.05440
# [53]	validation_0-logloss:0.05391
# [54]	validation_0-logloss:0.05330
# [55]	validation_0-logloss:0.05359
# [56]	validation_0-logloss:0.05366
# [57]	validation_0-logloss:0.05374
# [58]	validation_0-logloss:0.05345
# [59]	validation_0-logloss:0.05330
# [60]	validation_0-logloss:0.05279
# [61]	validation_0-logloss:0.05302
# [62]	validation_0-logloss:0.05247
# [63]	validation_0-logloss:0.05238
# [64]	validation_0-logloss:0.05201
# [65]	validation_0-logloss:0.05192
# [66]	validation_0-logloss:0.05185
# [67]	validation_0-logloss:0.05189
# [68]	validation_0-logloss:0.05190
# [69]	validation_0-logloss:0.05215
# [70]	validation_0-logloss:0.05224
# [71]	validation_0-logloss:0.05224
# [72]	validation_0-logloss:0.05210
# [73]	validation_0-logloss:0.05212
# [74]	validation_0-logloss:0.05217
# [0]	validation_0-logloss:0.24450
# [1]	validation_0-logloss:0.20825
# [2]	validation_0-logloss:0.19028
# [3]	validation_0-logloss:0.17037
# [4]	validation_0-logloss:0.15904
# [5]	validation_0-logloss:0.14751
# [6]	validation_0-logloss:0.13564
# [7]	validation_0-logloss:0.12553
# [8]	validation_0-logloss:0.11773
# [9]	validation_0-logloss:0.10996
# [10]	validation_0-logloss:0.10551
# [11]	validation_0-logloss:0.10046
# [12]	validation_0-logloss:0.09670
# [13]	validation_0-logloss:0.09322
# [14]	validation_0-logloss:0.09092
# [15]	validation_0-logloss:0.08838
# [16]	validation_0-logloss:0.08547
# [17]	validation_0-logloss:0.08420
# [18]	validation_0-logloss:0.08287
# [19]	validation_0-logloss:0.08214
# [20]	validation_0-logloss:0.08228
# [21]	validation_0-logloss:0.07996
# [22]	validation_0-logloss:0.07806
# [23]	validation_0-logloss:0.07758
# [24]	validation_0-logloss:0.07617
# [25]	validation_0-logloss:0.07521
# [26]	validation_0-logloss:0.07440
# [27]	validation_0-logloss:0.07448
# [28]	validation_0-logloss:0.07466
# [29]	validation_0-logloss:0.07538
# [30]	validation_0-logloss:0.07553
# [31]	validation_0-logloss:0.07494
# [32]	validation_0-logloss:0.07363
# [33]	validation_0-logloss:0.07386
# [34]	validation_0-logloss:0.07317
# [35]	validation_0-logloss:0.07268
# [36]	validation_0-logloss:0.07280
# [37]	validation_0-logloss:0.07355
# [38]	validation_0-logloss:0.07236
# [39]	validation_0-logloss:0.07247
# [40]	validation_0-logloss:0.07182
# [41]	validation_0-logloss:0.07138
# [42]	validation_0-logloss:0.07167
# [43]	validation_0-logloss:0.07122
# [44]	validation_0-logloss:0.07153
# [45]	validation_0-logloss:0.07113
# [46]	validation_0-logloss:0.07070
# [47]	validation_0-logloss:0.07004
# [48]	validation_0-logloss:0.06945
# [49]	validation_0-logloss:0.06948
# [50]	validation_0-logloss:0.06896
# [51]	validation_0-logloss:0.06844
# [52]	validation_0-logloss:0.06862
# [53]	validation_0-logloss:0.06819
# [54]	validation_0-logloss:0.06816
# [55]	validation_0-logloss:0.06802
# [56]	validation_0-logloss:0.06809
# [57]	validation_0-logloss:0.06816
# [58]	validation_0-logloss:0.06812
# [59]	validation_0-logloss:0.06773
# [60]	validation_0-logloss:0.06771
# [61]	validation_0-logloss:0.06747
# [62]	validation_0-logloss:0.06748
# [63]	validation_0-logloss:0.06735
# [64]	validation_0-logloss:0.06732
# [65]	validation_0-logloss:0.06727
# [66]	validation_0-logloss:0.06689
# [67]	validation_0-logloss:0.06742
# [68]	validation_0-logloss:0.06728
# [69]	validation_0-logloss:0.06731
# [70]	validation_0-logloss:0.06736
# [71]	validation_0-logloss:0.06735
# [72]	validation_0-logloss:0.06742
# [73]	validation_0-logloss:0.06748
# [74]	validation_0-logloss:0.06722
# [0]	validation_0-logloss:0.24104
# [1]	validation_0-logloss:0.20321
# [2]	validation_0-logloss:0.18443
# [3]	validation_0-logloss:0.16341
# [4]	validation_0-logloss:0.15203
# [5]	validation_0-logloss:0.13872
# [6]	validation_0-logloss:0.12696
# [7]	validation_0-logloss:0.11722
# [8]	validation_0-logloss:0.10948
# [9]	validation_0-logloss:0.10291
# [10]	validation_0-logloss:0.09746
# [11]	validation_0-logloss:0.09188
# [12]	validation_0-logloss:0.08767
# [13]	validation_0-logloss:0.08408
# [14]	validation_0-logloss:0.08129
# [15]	validation_0-logloss:0.07796
# [16]	validation_0-logloss:0.07549
# [17]	validation_0-logloss:0.07443
# [18]	validation_0-logloss:0.07218
# [19]	validation_0-logloss:0.07134
# [20]	validation_0-logloss:0.07099
# [21]	validation_0-logloss:0.06870
# [22]	validation_0-logloss:0.06710
# [23]	validation_0-logloss:0.06618
# [24]	validation_0-logloss:0.06573
# [25]	validation_0-logloss:0.06471
# [26]	validation_0-logloss:0.06383
# [27]	validation_0-logloss:0.06375
# [28]	validation_0-logloss:0.06365
# [29]	validation_0-logloss:0.06355
# [30]	validation_0-logloss:0.06337
# [31]	validation_0-logloss:0.06261
# [32]	validation_0-logloss:0.06213
# [33]	validation_0-logloss:0.06142
# [34]	validation_0-logloss:0.06094
# [35]	validation_0-logloss:0.06125
# [36]	validation_0-logloss:0.06136
# [37]	validation_0-logloss:0.06158
# [38]	validation_0-logloss:0.06067
# [39]	validation_0-logloss:0.06060
# [40]	validation_0-logloss:0.06018
# [41]	validation_0-logloss:0.05961
# [42]	validation_0-logloss:0.05917
# [43]	validation_0-logloss:0.05862
# [44]	validation_0-logloss:0.05780
# [45]	validation_0-logloss:0.05723
# [46]	validation_0-logloss:0.05660
# [47]	validation_0-logloss:0.05607
# [48]	validation_0-logloss:0.05563
# [49]	validation_0-logloss:0.05501
# [50]	validation_0-logloss:0.05465
# [51]	validation_0-logloss:0.05450
# [52]	validation_0-logloss:0.05420
# [53]	validation_0-logloss:0.05413
# [54]	validation_0-logloss:0.05405
# [55]	validation_0-logloss:0.05389
# [56]	validation_0-logloss:0.05387
# [57]	validation_0-logloss:0.05395
# [58]	validation_0-logloss:0.05337
# [59]	validation_0-logloss:0.05292
# [60]	validation_0-logloss:0.05213
# [61]	validation_0-logloss:0.05197
# [62]	validation_0-logloss:0.05202
# [63]	validation_0-logloss:0.05154
# [64]	validation_0-logloss:0.05171
# [65]	validation_0-logloss:0.05170
# [66]	validation_0-logloss:0.05175
# [67]	validation_0-logloss:0.05175
# [68]	validation_0-logloss:0.05180
# [69]	validation_0-logloss:0.05117
# [70]	validation_0-logloss:0.05083
# [71]	validation_0-logloss:0.05084
# [72]	validation_0-logloss:0.05064
# [73]	validation_0-logloss:0.05065
# [74]	validation_0-logloss:0.05066
# [75]	validation_0-logloss:0.05074
# [76]	validation_0-logloss:0.05077
# [77]	validation_0-logloss:0.05086
# [78]	validation_0-logloss:0.05087
# [79]	validation_0-logloss:0.05083
# [80]	validation_0-logloss:0.05088
# [0]	validation_0-logloss:0.26335
# [1]	validation_0-logloss:0.22057
# [2]	validation_0-logloss:0.19972
# [3]	validation_0-logloss:0.17674
# [4]	validation_0-logloss:0.16445
# [5]	validation_0-logloss:0.15095
# [6]	validation_0-logloss:0.13774
# [7]	validation_0-logloss:0.12751
# [8]	validation_0-logloss:0.11893
# [9]	validation_0-logloss:0.11193
# [10]	validation_0-logloss:0.10646
# [11]	validation_0-logloss:0.10120
# [12]	validation_0-logloss:0.09682
# [13]	validation_0-logloss:0.09347
# [14]	validation_0-logloss:0.09063
# [15]	validation_0-logloss:0.08735
# [16]	validation_0-logloss:0.08495
# [17]	validation_0-logloss:0.08380
# [18]	validation_0-logloss:0.08086
# [19]	validation_0-logloss:0.08035
# [20]	validation_0-logloss:0.08001
# [21]	validation_0-logloss:0.07869
# [22]	validation_0-logloss:0.07663
# [23]	validation_0-logloss:0.07534
# [24]	validation_0-logloss:0.07438
# [25]	validation_0-logloss:0.07367
# [26]	validation_0-logloss:0.07219
# [27]	validation_0-logloss:0.07238
# [28]	validation_0-logloss:0.07269
# [29]	validation_0-logloss:0.07296
# [30]	validation_0-logloss:0.07305
# [31]	validation_0-logloss:0.07206
# [32]	validation_0-logloss:0.07164
# [33]	validation_0-logloss:0.07127
# [34]	validation_0-logloss:0.07068
# [35]	validation_0-logloss:0.07081
# [36]	validation_0-logloss:0.07093
# [37]	validation_0-logloss:0.07097
# [38]	validation_0-logloss:0.06975
# [39]	validation_0-logloss:0.06982
# [40]	validation_0-logloss:0.06870
# [41]	validation_0-logloss:0.06771
# [42]	validation_0-logloss:0.06704
# [43]	validation_0-logloss:0.06690
# [44]	validation_0-logloss:0.06679
# [45]	validation_0-logloss:0.06673
# [46]	validation_0-logloss:0.06654
# [47]	validation_0-logloss:0.06588
# [48]	validation_0-logloss:0.06585
# [49]	validation_0-logloss:0.06550
# [50]	validation_0-logloss:0.06453
# [51]	validation_0-logloss:0.06357
# [52]	validation_0-logloss:0.06302
# [53]	validation_0-logloss:0.06309
# [54]	validation_0-logloss:0.06233
# [55]	validation_0-logloss:0.06246
# [56]	validation_0-logloss:0.06251
# [57]	validation_0-logloss:0.06260
# [58]	validation_0-logloss:0.06228
# [59]	validation_0-logloss:0.06182
# [60]	validation_0-logloss:0.06183
# [61]	validation_0-logloss:0.06178
# [62]	validation_0-logloss:0.06172
# [63]	validation_0-logloss:0.06170
# [64]	validation_0-logloss:0.06165
# [65]	validation_0-logloss:0.06193
# [66]	validation_0-logloss:0.06172
# [67]	validation_0-logloss:0.06166
# [68]	validation_0-logloss:0.06146
# [69]	validation_0-logloss:0.06146
# [70]	validation_0-logloss:0.06105
# [71]	validation_0-logloss:0.06106
# [72]	validation_0-logloss:0.06108
# [73]	validation_0-logloss:0.06105
# [74]	validation_0-logloss:0.06120
# [75]	validation_0-logloss:0.06121
# [76]	validation_0-logloss:0.06122
# [77]	validation_0-logloss:0.06090
# [78]	validation_0-logloss:0.06092
# [79]	validation_0-logloss:0.06093
# [80]	validation_0-logloss:0.06065
# [81]	validation_0-logloss:0.06066
# [82]	validation_0-logloss:0.06088
# [83]	validation_0-logloss:0.06129
# [84]	validation_0-logloss:0.06129
# [85]	validation_0-logloss:0.06129
# [86]	validation_0-logloss:0.06131
# [87]	validation_0-logloss:0.06130
# [0]	validation_0-logloss:0.25340
# [1]	validation_0-logloss:0.21176
# [2]	validation_0-logloss:0.19220
# [3]	validation_0-logloss:0.16994
# [4]	validation_0-logloss:0.15778
# [5]	validation_0-logloss:0.14527
# [6]	validation_0-logloss:0.13250
# [7]	validation_0-logloss:0.12146
# [8]	validation_0-logloss:0.11304
# [9]	validation_0-logloss:0.10612
# [10]	validation_0-logloss:0.10082
# [11]	validation_0-logloss:0.09589
# [12]	validation_0-logloss:0.09100
# [13]	validation_0-logloss:0.08777
# [14]	validation_0-logloss:0.08444
# [15]	validation_0-logloss:0.08170
# [16]	validation_0-logloss:0.07934
# [17]	validation_0-logloss:0.07803
# [18]	validation_0-logloss:0.07621
# [19]	validation_0-logloss:0.07537
# [20]	validation_0-logloss:0.07481
# [21]	validation_0-logloss:0.07344
# [22]	validation_0-logloss:0.07175
# [23]	validation_0-logloss:0.07034
# [24]	validation_0-logloss:0.06921
# [25]	validation_0-logloss:0.06823
# [26]	validation_0-logloss:0.06745
# [27]	validation_0-logloss:0.06742
# [28]	validation_0-logloss:0.06738
# [29]	validation_0-logloss:0.06723
# [30]	validation_0-logloss:0.06656
# [31]	validation_0-logloss:0.06584
# [32]	validation_0-logloss:0.06524
# [33]	validation_0-logloss:0.06496
# [34]	validation_0-logloss:0.06431
# [35]	validation_0-logloss:0.06406
# [36]	validation_0-logloss:0.06420
# [37]	validation_0-logloss:0.06419
# [38]	validation_0-logloss:0.06331
# [39]	validation_0-logloss:0.06348
# [40]	validation_0-logloss:0.06291
# [41]	validation_0-logloss:0.06239
# [42]	validation_0-logloss:0.06205
# [43]	validation_0-logloss:0.06148
# [44]	validation_0-logloss:0.06106
# [45]	validation_0-logloss:0.06072
# [46]	validation_0-logloss:0.06027
# [47]	validation_0-logloss:0.06003
# [48]	validation_0-logloss:0.05967
# [49]	validation_0-logloss:0.05953
# [50]	validation_0-logloss:0.05954
# [51]	validation_0-logloss:0.05932
# [52]	validation_0-logloss:0.05904
# [53]	validation_0-logloss:0.05891
# [54]	validation_0-logloss:0.05878
# [55]	validation_0-logloss:0.05893
# [56]	validation_0-logloss:0.05879
# [57]	validation_0-logloss:0.05898
# [58]	validation_0-logloss:0.05875
# [59]	validation_0-logloss:0.05852
# [60]	validation_0-logloss:0.05781
# [61]	validation_0-logloss:0.05742
# [62]	validation_0-logloss:0.05716
# [63]	validation_0-logloss:0.05737
# [64]	validation_0-logloss:0.05731
# [65]	validation_0-logloss:0.05751
# [66]	validation_0-logloss:0.05751
# [67]	validation_0-logloss:0.05755
# [68]	validation_0-logloss:0.05730
# [69]	validation_0-logloss:0.05711
# [70]	validation_0-logloss:0.05716
# [71]	validation_0-logloss:0.05718
# [72]	validation_0-logloss:0.05697
# [73]	validation_0-logloss:0.05698
# [74]	validation_0-logloss:0.05721
# [75]	validation_0-logloss:0.05721
# [76]	validation_0-logloss:0.05736
# [77]	validation_0-logloss:0.05735
# [78]	validation_0-logloss:0.05723
# [79]	validation_0-logloss:0.05695
# [80]	validation_0-logloss:0.05695
# [81]	validation_0-logloss:0.05696
# [82]	validation_0-logloss:0.05680
# [83]	validation_0-logloss:0.05681
# [84]	validation_0-logloss:0.05690
# [85]	validation_0-logloss:0.05648
# [86]	validation_0-logloss:0.05661
# [87]	validation_0-logloss:0.05661
# [88]	validation_0-logloss:0.05660
# [89]	validation_0-logloss:0.05660
# [90]	validation_0-logloss:0.05682
# [91]	validation_0-logloss:0.05683
# [92]	validation_0-logloss:0.05691
# [93]	validation_0-logloss:0.05692
# [0]	validation_0-logloss:0.23540
# [1]	validation_0-logloss:0.19647
# [2]	validation_0-logloss:0.17778
# [3]	validation_0-logloss:0.15631
# [4]	validation_0-logloss:0.14493
# [5]	validation_0-logloss:0.13302
# [6]	validation_0-logloss:0.12098
# [7]	validation_0-logloss:0.11111
# [8]	validation_0-logloss:0.10270
# [9]	validation_0-logloss:0.09637
# [10]	validation_0-logloss:0.09116
# [11]	validation_0-logloss:0.08582
# [12]	validation_0-logloss:0.08134
# [13]	validation_0-logloss:0.07842
# [14]	validation_0-logloss:0.07557
# [15]	validation_0-logloss:0.07262
# [16]	validation_0-logloss:0.07033
# [17]	validation_0-logloss:0.06943
# [18]	validation_0-logloss:0.06753
# [19]	validation_0-logloss:0.06637
# [20]	validation_0-logloss:0.06551
# [21]	validation_0-logloss:0.06459
# [22]	validation_0-logloss:0.06259
# [23]	validation_0-logloss:0.06179
# [24]	validation_0-logloss:0.06081
# [25]	validation_0-logloss:0.05938
# [26]	validation_0-logloss:0.05805
# [27]	validation_0-logloss:0.05795
# [28]	validation_0-logloss:0.05766
# [29]	validation_0-logloss:0.05758
# [30]	validation_0-logloss:0.05762
# [31]	validation_0-logloss:0.05719
# [32]	validation_0-logloss:0.05654
# [33]	validation_0-logloss:0.05620
# [34]	validation_0-logloss:0.05549
# [35]	validation_0-logloss:0.05543
# [36]	validation_0-logloss:0.05536
# [37]	validation_0-logloss:0.05512
# [38]	validation_0-logloss:0.05494
# [39]	validation_0-logloss:0.05478
# [40]	validation_0-logloss:0.05397
# [41]	validation_0-logloss:0.05374
# [42]	validation_0-logloss:0.05311
# [43]	validation_0-logloss:0.05265
# [44]	validation_0-logloss:0.05221
# [45]	validation_0-logloss:0.05166
# [46]	validation_0-logloss:0.05137
# [47]	validation_0-logloss:0.05115
# [48]	validation_0-logloss:0.05104
# [49]	validation_0-logloss:0.05083
# [50]	validation_0-logloss:0.05047
# [51]	validation_0-logloss:0.05065
# [52]	validation_0-logloss:0.05040
# [53]	validation_0-logloss:0.05037
# [54]	validation_0-logloss:0.04988
# [55]	validation_0-logloss:0.04969
# [56]	validation_0-logloss:0.04968
# [57]	validation_0-logloss:0.04939
# [58]	validation_0-logloss:0.04908
# [59]	validation_0-logloss:0.04878
# [60]	validation_0-logloss:0.04856
# [61]	validation_0-logloss:0.04845
# [62]	validation_0-logloss:0.04846
# [63]	validation_0-logloss:0.04845
# [64]	validation_0-logloss:0.04808
# [65]	validation_0-logloss:0.04765
# [66]	validation_0-logloss:0.04764
# [67]	validation_0-logloss:0.04763
# [68]	validation_0-logloss:0.04734
# [69]	validation_0-logloss:0.04681
# [70]	validation_0-logloss:0.04683
# [71]	validation_0-logloss:0.04697
# [72]	validation_0-logloss:0.04706
# [73]	validation_0-logloss:0.04711
# [74]	validation_0-logloss:0.04706
# [75]	validation_0-logloss:0.04707
# [76]	validation_0-logloss:0.04706
# [77]	validation_0-logloss:0.04707
# [0]	validation_0-logloss:0.25063
# [1]	validation_0-logloss:0.20845
# [2]	validation_0-logloss:0.18622
# [3]	validation_0-logloss:0.16285
# [4]	validation_0-logloss:0.14903
# [5]	validation_0-logloss:0.13670
# [6]	validation_0-logloss:0.12343
# [7]	validation_0-logloss:0.11360
# [8]	validation_0-logloss:0.10465
# [9]	validation_0-logloss:0.09761
# [10]	validation_0-logloss:0.09223
# [11]	validation_0-logloss:0.08698
# [12]	validation_0-logloss:0.08223
# ...
# [67]	validation_0-logloss:0.03343
# [68]	validation_0-logloss:0.03343
# [69]	validation_0-logloss:0.03344
# [70]	validation_0-logloss:0.03351
# [71]	validation_0-logloss:0.03314
# [72]	validation_0-logloss:0.03317
# [73]	validation_0-logloss:0.03311
# [74]	validation_0-logloss:0.03313
# [75]	validation_0-logloss:0.03311
# [76]	validation_0-logloss:0.03312
# [77]	validation_0-logloss:0.03326
# [78]	validation_0-logloss:0.03326
# [79]	validation_0-logloss:0.03324
# [80]	validation_0-logloss:0.03305
# [81]	validation_0-logloss:0.03288
# [82]	validation_0-logloss:0.03279
# [83]	validation_0-logloss:0.03293
# [84]	validation_0-logloss:0.03279
# [85]	validation_0-logloss:0.03280
# [86]	validation_0-logloss:0.03284
# [87]	validation_0-logloss:0.03284
# [88]	validation_0-logloss:0.03285
# [89]	validation_0-logloss:0.03288
# [90]	validation_0-logloss:0.03266
# [91]	validation_0-logloss:0.03264
# [92]	validation_0-logloss:0.03277
# [93]	validation_0-logloss:0.03278
# [94]	validation_0-logloss:0.03259
# [95]	validation_0-logloss:0.03264
# [96]	validation_0-logloss:0.03266
# [97]	validation_0-logloss:0.03266
# [98]	validation_0-logloss:0.03268
# [99]	validation_0-logloss:0.03290
# [100]	validation_0-logloss:0.03290
# [101]	validation_0-logloss:0.03290
# [0]	validation_0-logloss:0.24197
# [1]	validation_0-logloss:0.20242
# [2]	validation_0-logloss:0.18270
# [3]	validation_0-logloss:0.16048
# [4]	validation_0-logloss:0.14763
# [5]	validation_0-logloss:0.13488
# [6]	validation_0-logloss:0.12185
# [7]	validation_0-logloss:0.11178
# [8]	validation_0-logloss:0.10292
# [9]	validation_0-logloss:0.09576
# [10]	validation_0-logloss:0.09023
# [11]	validation_0-logloss:0.08375
# [12]	validation_0-logloss:0.07967
# [13]	validation_0-logloss:0.07643
# [14]	validation_0-logloss:0.07334
# [15]	validation_0-logloss:0.06998
# [16]	validation_0-logloss:0.06660
# [17]	validation_0-logloss:0.06505
# [18]	validation_0-logloss:0.06258
# [19]	validation_0-logloss:0.06141
# [20]	validation_0-logloss:0.06049
# [21]	validation_0-logloss:0.05823
# [22]	validation_0-logloss:0.05656
# [23]	validation_0-logloss:0.05485
# [24]	validation_0-logloss:0.05359
# [25]	validation_0-logloss:0.05272
# [26]	validation_0-logloss:0.05210
# [27]	validation_0-logloss:0.05186
# [28]	validation_0-logloss:0.05152
# [29]	validation_0-logloss:0.05117
# [30]	validation_0-logloss:0.05075
# [31]	validation_0-logloss:0.04963
# [32]	validation_0-logloss:0.04872
# [33]	validation_0-logloss:0.04788
# [34]	validation_0-logloss:0.04777
# [35]	validation_0-logloss:0.04755
# [36]	validation_0-logloss:0.04714
# [37]	validation_0-logloss:0.04693
# [38]	validation_0-logloss:0.04644
# [39]	validation_0-logloss:0.04630
# [40]	validation_0-logloss:0.04573
# [41]	validation_0-logloss:0.04508
# [42]	validation_0-logloss:0.04440
# [43]	validation_0-logloss:0.04399
# [44]	validation_0-logloss:0.04391
# [45]	validation_0-logloss:0.04362
# [46]	validation_0-logloss:0.04330
# [47]	validation_0-logloss:0.04289
# [48]	validation_0-logloss:0.04249
# [49]	validation_0-logloss:0.04241
# [50]	validation_0-logloss:0.04249
# [51]	validation_0-logloss:0.04233
# [52]	validation_0-logloss:0.04274
# [53]	validation_0-logloss:0.04233
# [54]	validation_0-logloss:0.04213
# [55]	validation_0-logloss:0.04195
# [56]	validation_0-logloss:0.04170
# [57]	validation_0-logloss:0.04173
# [58]	validation_0-logloss:0.04151
# [59]	validation_0-logloss:0.04123
# [60]	validation_0-logloss:0.04152
# [61]	validation_0-logloss:0.04140
# [62]	validation_0-logloss:0.04167
# [63]	validation_0-logloss:0.04162
# [64]	validation_0-logloss:0.04161
# [65]	validation_0-logloss:0.04147
# [66]	validation_0-logloss:0.04147
# [67]	validation_0-logloss:0.04178
# [0]	validation_0-logloss:0.24089
# [1]	validation_0-logloss:0.20280
# [2]	validation_0-logloss:0.18493
# [3]	validation_0-logloss:0.16376
# [4]	validation_0-logloss:0.15229
# [5]	validation_0-logloss:0.13953
# [6]	validation_0-logloss:0.12738
# [7]	validation_0-logloss:0.11781
# [8]	validation_0-logloss:0.10946
# [9]	validation_0-logloss:0.10275
# [10]	validation_0-logloss:0.09734
# [11]	validation_0-logloss:0.09133
# [12]	validation_0-logloss:0.08724
# [13]	validation_0-logloss:0.08400
# [14]	validation_0-logloss:0.08145
# [15]	validation_0-logloss:0.07862
# [16]	validation_0-logloss:0.07662
# [17]	validation_0-logloss:0.07583
# [18]	validation_0-logloss:0.07433
# [19]	validation_0-logloss:0.07380
# [20]	validation_0-logloss:0.07318
# [21]	validation_0-logloss:0.07108
# [22]	validation_0-logloss:0.06997
# [23]	validation_0-logloss:0.06910
# [24]	validation_0-logloss:0.06782
# [25]	validation_0-logloss:0.06677
# [26]	validation_0-logloss:0.06551
# [27]	validation_0-logloss:0.06539
# [28]	validation_0-logloss:0.06517
# [29]	validation_0-logloss:0.06505
# [30]	validation_0-logloss:0.06487
# [31]	validation_0-logloss:0.06342
# [32]	validation_0-logloss:0.06292
# [33]	validation_0-logloss:0.06271
# [34]	validation_0-logloss:0.06226
# [35]	validation_0-logloss:0.06225
# [36]	validation_0-logloss:0.06225
# [37]	validation_0-logloss:0.06222
# [38]	validation_0-logloss:0.06165
# [39]	validation_0-logloss:0.06149
# [40]	validation_0-logloss:0.06055
# [41]	validation_0-logloss:0.06008
# [42]	validation_0-logloss:0.05965
# [43]	validation_0-logloss:0.05889
# [44]	validation_0-logloss:0.05860
# [45]	validation_0-logloss:0.05761
# [46]	validation_0-logloss:0.05787
# [47]	validation_0-logloss:0.05744
# [48]	validation_0-logloss:0.05734
# [49]	validation_0-logloss:0.05737
# [50]	validation_0-logloss:0.05744
# [51]	validation_0-logloss:0.05725
# [52]	validation_0-logloss:0.05732
# [53]	validation_0-logloss:0.05714
# [54]	validation_0-logloss:0.05719
# [55]	validation_0-logloss:0.05691
# [56]	validation_0-logloss:0.05663
# [57]	validation_0-logloss:0.05699
# [58]	validation_0-logloss:0.05709
# [59]	validation_0-logloss:0.05683
# [60]	validation_0-logloss:0.05678
# [61]	validation_0-logloss:0.05700
# [62]	validation_0-logloss:0.05749
# [63]	validation_0-logloss:0.05747
# [0]	validation_0-logloss:0.24702
# [1]	validation_0-logloss:0.20876
# [2]	validation_0-logloss:0.19037
# [3]	validation_0-logloss:0.17081
# [4]	validation_0-logloss:0.15957
# [5]	validation_0-logloss:0.14779
# [6]	validation_0-logloss:0.13714
# [7]	validation_0-logloss:0.12753
# [8]	validation_0-logloss:0.12058
# [9]	validation_0-logloss:0.11391
# [10]	validation_0-logloss:0.10920
# [11]	validation_0-logloss:0.10365
# [12]	validation_0-logloss:0.09961
# [13]	validation_0-logloss:0.09640
# [14]	validation_0-logloss:0.09421
# [15]	validation_0-logloss:0.09128
# [16]	validation_0-logloss:0.08967
# [17]	validation_0-logloss:0.08782
# [18]	validation_0-logloss:0.08672
# [19]	validation_0-logloss:0.08567
# [20]	validation_0-logloss:0.08485
# [21]	validation_0-logloss:0.08305
# [22]	validation_0-logloss:0.08129
# [23]	validation_0-logloss:0.08054
# [24]	validation_0-logloss:0.07971
# [25]	validation_0-logloss:0.07900
# [26]	validation_0-logloss:0.07865
# [27]	validation_0-logloss:0.07850
# [28]	validation_0-logloss:0.07874
# [29]	validation_0-logloss:0.07845
# [30]	validation_0-logloss:0.07776
# [31]	validation_0-logloss:0.07772
# [32]	validation_0-logloss:0.07765
# [33]	validation_0-logloss:0.07772
# [34]	validation_0-logloss:0.07742
# [35]	validation_0-logloss:0.07787
# [36]	validation_0-logloss:0.07841
# [37]	validation_0-logloss:0.07887
# [38]	validation_0-logloss:0.07943
# [39]	validation_0-logloss:0.07985
# [40]	validation_0-logloss:0.07919
# [41]	validation_0-logloss:0.07894
# [0]	validation_0-logloss:0.27037
# [1]	validation_0-logloss:0.22145
# [2]	validation_0-logloss:0.19973
# [3]	validation_0-logloss:0.17357
# [4]	validation_0-logloss:0.16042
# [5]	validation_0-logloss:0.14658
# [6]	validation_0-logloss:0.13144
# [7]	validation_0-logloss:0.11910
# [8]	validation_0-logloss:0.10854
# [9]	validation_0-logloss:0.10031
# [10]	validation_0-logloss:0.09404
# [11]	validation_0-logloss:0.08754
# [12]	validation_0-logloss:0.08202
# [13]	validation_0-logloss:0.07819
# [14]	validation_0-logloss:0.07472
# [15]	validation_0-logloss:0.07123
# [16]	validation_0-logloss:0.06859
# [17]	validation_0-logloss:0.06703
# [18]	validation_0-logloss:0.06479
# [19]	validation_0-logloss:0.06369
# [20]	validation_0-logloss:0.06283
# [21]	validation_0-logloss:0.06102
# [22]	validation_0-logloss:0.05942
# [23]	validation_0-logloss:0.05789
# [24]	validation_0-logloss:0.05681
# [25]	validation_0-logloss:0.05573
# [26]	validation_0-logloss:0.05428
# [27]	validation_0-logloss:0.05401
# [28]	validation_0-logloss:0.05350
# [29]	validation_0-logloss:0.05320
# [30]	validation_0-logloss:0.05284
# [31]	validation_0-logloss:0.05214
# [32]	validation_0-logloss:0.05145
# [33]	validation_0-logloss:0.05085
# [34]	validation_0-logloss:0.05076
# [35]	validation_0-logloss:0.05069
# [36]	validation_0-logloss:0.05075
# [37]	validation_0-logloss:0.05072
# [38]	validation_0-logloss:0.04990
# [39]	validation_0-logloss:0.04946
# [40]	validation_0-logloss:0.04877
# [41]	validation_0-logloss:0.04801
# [42]	validation_0-logloss:0.04739
# [43]	validation_0-logloss:0.04704
# [44]	validation_0-logloss:0.04680
# [45]	validation_0-logloss:0.04659
# [46]	validation_0-logloss:0.04628
# [47]	validation_0-logloss:0.04610
# [48]	validation_0-logloss:0.04597
# [49]	validation_0-logloss:0.04563
# [50]	validation_0-logloss:0.04532
# [51]	validation_0-logloss:0.04544
# [52]	validation_0-logloss:0.04468
# [53]	validation_0-logloss:0.04444
# [54]	validation_0-logloss:0.04409
# [55]	validation_0-logloss:0.04350
# [56]	validation_0-logloss:0.04334
# [57]	validation_0-logloss:0.04296
# [58]	validation_0-logloss:0.04284
# [59]	validation_0-logloss:0.04259
# [60]	validation_0-logloss:0.04247
# [61]	validation_0-logloss:0.04204
# [62]	validation_0-logloss:0.04207
# [63]	validation_0-logloss:0.04159
# [64]	validation_0-logloss:0.04150
# [65]	validation_0-logloss:0.04092
# [66]	validation_0-logloss:0.04084
# [67]	validation_0-logloss:0.04113
# [68]	validation_0-logloss:0.04132
# [69]	validation_0-logloss:0.04132
# [70]	validation_0-logloss:0.04119
# [71]	validation_0-logloss:0.04105
# [72]	validation_0-logloss:0.04077
# [73]	validation_0-logloss:0.04055
# [74]	validation_0-logloss:0.04062
# [75]	validation_0-logloss:0.04102
# [76]	validation_0-logloss:0.04107
# [77]	validation_0-logloss:0.04056
# [78]	validation_0-logloss:0.04054
# [79]	validation_0-logloss:0.04051
# [80]	validation_0-logloss:0.04049
# [81]	validation_0-logloss:0.04054
# [82]	validation_0-logloss:0.04046
# [83]	validation_0-logloss:0.04042
# [84]	validation_0-logloss:0.04047
# [85]	validation_0-logloss:0.04052
# [86]	validation_0-logloss:0.04055
# [87]	validation_0-logloss:0.04055
# [88]	validation_0-logloss:0.04054
# [89]	validation_0-logloss:0.04055
# [90]	validation_0-logloss:0.04057
# [91]	validation_0-logloss:0.04057
# [0]	validation_0-logloss:0.27495
# [1]	validation_0-logloss:0.23028
# [2]	validation_0-logloss:0.20993
# [3]	validation_0-logloss:0.18609
# [4]	validation_0-logloss:0.17356
# [5]	validation_0-logloss:0.15890
# [6]	validation_0-logloss:0.14523
# [7]	validation_0-logloss:0.13522
# [8]	validation_0-logloss:0.12615
# [9]	validation_0-logloss:0.11948
# [10]	validation_0-logloss:0.11298
# [11]	validation_0-logloss:0.10742
# [12]	validation_0-logloss:0.10282
# [13]	validation_0-logloss:0.09897
# [14]	validation_0-logloss:0.09552
# [15]	validation_0-logloss:0.09289
# [16]	validation_0-logloss:0.09081
# [17]	validation_0-logloss:0.08995
# [18]	validation_0-logloss:0.08837
# [19]	validation_0-logloss:0.08829
# [20]	validation_0-logloss:0.08790
# [21]	validation_0-logloss:0.08563
# [22]	validation_0-logloss:0.08385
# [23]	validation_0-logloss:0.08227
# [24]	validation_0-logloss:0.08098
# [25]	validation_0-logloss:0.07959
# [26]	validation_0-logloss:0.07876
# [27]	validation_0-logloss:0.07836
# [28]	validation_0-logloss:0.07813
# [29]	validation_0-logloss:0.07782
# [30]	validation_0-logloss:0.07784
# [31]	validation_0-logloss:0.07679
# [32]	validation_0-logloss:0.07638
# [33]	validation_0-logloss:0.07563
# [34]	validation_0-logloss:0.07487
# [35]	validation_0-logloss:0.07474
# [36]	validation_0-logloss:0.07453
# [37]	validation_0-logloss:0.07453
# [38]	validation_0-logloss:0.07367
# [39]	validation_0-logloss:0.07326
# [40]	validation_0-logloss:0.07256
# [41]	validation_0-logloss:0.07233
# [42]	validation_0-logloss:0.07106
# [43]	validation_0-logloss:0.07049
# [44]	validation_0-logloss:0.07045
# [45]	validation_0-logloss:0.06969
# [46]	validation_0-logloss:0.06957
# [47]	validation_0-logloss:0.06962
# [48]	validation_0-logloss:0.06937
# [49]	validation_0-logloss:0.06928
# [50]	validation_0-logloss:0.06867
# [51]	validation_0-logloss:0.06868
# [52]	validation_0-logloss:0.06795
# [53]	validation_0-logloss:0.06762
# [54]	validation_0-logloss:0.06750
# [55]	validation_0-logloss:0.06765
# [56]	validation_0-logloss:0.06681
# [57]	validation_0-logloss:0.06689
# [58]	validation_0-logloss:0.06701
# [59]	validation_0-logloss:0.06661
# [60]	validation_0-logloss:0.06656
# [61]	validation_0-logloss:0.06642
# [62]	validation_0-logloss:0.06669
# [63]	validation_0-logloss:0.06669
# [64]	validation_0-logloss:0.06659
# [65]	validation_0-logloss:0.06672
# [66]	validation_0-logloss:0.06659
# [67]	validation_0-logloss:0.06660
# [68]	validation_0-logloss:0.06542
# [69]	validation_0-logloss:0.06502
# [70]	validation_0-logloss:0.06496
# [71]	validation_0-logloss:0.06481
# [72]	validation_0-logloss:0.06422
# [73]	validation_0-logloss:0.06424
# [74]	validation_0-logloss:0.06370
# [75]	validation_0-logloss:0.06304
# [76]	validation_0-logloss:0.06304
# [77]	validation_0-logloss:0.06284
# [78]	validation_0-logloss:0.06281
# [79]	validation_0-logloss:0.06285
# [80]	validation_0-logloss:0.06273
# [81]	validation_0-logloss:0.06262
# [82]	validation_0-logloss:0.06247
# [83]	validation_0-logloss:0.06252
# [84]	validation_0-logloss:0.06261
# [85]	validation_0-logloss:0.06267
# [86]	validation_0-logloss:0.06267
# [87]	validation_0-logloss:0.06267
# [88]	validation_0-logloss:0.06267
# [89]	validation_0-logloss:0.06269
# [0]	validation_0-logloss:0.27682
# [1]	validation_0-logloss:0.23209
# [2]	validation_0-logloss:0.21177
# [3]	validation_0-logloss:0.18763
# [4]	validation_0-logloss:0.17544
# [5]	validation_0-logloss:0.16083
# [6]	validation_0-logloss:0.14769
# [7]	validation_0-logloss:0.13673
# [8]	validation_0-logloss:0.12749
# [9]	validation_0-logloss:0.12032
# [10]	validation_0-logloss:0.11448
# [11]	validation_0-logloss:0.10902
# [12]	validation_0-logloss:0.10462
# [13]	validation_0-logloss:0.10080
# [14]	validation_0-logloss:0.09789
# [15]	validation_0-logloss:0.09492
# [16]	validation_0-logloss:0.09260
# [17]	validation_0-logloss:0.09167
# [18]	validation_0-logloss:0.08998
# [19]	validation_0-logloss:0.08940
# [20]	validation_0-logloss:0.08958
# [21]	validation_0-logloss:0.08727
# [22]	validation_0-logloss:0.08489
# [23]	validation_0-logloss:0.08353
# [24]	validation_0-logloss:0.08194
# [25]	validation_0-logloss:0.08048
# [26]	validation_0-logloss:0.07906
# [27]	validation_0-logloss:0.07927
# [28]	validation_0-logloss:0.07922
# [29]	validation_0-logloss:0.07931
# [30]	validation_0-logloss:0.07934
# [31]	validation_0-logloss:0.07834
# [32]	validation_0-logloss:0.07766
# [33]	validation_0-logloss:0.07751
# [34]	validation_0-logloss:0.07662
# [35]	validation_0-logloss:0.07665
# [36]	validation_0-logloss:0.07671
# [37]	validation_0-logloss:0.07712
# [38]	validation_0-logloss:0.07590
# [39]	validation_0-logloss:0.07571
# [40]	validation_0-logloss:0.07518
# [41]	validation_0-logloss:0.07484
# [42]	validation_0-logloss:0.07432
# [43]	validation_0-logloss:0.07392
# [44]	validation_0-logloss:0.07343
# [45]	validation_0-logloss:0.07297
# [46]	validation_0-logloss:0.07292
# [47]	validation_0-logloss:0.07282
# [48]	validation_0-logloss:0.07207
# [49]	validation_0-logloss:0.07117
# [50]	validation_0-logloss:0.07070
# [51]	validation_0-logloss:0.07066
# [52]	validation_0-logloss:0.07007
# [53]	validation_0-logloss:0.06971
# [54]	validation_0-logloss:0.06893
# [55]	validation_0-logloss:0.06906
# [56]	validation_0-logloss:0.06969
# [57]	validation_0-logloss:0.06977
# [58]	validation_0-logloss:0.06975
# [59]	validation_0-logloss:0.06973
# [60]	validation_0-logloss:0.06911
# [61]	validation_0-logloss:0.06872
# [62]	validation_0-logloss:0.06842
# [63]	validation_0-logloss:0.06802
# [64]	validation_0-logloss:0.06803
# [65]	validation_0-logloss:0.06790
# [66]	validation_0-logloss:0.06793
# [67]	validation_0-logloss:0.06825
# [68]	validation_0-logloss:0.06764
# [69]	validation_0-logloss:0.06737
# [70]	validation_0-logloss:0.06737
# [71]	validation_0-logloss:0.06740
# [72]	validation_0-logloss:0.06745
# [73]	validation_0-logloss:0.06745
# [74]	validation_0-logloss:0.06749
# [75]	validation_0-logloss:0.06753
# [76]	validation_0-logloss:0.06755
# [77]	validation_0-logloss:0.06744
# Done!
# CPU times: user 1min 24s, sys: 1.88 s, total: 1min 26s
# Wall time: 1min 26s

# %%
model_performance_after.round(3)
# Out:
#                      accuracy mean  accuracy std  balanced accuracy mean  \
# Logistic Regression          0.921         0.007                   0.901
# KNN                          0.973         0.004                   0.885
# Decision Tree                0.958         0.006                   0.958
# LightGBM                     0.959         0.007                   0.969
# XGBoost                      0.980         0.003                   0.911
#
#                      balanced accuracy std  f1 mean  f1 std  f1 micro mean  \
# Logistic Regression                  0.015    0.956   0.004          0.921
# KNN                                  0.017    0.985   0.002          0.973
# Decision Tree                        0.009    0.977   0.003          0.958
# LightGBM                             0.007    0.978   0.004          0.959
# XGBoost                              0.018    0.989   0.002          0.980
#
#                      f1 micro std  f1 macro mean  f1 macro std  \
# Logistic Regression         0.007          0.785         0.014
# KNN                         0.004          0.895         0.013
# Decision Tree               0.006          0.872         0.014
# LightGBM                    0.007          0.878         0.018
# XGBoost                     0.003          0.924         0.012
#
#                      f1 weighted mean  f1 weighted std  precision mean  \
# Logistic Regression             0.931            0.005           0.990
# KNN                             0.972            0.004           0.983
# Decision Tree                   0.962            0.005           0.997
# LightGBM                        0.963            0.006           0.998
# XGBoost                         0.980            0.003           0.987
#
#                      precision std  precision micro mean  precision micro std  \
# Logistic Regression          0.002                 0.921                0.007
# KNN                          0.003                 0.973                0.004
# Decision Tree                0.002                 0.958                0.006
# LightGBM                     0.001                 0.959                0.007
# XGBoost                      0.003                 0.980                0.003
#
#                      precision macro mean  precision macro std  \
# Logistic Regression                 0.732                0.013
# KNN                                 0.907                0.017
# Decision Tree                       0.819                0.017
# LightGBM                            0.822                0.023
# XGBoost                             0.938                0.013
#
#                      precision weighted mean  precision weighted std  \
# Logistic Regression                    0.953                   0.003
# KNN                                    0.972                   0.004
# Decision Tree                          0.971                   0.003
# LightGBM                               0.973                   0.003
# XGBoost                                0.980                   0.003
#
#                      average precision mean  average precision std  \
# Logistic Regression                   0.997                  0.000
# KNN                                   0.997                  0.001
# Decision Tree                         0.997                  0.001
# LightGBM                              1.000                  0.000
# XGBoost                               1.000                  0.000
#
#                      recall mean  recall std  recall micro mean  \
# Logistic Regression        0.924       0.007              0.921
# KNN                        0.988       0.003              0.973
# Decision Tree              0.958       0.006              0.958
# LightGBM                   0.958       0.008              0.959
# XGBoost                    0.992       0.002              0.980
#
#                      recall micro std  recall macro mean  recall macro std  \
# Logistic Regression             0.007              0.901             0.015
# KNN                             0.004              0.885             0.017
# Decision Tree                   0.006              0.958             0.009
# LightGBM                        0.007              0.969             0.007
# XGBoost                         0.003              0.911             0.018
#
#                      recall weighted mean  recall weighted std  roc auc mean  \
# Logistic Regression                 0.921                0.007         0.961
# KNN                                 0.973                0.004         0.973
# Decision Tree                       0.958                0.006         0.978
# LightGBM                            0.959                0.007         0.994
# XGBoost                             0.980                0.003         0.994
#
#                      roc auc std  roc auc ovr mean  roc auc ovr std  \
# Logistic Regression        0.005             0.961            0.005
# KNN                        0.009             0.973            0.009
# Decision Tree              0.008             0.978            0.008
# LightGBM                   0.002             0.994            0.002
# XGBoost                    0.001             0.994            0.001
#
#                      roc auc ovo mean  roc auc ovo std  \
# Logistic Regression             0.961            0.005
# KNN                             0.973            0.009
# Decision Tree                   0.978            0.008
# LightGBM                        0.994            0.002
# XGBoost                         0.994            0.001
#
#                      roc auc ovr weighted mean  roc auc ovr weighted std  \
# Logistic Regression                      0.961                     0.005
# KNN                                      0.973                     0.009
# Decision Tree                            0.978                     0.008
# LightGBM                                 0.994                     0.002
# XGBoost                                  0.994                     0.001
#
#                      roc auc ovo weighted mean  roc auc ovo weighted std
# Logistic Regression                      0.961                     0.005
# KNN                                      0.973                     0.009
# Decision Tree                            0.978                     0.008
# LightGBM                                 0.994                     0.002
# XGBoost                                  0.994                     0.001

# %%
score_metric = scoring
lfunc.plot_model_score([collect_cv_results_before, collect_cv_results_after],
                 score = score_metric, classifiers_names = classifiers_h,
                 colors = ['skyblue', 'red'], tilt_x = True,
                 title = score_metric.replace('_',' ').title()+
                        ' (Tuning Metric) per Algorithm before (blue) '+
                        'and after (red) Hypertuning')  ;

# %%
score_metrics = ['balanced_accuracy', 'f1_weighted', 'precision_weighted', 'recall_weighted',
                 'roc_auc_ovr_weighted', 'roc_auc_ovo_weighted']

for score_metric in score_metrics:
    if score_metric is not scoring:
        lfunc.plot_model_score([collect_cv_results_before, collect_cv_results_after],
                 score = score_metric, classifiers_names = classifiers_h,
                 colors = ['skyblue', 'red'], tilt_x = True,
                 title = score_metric.replace('_',' ').title()+
                        ' per Algorithm before Hypertuning')  ;

# %%
from sklearn.metrics import classification_report
y_pred = (model_prob_after[-1][:, 1] > 0.5)#.astype("float")
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.78      0.80       156
#            1       0.98      0.99      0.98      2001
#
#     accuracy                           0.97      2157
#    macro avg       0.90      0.88      0.89      2157
# weighted avg       0.97      0.97      0.97      2157

# %% [markdown]
# #### Confusion Matrices after Hypertune

# %%
# %reload_ext autoreload


lfunc.plot_confusion_matrices(model_prob_after,y_test,
                              names = classifiers,
                              n_cols = 3, normalize = 'all', labels = labels,
                              title = 'for the Following Hypertuned Algorithms')

# %% [markdown]
# ## Ensemble

# %% [markdown]
# ### Voting Classifier

# %%
# %%time
# %reload_ext autoreload

classifiers_vot = classifiers_h.copy()

to_exclude = ['Linear Svm','Radial Svm',
             'Logistic Regression',
             #'KNN',
             #'Decision Tree', 'Random Forest',
             #'LightGBM', 'XGBoost'
              ]
for item in to_exclude:
    if item in classifiers_vot:
        classifiers_vot.remove(item)

estimators_vot = []
for clas in classifiers_vot:
    estimators_vot.append(classifier_map_h[clas])

estimators_list = list(zip(classifiers_vot,estimators_vot))

# Need to remove XGBoost because it needs fit_params for early stopping
# - unclear how to implement this without crashing
if 'XGBoost' in classifiers_vot:
    index = classifiers_vot.index('XGBoost')
    estimators_list.pop(index)

vot_clas = VotingClassifier(estimators = estimators_list,
                            voting='soft')

pipe_steps = pipe_prep_steps.copy()
pipe_steps.append(('vot_classifiers' , vot_clas))

vot_pipe = Pipeline(pipe_steps)

vot_perf, vot_results, vot_prob = lfunc.model_scores(X_train,y_train,X_test,
                                                     models = [vot_pipe],
                                                     model_names = ['vot_classifiers'],
                                                     cv = cvRSK)
# Out:
# Executing vot_classifiers
# Done!
# CPU times: user 18.1 s, sys: 252 ms, total: 18.3 s
# Wall time: 16.2 s

# %%
vot_perf.round(3)
# Out:
#                  accuracy mean  accuracy std  balanced accuracy mean  \
# vot_classifiers          0.968         0.005                   0.952
#
#                  balanced accuracy std  f1 mean  f1 std  f1 micro mean  \
# vot_classifiers                  0.012    0.983   0.003          0.968
#
#                  f1 micro std  f1 macro mean  f1 macro std  f1 weighted mean  \
# vot_classifiers         0.005          0.896         0.013              0.97
#
#                  f1 weighted std  precision mean  precision std  \
# vot_classifiers            0.004           0.995          0.002
#
#                  precision micro mean  precision micro std  \
# vot_classifiers                 0.968                0.005
#
#                  precision macro mean  precision macro std  \
# vot_classifiers                 0.855                0.018
#
#                  precision weighted mean  precision weighted std  \
# vot_classifiers                    0.975                   0.003
#
#                  average precision mean  average precision std  recall mean  \
# vot_classifiers                   0.999                    0.0        0.971
#
#                  recall std  recall micro mean  recall micro std  \
# vot_classifiers       0.005              0.968             0.005
#
#                  recall macro mean  recall macro std  recall weighted mean  \
# vot_classifiers              0.952             0.012                 0.968
#
#                  recall weighted std  roc auc mean  roc auc std  \
# vot_classifiers                0.005         0.992        0.002
#
#                  roc auc ovr mean  roc auc ovr std  roc auc ovo mean  \
# vot_classifiers             0.992            0.002             0.992
#
#                  roc auc ovo std  roc auc ovr weighted mean  \
# vot_classifiers            0.002                      0.992
#
#                  roc auc ovr weighted std  roc auc ovo weighted mean  \
# vot_classifiers                     0.002                      0.992
#
#                  roc auc ovo weighted std
# vot_classifiers                     0.002

# %%
# %reload_ext autoreload

lfunc.plot_confusion_matrices(vot_prob, y_test,
                              names = ['voting classifier'],
                              n_cols = 1, normalize = 'all',
                              threshold = 0.5, labels = labels,
                              title = 'for the Following \nHypertuned Algorithms')

# %% [markdown]
# ### Bagging

# %%
# %%time
# %reload_ext autoreload

# XGBoost issues with fit_params again...

clf_name = 'Decision Tree'
clf = classifier_map_h[clf_name]

index = classifiers_h.index(clf_name)
fit_params = fit_params_hyped[index]

bag_name = 'bag_'+clf_name.replace(' ', '_')
bag_clas = BaggingClassifier(base_estimator=clf,random_state=0,n_estimators=100)

pipe_steps = pipe_prep_steps.copy()
pipe_steps.append((bag_name , bag_clas))
bag_pipe = Pipeline(pipe_steps)

bag_perf, bag_results, bag_prob = lfunc.model_scores(X_train, y_train, X_test,
                                                     models = [bag_pipe],
                                                     model_names = [bag_name],
                                                     cv = cvRSK)
# Out:
# Executing bag_Decision_Tree
# Done!
# CPU times: user 48.4 s, sys: 247 ms, total: 48.6 s
# Wall time: 49.5 s

# %%
bag_perf.round(3)
# Out:
#                    accuracy mean  accuracy std  balanced accuracy mean  \
# bag_Decision_Tree          0.961         0.005                   0.958
#
#                    balanced accuracy std  f1 mean  f1 std  f1 micro mean  \
# bag_Decision_Tree                   0.01    0.979   0.003          0.961
#
#                    f1 micro std  f1 macro mean  f1 macro std  \
# bag_Decision_Tree         0.005          0.879         0.012
#
#                    f1 weighted mean  f1 weighted std  precision mean  \
# bag_Decision_Tree             0.964            0.004           0.996
#
#                    precision std  precision micro mean  precision micro std  \
# bag_Decision_Tree          0.002                 0.961                0.005
#
#                    precision macro mean  precision macro std  \
# bag_Decision_Tree                 0.828                0.015
#
#                    precision weighted mean  precision weighted std  \
# bag_Decision_Tree                    0.972                   0.002
#
#                    average precision mean  average precision std  recall mean  \
# bag_Decision_Tree                   0.999                    0.0        0.961
#
#                    recall std  recall micro mean  recall micro std  \
# bag_Decision_Tree       0.005              0.961             0.005
#
#                    recall macro mean  recall macro std  recall weighted mean  \
# bag_Decision_Tree              0.958              0.01                 0.961
#
#                    recall weighted std  roc auc mean  roc auc std  \
# bag_Decision_Tree                0.005         0.992        0.003
#
#                    roc auc ovr mean  roc auc ovr std  roc auc ovo mean  \
# bag_Decision_Tree             0.992            0.003             0.992
#
#                    roc auc ovo std  roc auc ovr weighted mean  \
# bag_Decision_Tree            0.003                      0.992
#
#                    roc auc ovr weighted std  roc auc ovo weighted mean  \
# bag_Decision_Tree                     0.003                      0.992
#
#                    roc auc ovo weighted std
# bag_Decision_Tree                     0.003

# %%
# %%time
# %reload_ext autoreload

thresh = 0.51
title = 'for the Bagging of the \n Following Hypertuned Algorithms \
\n for a threshold of '+ str(thresh)

lfunc.plot_confusion_matrices(bag_prob, y_test,
                              names = [bag_name],
                              n_cols = 1, normalize = 'all',
                              threshold = thresh, labels = labels,
                              title = title)
# Out:
# CPU times: user 262 ms, sys: 121 ms, total: 382 ms
# Wall time: 275 ms

# %% [markdown]
# ## ROCAUC, Precisions-Recall curve and Discrimination Threshold

# %%
model_pipe = bag_pipe
#model_pipe = pipe

model_pipe.fit(X_train, y_train)

visualizer = ROCAUC(model_pipe, classes= LE.classes_)

visualizer.fit(X_train, y_train)        # Fit the training data to the visualizer
visualizer.score(X_test, y_test)        # Evaluate the model on the test data
visualizer.show();

# %%
# does not work with LightGBM
viz = PrecisionRecallCurve(model_pipe, classes= LE.classes_)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %%
# not supported for multiclass
visualizer = DiscriminationThreshold(model_pipe, quantiles=np.array([0.25, 0.5, 0.75]))

visualizer.fit(X_train, y_train)
visualizer.show();

# %%
# needs results from DiscriminationThreshold - not supported for multiclass

best_threshold = visualizer.thresholds_[visualizer.cv_scores_[visualizer.argmax].argmax()].round(3)
print('best_threshold:', best_threshold.round(3))
thresh_pipe = Thresholder(bag_pipe, best_threshold, refit=False)

thresh_pipe.fit(X_train, y_train)
# Out:
# best_threshold: 0.102
# Thresholder(model=Pipeline(steps=[('preprocessor',
#                                    ColumnTransformer(remainder='passthrough',
#                                                      transformers=[('num',
#                                                                     Pipeline(steps=[('imputer',
#                                                                                      SimpleImputer(strategy='median')),
#                                                                                     ('scaler',
#                                                                                      StandardScaler())]),
#                                                                     ['Amount '
#                                                                      'Requested',
#                                                                      'Risk_Score',
#                                                                      'dti']),
#                                                                    ('cat',
#                                                                     Pipeline(steps=[('imputer',
#                                                                                      SimpleImputer(strategy='most_frequent')),
#                                                                                     ('encoder',
#                                                                                      OneHotEncoder(hand...
#                                                                                                                  'year',
#                                                                                                                  '2 '
#                                                                                                                  'years',
#                                                                                                                  '3 '
#                                                                                                                  'years',
#                                                                                                                  '4 '
#                                                                                                                  'years',
#                                                                                                                  '5 '
#                                                                                                                  'years',
#                                                                                                                  '6 '
#                                                                                                                  'years',
#                                                                                                                  '7 '
#                                                                                                                  'years',
#                                                                                                                  '8 '
#                                                                                                                  'years',
#                                                                                                                  '9 '
#                                                                                                                  'years',
#                                                                                                                  '10+ '
#                                                                                                                  'years']]))]),
#                                                                     ['Employment '
#                                                                      'Length'])])),
#                                   ('bag_Decision_Tree',
#                                    BaggingClassifier(base_estimator=DecisionTreeClassifier(class_weight='balanced',
#                                                                                            min_samples_leaf=6,
#                                                                                            min_samples_split=40,
#                                                                                            random_state=1),
#                                                      n_estimators=100,
#                                                      random_state=0))]),
#             threshold=0.102)

# %%
# %%time
# %reload_ext autoreload

thresh = 0.51
title = 'for the Thresholded BaggingClassifier of the \n Following Hypertuned Algorithms \
\n for a threshold of '+ str(best_threshold)


thresh_prob = thresh_pipe.predict_proba(X_test)

lfunc.plot_confusion_matrices([thresh_prob], y_test,
                              names = [bag_name],
                              n_cols = 1, normalize = 'all',
                              threshold = best_threshold, labels = labels,
                              title = title)
# Out:
# CPU times: user 259 ms, sys: 121 ms, total: 380 ms
# Wall time: 267 ms

# %% [markdown]
# Decision Tree qith threshold 0.23 --> unexpectedly good

# %% [markdown]
# ## Explainability

# %% [markdown]
# ### Permutation Importance

# %%
X_test_transformed = pd.DataFrame(bag_pipe[:-1].transform(X_test), columns=new_cols)

perm = PermutationImportance(bag_clas,
                             n_iter = 5, random_state=1
                             ).fit(X_test_transformed, y_test)
eli5.show_weights(perm, feature_names = new_cols)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0857
#
#                     &plusmn; 0.0067
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 num__Risk_Score
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.78%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0161
#
#                     &plusmn; 0.0055
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 num__dti
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.29%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0143
#
#                     &plusmn; 0.0045
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ord__Employment Length
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0023
#
#                     &plusmn; 0.0048
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 num__Amount Requested
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %%
# %%time
# %reload_ext autoreload

clf_name = 'LightGBM'
index = classifiers.index(clf_name)
pipe = models_hyped[index]

model_pipe = pipe
model_pipe.fit(X_train, y_train)
X_test_transformed = pd.DataFrame(model_pipe[:-1].transform(X_test), columns=new_cols)

perm = PermutationImportance(model_pipe[-1], scoring=scoring,
                             n_iter = 5, random_state=1
                             ).fit(X_test_transformed, y_test)
eli5.show_weights(perm, feature_names = new_cols)
# Out:
# CPU times: user 411 ms, sys: 23.9 ms, total: 435 ms
# Wall time: 442 ms
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.4265
#
#                     &plusmn; 0.0237
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 num__Risk_Score
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.77%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1199
#
#                     &plusmn; 0.0301
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 num__dti
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.70%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0325
#
#                     &plusmn; 0.0067
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ord__Employment Length
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.29%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0036
#
#                     &plusmn; 0.0041
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 num__Amount Requested
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %% [markdown]
# ### SHAP evaluation

# %%
# cannot work on BaggedClassifier

#does not work for LightGBM, XGBoost (wrappers?), KNN

clf_name = 'Logistic Regression'
index = classifiers.index(clf_name)
pipe = models_hyped[index]

model_pipe = pipe
#model_pipe = models_hyped[2] # LogReg
model_pipe.fit(X_train, y_train)

X_test_transformed = np.array(model_pipe[:-1].transform(X_test))
X_train_transformed = np.array(model_pipe[:-1].fit_transform(X_train))

explainer = shap.Explainer(model_pipe[-1], X_train_transformed,
                           feature_names=new_cols, )
shap_values = explainer(X_test_transformed) #, check_additivity=False)

# %%
shap_values
# Out:
# .values =
# array([[ 5.03462159e-02, -4.01591871e-01, -2.62774781e-01,
#          3.27771424e-01],
#        [-3.37685896e-02, -1.06979798e+00, -2.15647806e-01,
#         -1.35310767e+00],
#        [ 1.27924600e-03,  8.35190814e+00, -1.03836437e-02,
#          3.27771424e-01],
#        ...,
#        [-4.07781568e-02,  1.46938523e+00, -5.96051519e-02,
#          3.27771424e-01],
#        [-6.18068582e-02, -4.01591871e-01, -3.50221503e-01,
#         -1.77332745e+00],
#        [ 1.55489723e-01, -4.01591871e-01, -3.02134534e-01,
#          3.27771424e-01]])
#
# .base_values =
# array([2.65710712, 2.65710712, 2.65710712, ..., 2.65710712, 2.65710712,
#        2.65710712])
#
# .data =
# array([[ 0.44671644,  0.07624701, -0.05674088,  0.        ],
#        [-0.35557175,  0.27688602, -0.05362927,  4.        ],
#        [-0.021285  , -2.55212403, -0.04007646,  0.        ],
#        ...,
#        [-0.42242909, -0.48554222, -0.04332637,  0.        ],
#        [-0.62300114,  0.07624701, -0.06251466,  5.        ],
#        [ 1.44957667,  0.07624701, -0.05933966,  0.        ]])

# %%
shap.initjs()
shap.plots.bar(shap_values[0])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %%
shap.plots.beeswarm(shap_values)

# %%
shap.initjs()

shap.plots.force(shap_values[1])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='iUBZV7FZK6AYCBW8OHOGU'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 2.6571071207573316, "outValue": -0.015214927508842013, "link": "identity", "featureNames": ["num__Amount Requested", "num__Risk_Score", "num__dti", "ord__Employment Length"], "features": {"0": {"effect": -0.03376858964855452, "value": -0.35557174592077395}, "1": {"effect": -1.0697979788685934, "value": 0.2768860225585355}, "2": {"effect": -0.2156478055053452, "value": -0.05362926952593197}, "3": {"effect": -1.3531076742436803, "value": 4.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iUBZV7FZK6AYCBW8OHOGU')
#   );
# </script>

# %%
clustering = shap.utils.hclust(X_test_transformed, y_test)

# %%
shap.plots.bar(shap_values, clustering = clustering, clustering_cutoff = 1.5)

# %% [markdown]
# ## Final Model

# %%
#stroke_LogReg_model = models_hyped[2]
final_model = bag_pipe

# %%
final_model.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Amount Requested',
#                                                    'Risk_Score', 'dti']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore')...
#                                                                    OrdinalEncoder(categories=[['< '
#                                                                                                '1 '
#                                                                                                'year',
#                                                                                                '1 '
#                                                                                                'year',
#                                                                                                '2 '
#                                                                                                'years',
#                                                                                                '3 '
#                                                                                                'years',
#                                                                                                '4 '
#                                                                                                'years',
#                                                                                                '5 '
#                                                                                                'years',
#                                                                                                '6 '
#                                                                                                'years',
#                                                                                                '7 '
#                                                                                                'years',
#                                                                                                '8 '
#                                                                                                'years',
#                                                                                                '9 '
#                                                                                                'years',
#                                                                                                '10+ '
#                                                                                                'years']]))]),
#                                                   ['Employment Length'])])),
#                 ('bag_Decision_Tree',
#                  BaggingClassifier(base_estimator=DecisionTreeClassifier(class_weight='balanced',
#                                                                          min_samples_leaf=6,
#                                                                          min_samples_split=40,
#                                                                          random_state=1),
#                                    n_estimators=100, random_state=0))])

# %%
filename = home_folder+'loan_acceptance_Bagged_model.pickle'
pickle.dump(final_model,open(filename, 'wb'))

# %% [markdown]
# # Summary

# %% [markdown]
# # Improvements

# %% [markdown]
# **General**
#
# Feature selection/Cleaning
# * less strict on mulitcolinearity
# * Less strict on dropping but freq-%
# * reduce/bundle classes of features
# * Missing values in categoricals: Own class instead of * imputing
# * software, e.g. Boruta
# * use logarithmic features
#
#
# Models and Optimization
# * try other model, e.g. CatBoost
# * failed attempts: TuneSearchCV (internal bugs), * OptunaSearchCV
# * Auto-sklearn (grade prediction - not yet finding solutions)
#
# .
#
# **Model-specific**
#
# Linear Regression
# * clip outliers
#
# Regression/Classifier Trees
# * omit scaling of numericals
#
# Loan acceptance
# * Language processing of 'loan_title' → purpose
#
# Grade/Sub-grade
# * Classifiers: change class weights manually in estimators
# * Linear Regression on ordinal target
# * Ordinal Logistic Regression

# %% [markdown]
# #### PCA

# %%
X_train[num_feat].columns
# Out:
# Index(['Amount Requested', 'Risk_Score', 'dti'], dtype='object')

# %%
num_feat = X_train.select_dtypes(include=np.number).columns.tolist()

transformers=[("num", numeric_transformer, num_feat),
              ]

preprocessor_pca = ColumnTransformer(transformers=transformers,
                                 remainder='passthrough'
                                 )

# %%
from sklearn.decomposition import PCA

pca = PCA()
pca_pipe = Pipeline([('preprocessor', preprocessor_pca),
                     ("pca", pca)
                                  ])

# %%
X_transformed = pca_pipe.fit_transform(X_train[num_feat])

final = pd.DataFrame(X_transformed[:,:2], columns=['first_component', 'second_component'])

pca_pipe.named_steps['pca'].explained_variance_ratio_
# Out:
# array([0.37250176, 0.33250621, 0.29499202])

# %%
best_cat_feat = features
final = pd.merge(X_train_analysis[best_cat_feat],
                 final, left_index=True, right_index=True)
final.head()
# Out:
#       Amount Requested  Risk_Score Employment Length     dti  first_component  \
# 7041            4100.0         NaN           5 years   42.37        -0.106044
# 1358           10000.0         NaN          < 1 year  274.23        -0.005920
# 569             7000.0         NaN          < 1 year   14.96        -0.012085
# 8044            6500.0         NaN          < 1 year   16.09        -0.065945
# 7274           20000.0       706.0          < 1 year   14.83        -0.248609
#
#       second_component
# 7041         -0.009182
# 1358         -0.033274
# 569          -0.021869
# 8044         -0.016104
# 7274         -0.001044

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 10))

hue_list= best_cat_feat
hue = hue_list[1]

fig = sns.scatterplot(final, x='first_component', y='second_component', s=100,
                     alpha=0.5, hue = hue,
                      ax=ax)

ax.set_title('PCA', size=20)
ax.set_xlabel('first_component', size=16)
ax.set_ylabel('second_component', size=16)
ax.tick_params(labelsize=14)
ax.set_xlim(-6, 15)
ax.grid(False)

# %%
from matplotlib.patches import Circle
from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import euclidean_distances

# %%
#Xstd = StandardScaler().fit_transform(X)
#pca = PCA(n_components=2)
Xpca = pca_pipe.fit_transform(X_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-e5cbe2896648> in <cell line: 3>()
#       1 #Xstd = StandardScaler().fit_transform(X)
#       2 #pca = PCA(n_components=2)
# ----> 3 Xpca = pca_pipe.fit_transform(X_train)
#
# /usr/local/lib/python3.10/dist-packages/imblearn/utils/fixes.py in wrapper(estimator, *args, **kwargs)
#      83                     )
#      84                 ):
# ---> 85                     return fit_method(estimator, *args, **kwargs)
#      86
#      87             return wrapper
#
# /usr/local/lib/python3.10/dist-packages/imblearn/pipeline.py in fit_transform(self, X, y, **params)
#     398             last_step_params = routed_params[self.steps[-1][0]]
#     399             if hasattr(last_step, "fit_transform"):
# --> 400                 return last_step.fit_transform(
#     401                     Xt, yt, **last_step_params["fit_transform"]
#     402                 )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/decomposition/_pca.py in fit_transform(self, X, y)
#     460         self._validate_params()
#     461
# --> 462         U, S, Vt = self._fit(X)
#     463         U = U[:, : self.n_components_]
#     464
#
# /usr/local/lib/python3.10/dist-packages/sklearn/decomposition/_pca.py in _fit(self, X)
#     483             )
#     484
# --> 485         X = self._validate_data(
#     486             X, dtype=[np.float64, np.float32], ensure_2d=True, copy=self.copy
#     487         )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     563             raise ValueError("Validation should be done on X, y or both.")
#     564         elif not no_val_X and no_val_y:
# --> 565             X = check_array(X, input_name="X", **check_params)
#     566             out = X
#     567         elif no_val_X and not no_val_y:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     877                     array = xp.astype(array, dtype, copy=False)
#     878                 else:
# --> 879                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     880             except ComplexWarning as complex_warning:
#     881                 raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py in _asarray_with_order(array, dtype, order, copy, xp)
#     183     if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184         # Use NumPy API to support order
# --> 185         array = numpy.asarray(array, order=order, dtype=dtype)
#     186         return xp.asarray(array, copy=copy)
#     187     else:
#
# ValueError: could not convert string to float: '5 years'

# %%
len(Xpca)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-d1f6a6160c23> in <cell line: 1>()
# ----> 1 len(Xpca)
#
# NameError: name 'Xpca' is not defined

# %%
eucl_dist = []
for i,j in enumerate(X_train .T):
    corr1 = np.corrcoef(j,Xpca[:,0])[0,1]
    corr2 = np.corrcoef(j,Xpca[:,1])[0,1]
    circle.append((corr1, corr2))
    eucl_dist.append(np.sqrt(corr1**2 + corr2**2))

# %%
with plt.style.context(('seaborn-whitegrid')):
    fig, axs = plt.subplots(figsize=(6, 6))
    for i,j in enumerate(eucl_dist):
        arrow_col = plt.cm.cividis((eucl_dist[i] - np.array(eucl_dist).min())/\
                                (np.array(eucl_dist).max() - np.array(eucl_dist).min()) )
        axs.arrow(0,0, # Arrows start at the origin
                 ccircle[i][0],  #0 for PC1
                 ccircle[i][1],  #1 for PC2
                 lw = 2, # line width
                 length_includes_head=True,
                 color = arrow_col,
                 fc = arrow_col,
                 head_width=0.05,
                 head_length=0.05)
        axs.text(ccircle[i][0]/2,ccircle[i][1]/2, iris.feature_names[i])
    # Draw the unit circle, for clarity
    circle = Circle((0, 0), 1, facecolor='none', edgecolor='k', linewidth=1, alpha=0.5)
    axs.add_patch(circle)
    axs.set_xlabel("PCA 1")
    axs.set_ylabel("PCA 2")
plt.tight_layout()
plt.show()

# %%
X_pca = pca_pipe.fit_transform(X_train)
total_explained_variance = pca_pipe['pca'].explained_variance_ratio_.cumsum()
n_over_95 = len(total_explained_variance[total_explained_variance >= .95])
n_to_reach_95 = X_pca.shape[1] - n_over_95 + 1
print('Number features: {}\tTotal Variance Explained: {}'.format(n_to_reach_95, total_explained_variance[n_to_reach_95-1]))

# %%
X_train_analysis.columns

# %%
import plotly.express as px
from sklearn.decomposition import PCA
from sklearn import datasets
from sklearn.preprocessing import StandardScaler

#df = px.data.iris()
features = X_train_analysis.columns.tolist() #['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
#X = df[features]

#pca = PCA(n_components=2)
components = pca_pipe.fit_transform(X_train)

loadings = pca.components_.T * np.sqrt(pca.explained_variance_)

fig = px.scatter(components, x=0, y=1, color=X_train_analysis['loan_status_simple'])

for i, feature in enumerate(features):
    fig.add_annotation(
        ax=0, ay=0,
        axref="x", ayref="y",
        x=loadings[i, 0],
        y=loadings[i, 1],
        showarrow=True,
        arrowsize=2,
        arrowhead=2,
        xanchor="right",
        yanchor="top"
    )
    fig.add_annotation(
        x=loadings[i, 0],
        y=loadings[i, 1],
        ax=0, ay=0,
        xanchor="center",
        yanchor="bottom",
        text=feature,
        yshift=5,
    )
fig.show()

# %%
from yellowbrick.features import PCA

#selected_feat= final_multicol_reduced_feat + cat_feat
#
#X = LCacc_PC_EDA[selected_feat]
#X = X.drop(columns=['grade', 'sub_grade', 'sub_grade', 'loan_status_simple', 'int_rate'])
#y = LCacc_PC_EDA['int_rate'].to_frame()


visualizer = PCA(scale=False, proj_features=True, )
visualizer.fit_transform(X_train_prep)
visualizer.show()
