# %% [markdown]
# # Home Credit Prediction: Data Cleaning of POS CASH Table

# %% [markdown]
# For an up-to-date version / full view of the plotly - plots, please, go to
#
# Data Cleaning - POS CASH:  https://drive.google.com/file/d/16n5gXaxqB59kyMqAB5thSLDFwrxoqg0u/view?usp=sharing

# %% [markdown]
# List of all notebooks and resources for this project: https://drive.google.com/file/d/1Z8vPNZAcivWOxeh3UKFfeARbQCMkQ_NR/view?usp=sharing

# %% [markdown]
# ## Import Modules

# %%
# %%capture
#! pip install -q pingouin
#! pip install -q scikit-optimize
! pip install -q scikit-optimize

# %%
import numpy as np
import pandas as pd

import sys
import os
import warnings
from importlib import reload

from dask import dataframe as dd
#import matplotlib.pyplot as plt
#import seaborn as sns
#import plotly.express as px

from google.colab import drive
drive.mount("/content/gdrive")

warnings.filterwarnings('ignore')

pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
#pd.reset_option('display.max_rows')
# Out:
# Mounted at /content/gdrive

# %%
pd.__version__
# Out:
# '2.1.4'

# %%
home_folder = '/content/gdrive/MyDrive/Colab Notebooks/Portfolio/ML_HomeCredit_DefaultRiskEvaluation/'

# %% [markdown]
# ### Functions

# %% [markdown]
# The Python-file with the functions is at
# https://drive.google.com/file/d/17IchsTGy2QI9sq0LTIvGvxAk2mrWs4Xz/view?usp=sharing

# %%
# %load_ext autoreload
# %autoreload 2

sys.path.append(home_folder)
import driskfunc as dfunc

# %% [markdown]
# # 1. Load and Update Data

# %% [markdown]
# data source: https://storage.googleapis.com/341-home-credit-default/home-credit-default-risk.zip
#
# description: https://storage.googleapis.com/341-home-credit-default/Home%20Credit%20Default%20Risk.pdf

# %%
HCdescr = pd.read_csv(home_folder+'data/HomeCredit_columns_description.csv', encoding='latin1') #, dtype=dtype)

# %%
HCdescr.loc[HCdescr.Table == 'POS_CASH_balance.csv']
# Out:
#      Unnamed: 0                 Table                    Row  \
# 142         145  POS_CASH_balance.csv            SK_ID_PREV
# 143         146  POS_CASH_balance.csv             SK_ID_CURR
# 144         147  POS_CASH_balance.csv         MONTHS_BALANCE
# 145         148  POS_CASH_balance.csv         CNT_INSTALMENT
# 146         149  POS_CASH_balance.csv  CNT_INSTALMENT_FUTURE
# 147         150  POS_CASH_balance.csv   NAME_CONTRACT_STATUS
# 148         151  POS_CASH_balance.csv                 SK_DPD
# 149         152  POS_CASH_balance.csv             SK_DPD_DEF
#
#                                                                                                                                                                                                                                                         Description  \
# 142                                                                                                               ID of previous credit in Home Credit related to loan in our sample. (One loan in our sample can have 0,1,2 or more previous loans in Home Credit)
# 143                                                                                                                                                                                                                                        ID of loan in our sample
# 144  Month of balance relative to application date (-1 means the information to the freshest monthly snapshot, 0 means the information at application - often it will be the same as -1 as many banks are not updating the information to Credit Bureau regularly )
# 145                                                                                                                                                                                                                  Term of previous credit (can change over time)
# 146                                                                                                                                                                                                                 Installments left to pay on the previous credit
# 147                                                                                                                                                                                                                                Contract status during the month
# 148                                                                                                                                                                                                         DPD (days past due) during the month of previous credit
# 149                                                                                                                                                            DPD during the month with tolerance (debts with low loan amounts are ignored) of the previous credit
#
#                                    Special
# 142                                    NaN
# 143                                    NaN
# 144  time only relative to the application
# 145                                    NaN
# 146                                    NaN
# 147                                    NaN
# 148                                    NaN
# 149                                    NaN

# %%
csv_pc = home_folder+'data/POS_CASH_balance.csv'
HCapp_pc = dd.read_csv(csv_pc) #, dtype=dtype)

df = HCapp_pc
df_name = 'HCapp POS CASH balance'

# %%
df.npartitions
# Out:
# 6

# %%
df = df.sort_values(by=['SK_ID_PREV', 'MONTHS_BALANCE'], ascending=False)
df = df.sort_values(by=['SK_ID_CURR','SK_ID_PREV'], ascending=True)

# %%
df.head(100)
# Out:
#          SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 532573      1369693      100001             -53             4.0
# 1373359     1369693      100001             -54             4.0
# 1156999     1369693      100001             -55             4.0
# 454770      1369693      100001             -56             4.0
# 500325      1369693      100001             -57             4.0
# 1597518     1851984      100001             -93             4.0
# 197015      1851984      100001             -94             4.0
# 226147      1851984      100001             -95             4.0
# 1261679     1851984      100001             -96             4.0
# 1628483     1038818      100002              -1            24.0
# 1459063     1038818      100002              -2            24.0
# 1457904     1038818      100002              -3            24.0
# 1047747     1038818      100002              -4            24.0
# 1545952     1038818      100002              -5            24.0
# 940002      1038818      100002              -6            24.0
# 1183347     1038818      100002              -7            24.0
# 1180272     1038818      100002              -8            24.0
# 1175791     1038818      100002              -9            24.0
# 935281      1038818      100002             -10            24.0
# 367584      1038818      100002             -11            24.0
# 893750      1038818      100002             -12            24.0
# 513222      1038818      100002             -13            24.0
# 736924      1038818      100002             -14            24.0
# 1515133     1038818      100002             -15            24.0
# 1216849     1038818      100002             -16            24.0
# 260724      1038818      100002             -17            24.0
# 347569      1038818      100002             -18            24.0
# 139607      1038818      100002             -19            24.0
# 469982      1810518      100003             -18             7.0
# 1556709     1810518      100003             -19            12.0
# 638616      1810518      100003             -20            12.0
# 1280598     1810518      100003             -21            12.0
# 1416019     1810518      100003             -22            12.0
# 1248580     1810518      100003             -23            12.0
# 1556914     1810518      100003             -24            12.0
# 1278613     1810518      100003             -25            12.0
# 152816      2396755      100003             -66            12.0
# 157149      2396755      100003             -67            12.0
# 917030      2396755      100003             -68            12.0
# 352491      2396755      100003             -69            12.0
# 792448      2396755      100003             -70            12.0
# 498159      2396755      100003             -71            12.0
# 161894      2396755      100003             -72            12.0
# 1027855     2396755      100003             -73            12.0
# 332053      2396755      100003             -74            12.0
# 788960      2396755      100003             -75            12.0
# 249683      2396755      100003             -76            12.0
# 1206513     2396755      100003             -77            12.0
# 1032371     2636178      100003             -21             6.0
# 37251       2636178      100003             -22             6.0
# 367237      2636178      100003             -23             6.0
# 866857      2636178      100003             -24             6.0
# 220892      2636178      100003             -25             6.0
# 212706      2636178      100003             -26             6.0
# 38493       2636178      100003             -27             6.0
# 1134783     2636178      100003             -28             6.0
# 781265      1564014      100004             -24             3.0
# 168875      1564014      100004             -25             4.0
# Out:
# The dataset HCapp POS CASH balance has:
# 5 features of type int64.
# 2 features of type float64.
# 1 features of type string.

# %%
# %%time
# %reload_ext autoreload

nan_overview_df = dfunc.nan_type_overview_dd(df, size_df[0])
nan_overview_df.round(1).style.background_gradient(cmap="Blues")
# Out:
# CPU times: user 35.7 s, sys: 5.16 s, total: 40.9 s
# Wall time: 27.6 s
# <style type="text/css">
# #T_7cbfc_row0_col1, #T_7cbfc_row0_col2, #T_7cbfc_row1_col1, #T_7cbfc_row1_col2, #T_7cbfc_row2_col1, #T_7cbfc_row2_col2, #T_7cbfc_row5_col1, #T_7cbfc_row5_col2, #T_7cbfc_row6_col1, #T_7cbfc_row6_col2, #T_7cbfc_row7_col1, #T_7cbfc_row7_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_7cbfc_row3_col1, #T_7cbfc_row3_col2, #T_7cbfc_row4_col1, #T_7cbfc_row4_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7cbfc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7cbfc_level0_col0" class="col_heading level0 col0" >type</th>
#       <th id="T_7cbfc_level0_col1" class="col_heading level0 col1" >NaN[abs]</th>
#       <th id="T_7cbfc_level0_col2" class="col_heading level0 col2" >NaN[%]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7cbfc_level0_row0" class="row_heading level0 row0" >SK_ID_PREV</th>
#       <td id="T_7cbfc_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_7cbfc_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_7cbfc_row0_col2" class="data row0 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7cbfc_level0_row1" class="row_heading level0 row1" >SK_ID_CURR</th>
#       <td id="T_7cbfc_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_7cbfc_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_7cbfc_row1_col2" class="data row1 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7cbfc_level0_row2" class="row_heading level0 row2" >MONTHS_BALANCE</th>
#       <td id="T_7cbfc_row2_col0" class="data row2 col0" >int64</td>
#       <td id="T_7cbfc_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_7cbfc_row2_col2" class="data row2 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7cbfc_level0_row3" class="row_heading level0 row3" >CNT_INSTALMENT</th>
#       <td id="T_7cbfc_row3_col0" class="data row3 col0" >float64</td>
#       <td id="T_7cbfc_row3_col1" class="data row3 col1" >26071</td>
#       <td id="T_7cbfc_row3_col2" class="data row3 col2" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_7cbfc_level0_row4" class="row_heading level0 row4" >CNT_INSTALMENT_FUTURE</th>
#       <td id="T_7cbfc_row4_col0" class="data row4 col0" >float64</td>
#       <td id="T_7cbfc_row4_col1" class="data row4 col1" >26087</td>
#       <td id="T_7cbfc_row4_col2" class="data row4 col2" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_7cbfc_level0_row5" class="row_heading level0 row5" >NAME_CONTRACT_STATUS</th>
#       <td id="T_7cbfc_row5_col0" class="data row5 col0" >string</td>
#       <td id="T_7cbfc_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_7cbfc_row5_col2" class="data row5 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7cbfc_level0_row6" class="row_heading level0 row6" >SK_DPD</th>
#       <td id="T_7cbfc_row6_col0" class="data row6 col0" >int64</td>
#       <td id="T_7cbfc_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_7cbfc_row6_col2" class="data row6 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7cbfc_level0_row7" class="row_heading level0 row7" >SK_DPD_DEF</th>
#       <td id="T_7cbfc_row7_col0" class="data row7 col0" >int64</td>
#       <td id="T_7cbfc_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_7cbfc_row7_col2" class="data row7 col2" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Duplicates Check

# %%
# %reload_ext autoreload

df_dup = dfunc.get_dup_dd(df, name=df_name, size=size_df[0])
# Out:
# Total number of duplicates in " HCapp POS CASH balance " : 0 ( 0.0 %).

# %% [markdown]
# ## Other Checks and Modifications

# %% [markdown]
# #### Overview

# %%
df.describe().compute().T.round(1)
# Out:
#                             count       mean       std        min        25%  \
# SK_ID_PREV             10001358.0  1903216.6  535846.5  1000001.0  1436092.0
# SK_ID_CURR             10001358.0   278403.9  102763.7   100001.0   182234.0
# MONTHS_BALANCE         10001358.0      -35.0      26.1      -96.0      -54.0
# CNT_INSTALMENT          9975287.0       17.1      12.0        1.0       10.0
# CNT_INSTALMENT_FUTURE   9975271.0       10.5      11.1        0.0        3.0
# SK_DPD                 10001358.0       11.6     132.7        0.0        0.0
# SK_DPD_DEF             10001358.0        0.7      32.8        0.0        0.0
#
#                              50%        75%        max
# SK_ID_PREV             1898404.0  2372628.0  2843499.0
# SK_ID_CURR              273959.0   367081.0   456255.0
# MONTHS_BALANCE             -27.0      -13.0       -1.0
# CNT_INSTALMENT              12.0       24.0       92.0
# CNT_INSTALMENT_FUTURE        7.0       14.0       85.0
# SK_DPD                       0.0        0.0     4231.0
# SK_DPD_DEF                   0.0        0.0     3595.0

# %%
df_obj = df.describe(exclude=np.number).compute().T
df_obj['freq'] = pd.to_numeric(df_obj['freq'])
df_obj['count'] = pd.to_numeric(df_obj['count'])
df_obj['freq[%]'] = (df_obj['freq']/df_obj['count']*100).astype('float')
df_obj.round(1)
# Out:
#                      unique     count     top     freq  freq[%]
# NAME_CONTRACT_STATUS      9  10001358  Active  9151119     91.5

# %% [markdown]
# #### INSTALMENTS paid

# %%
df['INSTALMENTS_paid'] = df['CNT_INSTALMENT'] - df['CNT_INSTALMENT_FUTURE'] # align with credit card table

# %% [markdown]
# #### NAME_CONTRACT_STATUS

# %%
df.NAME_CONTRACT_STATUS.value_counts().compute()
# Out:
# NAME_CONTRACT_STATUS
# Active                   9151119
# Completed                 744883
# Signed                     87260
# Demand                      7065
# Returned to the store       5461
# Approved                    4917
# Amortized debt               636
# Canceled                      15
# XNA                            2
# Name: count, dtype: int64[pyarrow]

# %% [markdown]
# Inspection shows that a month with 'XNA', 'Canceled', 'Returned to the store',  (typicall the very first month of the credit running, i.e. oldest month in payment list of a specific SK_ID_PREV) does not end the contract, but continues with 'Active' in the following months.
# Even if 'XNA', 'Canceled', 'Returned to the store' give a hint on the credit worthiness, with just 2, 15, 5461 rows out of >10 Mio. it provides too few cases to show an effect. Maybe 'Refused' rather indicates mistakes when filling the application form.

# %% [markdown]
# 'Amortized debt' = next escalation level above 'Demand'
#
# 636 out of 10Mio rows. ---> add them to 'Demand'

# %%
df.loc[df.NAME_CONTRACT_STATUS == 'Returned to the store'].compute().head(5)
# Out:
#          SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 1026728     2299329      100006             -20             NaN
# 1453090     1387636      100092             -46            12.0
# 1608420     2216247      100094              -8             NaN
# 968275      2192263      100101             -42            12.0
# 1471089     1752483      100110              -2             NaN
#
#          CNT_INSTALMENT_FUTURE   NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF  \
# 1026728                    NaN  Returned to the store       0           0
# 1453090                   12.0  Returned to the store       0           0
# 1608420                    NaN  Returned to the store       0           0
# 968275                    11.0  Returned to the store       0           0
# 1471089                    NaN  Returned to the store       0           0
#
#          INSTALMENTS_paid
# 1026728               NaN
# 1453090               0.0
# 1608420               NaN
# 968275                1.0
# 1471089               NaN

# %%
df.loc[df.SK_ID_PREV == 2299329].compute()
# Out:
#          SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 1260947     2299329      100006             -13             5.0
# 1547042     2299329      100006             -14             5.0
# 1147003     2299329      100006             -15            12.0
# 1561018     2299329      100006             -16            12.0
# 1417695     2299329      100006             -17            12.0
# 1632814     2299329      100006             -18            12.0
# 419009      2299329      100006             -19            12.0
# 1026728     2299329      100006             -20             NaN
#
#          CNT_INSTALMENT_FUTURE   NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF  \
# 1260947                    0.0              Completed       0           0
# 1547042                    0.0                 Active       0           0
# 1147003                    8.0                 Active       0           0
# 1561018                    9.0                 Active       0           0
# 1417695                   10.0                 Active       0           0
# 1632814                   11.0                 Active       0           0
# 419009                    12.0                 Active       0           0
# 1026728                    NaN  Returned to the store       0           0
#
#          INSTALMENTS_paid
# 1260947               5.0
# 1547042               5.0
# 1147003               4.0
# 1561018               3.0
# 1417695               2.0
# 1632814               1.0
# 419009                0.0
# 1026728               NaN

# %%
df_cstat = df['NAME_CONTRACT_STATUS']
df_cstat = df_cstat.mask((df_cstat=='Signed'), 'Initialized')
df_cstat = df_cstat.mask((df_cstat=='Returned to the store'), 'Initialized')
df_cstat = df_cstat.mask((df_cstat=='Approved'), 'Initialized')
df_cstat = df_cstat.mask((df_cstat=='Canceled'), 'Initialized')
df_cstat = df_cstat.mask((df_cstat=='XNA'), 'Initialized')
df_cstat = df_cstat.mask((df_cstat=='Amortized debt'), 'Demand')

df['NAME_CONTRACT_STATUS_red'] = df_cstat
df['NAME_CONTRACT_STATUS_red'].value_counts().compute()
# Out:
# NAME_CONTRACT_STATUS_red
# Active         9151119
# Completed       744883
# Initialized      97655
# Demand            7701
# Name: count, dtype: int64[pyarrow]

# %% [markdown]
# ## Aggregate by SK_ID_PREV

# %%
df_stat = df.categorize(columns = ['NAME_CONTRACT_STATUS_red']).NAME_CONTRACT_STATUS_red
df_status_cat = dd.get_dummies(df_stat, prefix = 'STATUS', dtype=int)

df_with_dummies = dd.concat([df, df_status_cat], axis=1)

#df_with_dummies.head(20)

# %%
df_mean = df_with_dummies.groupby("SK_ID_PREV").mean(numeric_only=True)
df_mean = df_mean.drop(columns=['MONTHS_BALANCE',
                                'CNT_INSTALMENT',
                                'CNT_INSTALMENT_FUTURE'
                                ])

df_count = df_with_dummies.groupby("SK_ID_PREV")['MONTHS_BALANCE'].count().to_frame()
df_count = df_count.rename(columns={'MONTHS_BALANCE': 'MONTHS_BALANCE_count'})

df_installment = df_with_dummies.groupby("SK_ID_PREV")['MONTHS_BALANCE',
                                                       #CNT_INSTALMENT,
                                                       'CNT_INSTALMENT_FUTURE',
                                                       'NAME_CONTRACT_STATUS',
                                                       'NAME_CONTRACT_STATUS_red'
                                                       ].first()

install_cols = {'MONTHS_BALANCE': 'MONTHS_BALANCE_latest',
                'CNT_INSTALMENT_FUTURE': 'CNT_INSTALMENT_FUTURE_latest',
                'NAME_CONTRACT_STATUS': 'NAME_CONTRACT_STATUS_latest',
                'NAME_CONTRACT_STATUS_red': 'NAME_CONTRACT_STATUS_red_latest'
                }

df_installment = df_installment.rename(columns=install_cols)

df_installment_max = df_with_dummies.groupby("SK_ID_PREV")['CNT_INSTALMENT'
                                                       ].max().to_frame()
df_installment_max = df_installment_max.rename(columns={'CNT_INSTALMENT': 'CNT_INSTALMENT_max'})


df_inst = dd.concat([df_installment_max, df_installment], axis=1)
df_count_inst = dd.concat([df_count, df_inst], axis=1)
df_final = dd.concat([df_mean, df_count_inst], axis=1)

df_final = df_final.reset_index()
df_final=df_final.sort_values(by='SK_ID_CURR')

df_final.round(2).head(20)
# Out:
#         SK_ID_PREV  SK_ID_CURR  SK_DPD  SK_DPD_DEF  INSTALMENTS_paid  \
# 71457      1851984    100001.0    1.75        1.75              3.25
# 31924      1369693    100001.0    0.00        0.00              2.00
# 3757       1038818    100002.0    0.00        0.00              9.00
# 67854      1810518    100003.0    0.00        0.00              3.50
# 132952     2636178    100003.0    0.00        0.00              3.38
# 114374     2396755    100003.0    0.00        0.00              5.50
# 48632      1564014    100004.0    0.00        0.00              1.50
# 122020     2495675    100005.0    0.00        0.00              4.50
# 98213      2190416    100006.0    0.00        0.00              4.50
# 89362      2078043    100006.0    0.00        0.00              0.67
# 106805     2299329    100006.0    0.00        0.00              2.86
# 78381      1940724    100007.0    0.00        0.00              6.00
# 59314      1692033    100007.0    0.00        0.00              5.50
# 119386     2462742    100007.0    0.00        0.00              6.00
# 92883      2119973    100007.0    0.00        0.00              4.50
# 83270      2001242    100007.0    0.00        0.00              8.50
# 100261     2218188    100008.0    0.00        0.00              5.73
# 16061      1186888    100008.0    0.00        0.00              2.62
# 131336     2613879    100008.0    0.00        0.00              4.00
# 75858      1907290    100008.0  511.67        0.00              9.00
#
#         STATUS_Active  STATUS_Completed  STATUS_Demand  STATUS_Initialized  \
# 71457            0.75              0.25            0.0                0.00
# 31924            0.80              0.20            0.0                0.00
# 3757             1.00              0.00            0.0                0.00
# 67854            0.88              0.12            0.0                0.00
# 132952           0.88              0.12            0.0                0.00
# 114374           1.00              0.00            0.0                0.00
# 48632            0.75              0.25            0.0                0.00
# 122020           0.82              0.09            0.0                0.09
# 98213            1.00              0.00            0.0                0.00
# 89362            0.67              0.33            0.0                0.00
# 106805           0.75              0.12            0.0                0.12
# 78381            0.85              0.08            0.0                0.08
# 59314            1.00              0.00            0.0                0.00
# 119386           0.92              0.08            0.0                0.00
# 92883            1.00              0.00            0.0                0.00
# 83270            0.94              0.06            0.0                0.00
# 100261           0.91              0.09            0.0                0.00
# 16061            0.75              0.12            0.0                0.12
# 131336           0.89              0.11            0.0                0.00
# 75858            0.98              0.02            0.0                0.00
#
#         MONTHS_BALANCE_count  CNT_INSTALMENT_max  MONTHS_BALANCE_latest  \
# 71457                      4                 4.0                    -93
# 31924                      5                 4.0                    -53
# 3757                      19                24.0                     -1
# 67854                      8                12.0                    -18
# 132952                     8                 6.0                    -21
# 114374                    12                12.0                    -66
# 48632                      4                 4.0                    -24
# 122020                    11                12.0                    -15
# 98213                     10                12.0                     -1
# 89362                      3                48.0                     -4
# 106805                     8                12.0                    -13
# 78381                     13                12.0                    -24
# 59314                     12                24.0                     -1
# 119386                    13                12.0                    -46
# 92883                     10                10.0                    -68
# 83270                     18                18.0                    -11
# 100261                    11                10.0                     -2
# 16061                      8                 6.0                    -77
# 131336                     9                30.0                    -13
# 75858                     55                10.0                    -23
#
#         CNT_INSTALMENT_FUTURE_latest NAME_CONTRACT_STATUS_latest  \
# 71457                            0.0                   Completed
# 31924                            0.0                   Completed
# 3757                             6.0                      Active
# 67854                            0.0                   Completed
# 132952                           0.0                   Completed
# 114374                           1.0                      Active
# 48632                            0.0                   Completed
# 122020                           0.0                   Completed
# 98213                            3.0                      Active
# 89362                            0.0                   Completed
# 106805                           0.0                   Completed
# 78381                            0.0                   Completed
# 59314                           13.0                      Active
# 119386                           0.0                   Completed
# 92883                            1.0                      Active
# 83270                            0.0                   Completed
# 100261                           0.0                   Completed
# 16061                            0.0                   Completed
# 131336                           0.0                   Completed
# 75858                            0.0                   Completed
#
#        NAME_CONTRACT_STATUS_red_latest
# 71457                        Completed
# 31924                        Completed
# 3757                            Active
# 67854                        Completed
# 132952                       Completed
# 114374                          Active
# 48632                        Completed
# 122020                       Completed
# 98213                           Active
# 89362                        Completed
# 106805                       Completed
# 78381                        Completed
# 59314                           Active
# 119386                       Completed
# 92883                           Active
# 83270                        Completed
# 100261                       Completed
# 16061                        Completed
# 131336                       Completed
# 75858                        Completed

# %%
df_stat_l = df_final.categorize(columns = ['NAME_CONTRACT_STATUS_red_latest']).NAME_CONTRACT_STATUS_red_latest
df_status_l_cat = dd.get_dummies(df_stat_l, prefix = 'STATUS_latest', dtype=int)

df_with_dummies_final = dd.concat([df_final, df_status_l_cat], axis=1)

#df_with_dummies.head(20)

# %%
size_df_final = [df_final.shape[0].compute(),  df_final.shape[1]]

print('The condensed dataset has', size_df_final[0], 'rows and', size_df_final[1], 'features.')
print('Initial size was', size_df[0], 'rows and', size_df[1], 'features.')
# Out:
# The condensed dataset has 936325 rows and 15 features.
# Initial size was 10001358 rows and 8 features.

# %%
nan_overview_df = dfunc.nan_type_overview_dd(df_final, size_df_final[0])
nan_overview_df.round(1).style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_d121d_row0_col1, #T_d121d_row0_col2, #T_d121d_row1_col1, #T_d121d_row1_col2, #T_d121d_row2_col1, #T_d121d_row2_col2, #T_d121d_row3_col1, #T_d121d_row3_col2, #T_d121d_row5_col1, #T_d121d_row5_col2, #T_d121d_row6_col1, #T_d121d_row6_col2, #T_d121d_row7_col1, #T_d121d_row7_col2, #T_d121d_row8_col1, #T_d121d_row8_col2, #T_d121d_row9_col1, #T_d121d_row9_col2, #T_d121d_row11_col1, #T_d121d_row11_col2, #T_d121d_row13_col1, #T_d121d_row13_col2, #T_d121d_row14_col1, #T_d121d_row14_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_d121d_row4_col1, #T_d121d_row4_col2, #T_d121d_row10_col1, #T_d121d_row10_col2, #T_d121d_row12_col1, #T_d121d_row12_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d121d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d121d_level0_col0" class="col_heading level0 col0" >type</th>
#       <th id="T_d121d_level0_col1" class="col_heading level0 col1" >NaN[abs]</th>
#       <th id="T_d121d_level0_col2" class="col_heading level0 col2" >NaN[%]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d121d_level0_row0" class="row_heading level0 row0" >SK_ID_PREV</th>
#       <td id="T_d121d_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_d121d_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_d121d_row0_col2" class="data row0 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d121d_level0_row1" class="row_heading level0 row1" >SK_ID_CURR</th>
#       <td id="T_d121d_row1_col0" class="data row1 col0" >float64</td>
#       <td id="T_d121d_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_d121d_row1_col2" class="data row1 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d121d_level0_row2" class="row_heading level0 row2" >SK_DPD</th>
#       <td id="T_d121d_row2_col0" class="data row2 col0" >float64</td>
#       <td id="T_d121d_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_d121d_row2_col2" class="data row2 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d121d_level0_row3" class="row_heading level0 row3" >SK_DPD_DEF</th>
#       <td id="T_d121d_row3_col0" class="data row3 col0" >float64</td>
#       <td id="T_d121d_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_d121d_row3_col2" class="data row3 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d121d_level0_row4" class="row_heading level0 row4" >INSTALMENTS_paid</th>
#       <td id="T_d121d_row4_col0" class="data row4 col0" >float64</td>
#       <td id="T_d121d_row4_col1" class="data row4 col1" >890</td>
#       <td id="T_d121d_row4_col2" class="data row4 col2" >0.100000</td>
#     </tr>
#     <tr>
#       <th id="T_d121d_level0_row5" class="row_heading level0 row5" >STATUS_Active</th>
#       <td id="T_d121d_row5_col0" class="data row5 col0" >float64</td>
#       <td id="T_d121d_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_d121d_row5_col2" class="data row5 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d121d_level0_row6" class="row_heading level0 row6" >STATUS_Completed</th>
#       <td id="T_d121d_row6_col0" class="data row6 col0" >float64</td>
#       <td id="T_d121d_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_d121d_row6_col2" class="data row6 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d121d_level0_row7" class="row_heading level0 row7" >STATUS_Demand</th>
#       <td id="T_d121d_row7_col0" class="data row7 col0" >float64</td>
#       <td id="T_d121d_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_d121d_row7_col2" class="data row7 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d121d_level0_row8" class="row_heading level0 row8" >STATUS_Initialized</th>
#       <td id="T_d121d_row8_col0" class="data row8 col0" >float64</td>
#       <td id="T_d121d_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_d121d_row8_col2" class="data row8 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d121d_level0_row9" class="row_heading level0 row9" >MONTHS_BALANCE_count</th>
#       <td id="T_d121d_row9_col0" class="data row9 col0" >int64</td>
#       <td id="T_d121d_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_d121d_row9_col2" class="data row9 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d121d_level0_row10" class="row_heading level0 row10" >CNT_INSTALMENT_max</th>
#       <td id="T_d121d_row10_col0" class="data row10 col0" >float64</td>
#       <td id="T_d121d_row10_col1" class="data row10 col1" >890</td>
#       <td id="T_d121d_row10_col2" class="data row10 col2" >0.100000</td>
#     </tr>
#     <tr>
#       <th id="T_d121d_level0_row11" class="row_heading level0 row11" >MONTHS_BALANCE_latest</th>
#       <td id="T_d121d_row11_col0" class="data row11 col0" >int64</td>
#       <td id="T_d121d_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_d121d_row11_col2" class="data row11 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d121d_level0_row12" class="row_heading level0 row12" >CNT_INSTALMENT_FUTURE_latest</th>
#       <td id="T_d121d_row12_col0" class="data row12 col0" >float64</td>
#       <td id="T_d121d_row12_col1" class="data row12 col1" >890</td>
#       <td id="T_d121d_row12_col2" class="data row12 col2" >0.100000</td>
#     </tr>
#     <tr>
#       <th id="T_d121d_level0_row13" class="row_heading level0 row13" >NAME_CONTRACT_STATUS_latest</th>
#       <td id="T_d121d_row13_col0" class="data row13 col0" >string</td>
#       <td id="T_d121d_row13_col1" class="data row13 col1" >0</td>
#       <td id="T_d121d_row13_col2" class="data row13 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d121d_level0_row14" class="row_heading level0 row14" >NAME_CONTRACT_STATUS_red_latest</th>
#       <td id="T_d121d_row14_col0" class="data row14 col0" >string</td>
#       <td id="T_d121d_row14_col1" class="data row14 col1" >0</td>
#       <td id="T_d121d_row14_col2" class="data row14 col2" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# This modified data set can now be merged with the 'previous applictions' dataset.

# %% [markdown]
# # Export

# %%
# %%capture
! mkdir home_folder+'cleaned/'
df_final.to_csv(home_folder+'cleaned/HC_POS_CASH_cleaned.csv',
                 index=False, single_file = True)
